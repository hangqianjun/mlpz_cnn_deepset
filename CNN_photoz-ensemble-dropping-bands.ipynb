# %% [markdown]
# # this is training the CNNPZ model on the noisy mock data with randomly dropping bands

# %% [raw]
# import os
# os.environ["OMP_NUM_THREADS"] = "32"
# os.environ["MKL_NUM_THREADS"] = "32"

# %%
import sys

# %%
from packaging import version
import sklearn
from sklearn.model_selection import KFold, train_test_split

assert version.parse(sklearn.__version__) >= version.parse("1.0.1")

# %%
import tensorflow as tf

assert version.parse(tf.__version__) >= version.parse("2.8.0")
# Out:
# 2026-09-04 03:30:51.310913: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-09-04 03:30:51.310939: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-09-04 03:30:51.312256: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-09-04 03:30:51.319783: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-04 03:30:54.328498: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [raw]
# import tensorflow_probability as tfp

# %%
import matplotlib.pyplot as plt

plt.rc('font', size=14)
plt.rc('axes', labelsize=14, titlesize=14)
plt.rc('legend', fontsize=14)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

# %%
import pandas as pd
import h5py
import numpy as np

# %%
import json
import os

# %% [raw]
# tf.config.threading.set_intra_op_parallelism_threads(32)
# tf.config.threading.set_inter_op_parallelism_threads(32)

# %% [raw]
# print(tf.config.threading.get_intra_op_parallelism_threads())
# print(tf.config.threading.get_inter_op_parallelism_threads())

# %% [markdown]
# # predefined functions

# %%
def rebin_filter(bin_edges, counts, new_edges):
  new_counts = []
  for i in range(len(new_edges) - 1):
      lo, hi = new_edges[i], new_edges[i+1]
      total = 0.0
      for j, (b0, b1, c) in enumerate(
              zip(bin_edges[:-1], bin_edges[1:], counts)):
          overlap = max(0, min(hi, b1) - max(lo, b0))
          total  += c * overlap#/(b1 - b0)  # proportional share
      new_counts.append(total)
  return np.array(new_counts)

def get_bin_edges(centres):
    step = centres[1] - centres[0]          # uniform spacing
    inner_edges = (centres[:-1] + centres[1:]) / 2
    first_edge  = centres[0]  - step / 2
    last_edge   = centres[-1] + step / 2
    return np.concatenate([[first_edge], inner_edges, [last_edge]])

# %%
# now write a code to convert all galaxies in the training set into the desired data format:
# array of magnitude
# array of wavelength
# array of filter availability

def convert_data_format(df, lambda_array_cen, no_detect = np.nan, no_obs = np.inf, no_detect_val = 0,
                       no_obs_val = 0):
    # no detection: setting to nan, sensitivity = 1
    # no observation: setting to inf, sensitivity = 0
    num_galaxies = len(df)
    num_wavelength_bins = len(lambda_array_cen)
    
    mags_data = np.zeros((num_galaxies, num_wavelength_bins))
    filter_availability_data = np.zeros((num_galaxies, num_wavelength_bins))
    
    for b in "ugrizy":
        ind = filter_blocks[b].astype(bool)
        mags_data[:, ind] = df[f'mag_{b}_lsst'].to_numpy()[:, None]
        filter_availability_data[:, ind] = 1
    
    for b in "JH":
        ind = filter_blocks[b].astype(bool)
        mags_data[:, ind] = df[f'mag_{b}_roman'].to_numpy()[:, None]
        filter_availability_data[:, ind] = 1
    
    # convert any nan or inf to zero:
    ind_nan = np.isnan(mags_data)
    ind_inf = np.isinf(mags_data)

    if no_obs == np.inf:
        filter_availability_data[ind_inf] = 0
        mags_data[ind_inf] = no_obs_val
        mags_data[ind_nan] = no_detect_val
    elif no_obs == np.nan:
        filter_availability_data[ind_nan] = 0
        mags_data[ind_nan] = no_obs_val
        mags_data[ind_inf] = no_detect_val

    wave_labels = np.arange(num_wavelength_bins)
    # normalize this
    wave_labels = wave_labels/wave_labels[-1]
    
    lambda_labels = np.outer(np.ones(num_galaxies), wave_labels)
    
    transformed_df = [mags_data, lambda_labels, filter_availability_data]
    transformed_df = np.stack(transformed_df, axis=-1)
    
    return transformed_df

# %%
#Functions to plot: bias, sigma, outlier fraction:
#Functions to produce these quantities as functin of mag
#from astropy.stats import biweight_location, biweight_scale
from scipy.stats import sigmaclip

def get_biweight_mean_sigma_outlier(subset, nclip= 3, abs_out_thresh=0.2):
    subset_clip, _, _ = sigmaclip(subset, low=3, high=3)
    for _j in range(nclip):
        subset_clip, _, _ = sigmaclip(subset_clip, low=3, high=3)

    #mean = biweight_location(subset_clip)
    #std = biweight_scale(subset_clip)
    mean = np.mean(subset_clip)
    std = np.std(subset_clip)
    #outlier_rate = np.sum(np.abs(subset) > 3 * biweight_scale(subset_clip)) / len(
    #    subset
    #)
    outlier_rate = np.sum(np.abs(subset) > 3 * np.std(subset_clip)) / len(
        subset
    )
    abs_outlier_rate = np.sum(np.abs(subset) > abs_out_thresh) / len(
        subset
    )

    return (
        mean,
        std / np.sqrt(len(subset_clip)),
        std,
        outlier_rate,
        abs_outlier_rate,
    )

# %%
import pickle

def get_all_stats(y_train, y_pred, imag_data, save=True, saveroot="", redshift_bins = np.linspace(0,2.5,11), imag_bins = np.linspace(18, 25.5,11)):
    Y = y_train.to_numpy()
    Y2 = y_pred.flatten()
    dz = (Y2 - Y)/(1+Y)
    stats = get_biweight_mean_sigma_outlier(dz, nclip= 3, abs_out_thresh=0.2)

    # split in terms of i-mags and redshifts
    redshift_stats = []
    imag_stats = []
    for i in range(10):
        ind= (Y > redshift_bins[i]) & (Y < redshift_bins[i+1])
        redshift_stats.append(get_biweight_mean_sigma_outlier(dz[ind]))
        ind= (imag_data > imag_bins[i]) & (imag_data < imag_bins[i+1])
        imag_stats.append(get_biweight_mean_sigma_outlier(dz[ind]))

    if save == True:
        with open(saveroot, "wb") as f:
            pickle.dump([stats, redshift_stats, imag_stats], f)

    return stats, redshift_stats, imag_stats

def read_stats(fname):
    with open(fname, "rb") as f:
        data = pickle.load(f)
    stats, redshift_stats, imag_stats = data
    return stats, redshift_stats, imag_stats

# %%
import matplotlib.gridspec as gridspec

def plot_stats(stats, redshift_stats, imag_stats, y_train, y_pred, redshift_bins, imag_bins, i_mag_data, save_path=None):
    Y  = y_train.to_numpy()
    Y2 = y_pred.flatten()
    dz = (Y2 - Y) / (1 + Y)

    fig = plt.figure(figsize=(15, 5))   # ← reduced height; 15/3 = 5 per column → square
    gs  = gridspec.GridSpec(
        2, 3,
        figure=fig,
        height_ratios=[2, 1],
        hspace=0.05,
        wspace=0.35
    )
    
    ax_scatter = fig.add_subplot(gs[:, 0])
    ax_zstats  = fig.add_subplot(gs[0, 1])
    ax_zdz     = fig.add_subplot(gs[1, 1], sharex=ax_zstats)
    ax_istats  = fig.add_subplot(gs[0, 2])
    ax_idz     = fig.add_subplot(gs[1, 2], sharex=ax_istats)
    
    # Only scatter panel needs to be square
    ax_scatter.set_box_aspect(1)    # ← only this one

    # ── Panel 1: scatter plot ────────────────────────────────────────────────
    mean, _mean_err, std, outlier_rate, abs_outlier_rate = stats
    mean, std, outlier_rate, abs_outlier_rate = (
        round(mean, 4), round(std, 4),
        round(outlier_rate, 4), round(abs_outlier_rate, 4)
    )

    ax_scatter.scatter(y_train, y_pred, s=0.1, color='k')
    ax_scatter.plot([0, 2.5], [0, 2.5], 'r-')
    ax_scatter.plot([0, 2.5], [0 - 3*std, 2.5 - 3*std], 'r--')
    ax_scatter.plot([0, 2.5], [0 + 3*std, 2.5 + 3*std], 'r--')
    ax_scatter.set_xlim([0, 2.5])
    ax_scatter.set_ylim([0, 2.5])
    ax_scatter.set_xlabel('truth redshift')
    ax_scatter.set_ylabel('predicted redshift')

    abs_out_thresh = 0.2
    label = (
        rf"$\Delta z = {mean}$" + "\n" +
        rf"$\sigma z = {std}$"  + "\n" +
        rf"outlier rate (>3$\sigma$) = {outlier_rate}" + "\n" +
        f"outlier rate (>{abs_out_thresh}) = {abs_outlier_rate}"
    )
    ax_scatter.text(0.1, 1.8, label, fontsize=12)

    # ── Panel 2: redshift statistics ─────────────────────────────────────────
    N_bin  = len(redshift_bins) - 1
    z_mean = np.zeros(N_bin)
    z_err  = np.zeros(N_bin)
    z_std  = np.zeros(N_bin)
    z_out  = np.zeros(N_bin)
    z_abs  = np.zeros(N_bin)
    for i in range(N_bin):
        z_mean[i], z_err[i], z_std[i], z_out[i], z_abs[i] = redshift_stats[i]

    z_centres = (redshift_bins[1:] + redshift_bins[:-1]) / 2
    ax_zstats.plot(z_centres, z_mean, '-', label="bias")
    ax_zstats.plot(z_centres, z_std,  '-', label=r"$\sigma_z$")
    ax_zstats.plot(z_centres, z_out,  '-', label="outlier rate")
    ax_zstats.legend()
    ax_zstats.set_ylabel("statistics")
    plt.setp(ax_zstats.get_xticklabels(), visible=False)

    ax_zdz.scatter(Y, dz, s=0.1, color='k')
    ax_zdz.set_xlabel("redshift")
    ax_zdz.set_ylabel(r"$(z_{pred} - z_{true})/(1 + z_{true})$")
    ax_zdz.set_ylim([-0.5, 0.5])    # ← y-axis limit on lower panel

    # ── Panel 3: i-magnitude statistics ──────────────────────────────────────
    N_bin  = len(imag_bins) - 1
    i_mean = np.zeros(N_bin)
    i_err  = np.zeros(N_bin)
    i_std  = np.zeros(N_bin)
    i_out  = np.zeros(N_bin)
    i_abs  = np.zeros(N_bin)
    for i in range(N_bin):
        i_mean[i], i_err[i], i_std[i], i_out[i], i_abs[i] = imag_stats[i]

    i_centres = (imag_bins[1:] + imag_bins[:-1]) / 2
    ax_istats.plot(i_centres, i_mean, '-', label="bias")
    ax_istats.plot(i_centres, i_std,  '-', label=r"$\sigma_z$")
    ax_istats.plot(i_centres, i_out,  '-', label="outlier rate")
    ax_istats.legend()
    ax_istats.set_ylabel("statistics")
    plt.setp(ax_istats.get_xticklabels(), visible=False)

    ax_idz.scatter(i_mag_data, dz, s=0.1, color='k')
    ax_idz.set_xlabel("i magnitude")
    ax_idz.set_ylabel(r"$(z_{pred} - z_{true})/(1 + z_{true})$")
    ax_idz.set_ylim([-0.5, 0.5])    # ← y-axis limit on lower panel

    plt.suptitle("Photo-z Statistics", fontsize=14)
    plt.tight_layout()
    plt.show()

    # Save if filename provided
    if save_path is not None:
        plt.savefig(save_path, dpi=150, bbox_inches='tight')
        print(f"Plot saved to {save_path}")

# %%
def stats_to_markdown(stats1_input, stats2_input, labels=("Mean", "Mean err", "Std", "Outlier rate", "Abs outlier rate"), skip_indices=(1,),
                     data_title=("Dataset 1", "Dataset 2")):
    # 0. Filter out skipped indices
    keep = [i for i in range(len(stats1_input)) if i not in skip_indices]
    stats1 = [stats1_input[i] for i in keep]
    stats2 = [stats2_input[i] for i in keep]
    labels = [labels[i] for i in keep]
    
    # 1. Fractional change vs dataset 1
    pct_change = [100 * (s2 - s1) / s1 if s1 != 0 else float('nan')
                  for s1, s2 in zip(stats1, stats2)]
    
    # 3. Build rows, rounded to 3 digits
    rows = []
    for label, s1, s2, pc in zip(labels, stats1, stats2, pct_change):
        rows.append(f"| {label} | {s1:.3g} | {s2:.3g} | {pc:.3g}% |")
    
    # 4. Assemble Markdown
    md = (
        f"| Statistic | {data_title[0]} | {data_title[1]} | % change |\n"
        "|---|---:|---:|---:|\n"
        + "\n".join(rows)
    )
    return md

# %%
def compare_binned_stats(redshift_bins, imag_bins, redshift_stats1, imag_stats1, redshift_stats2, imag_stats2):
    fig,axarr=plt.subplots(1, 2,figsize=(10,4))

    xlabels=["redshifts", "i magnitude"]

    for j, bins, stats1, stats2 in zip([0,1], [redshift_bins, imag_bins], 
                                      [redshift_stats1, imag_stats1], [redshift_stats2, imag_stats2]):
        plt.sca(axarr[j])
        N_bin = len(bins) - 1
        xx = (bins[1:] + bins[:-1])/2
        
        mean1 = np.zeros(N_bin)
        std1 = np.zeros(N_bin)
        outlier_rate1 = np.zeros(N_bin)
        for i in range(N_bin):
          mean1[i], _, std1[i], outlier_rate1[i], _ = stats1[i]
    
    
        mean2 = np.zeros(N_bin)
        std2 = np.zeros(N_bin)
        outlier_rate2 = np.zeros(N_bin)
        for i in range(N_bin):
          mean2[i], _, std2[i], outlier_rate2[i], _ = stats2[i]
        
        plt.plot(xx, mean1, '-',label="bias", color="C0")
        plt.plot(xx, std1, '-',label="$\sigma_z$", color="C1")
        plt.plot(xx, outlier_rate1, '-',label="outlier rate", color="C2")

        plt.plot(xx, mean2, '--', color="C0")
        plt.plot(xx, std2, '--', color="C1")
        plt.plot(xx, outlier_rate2, '--', color="C2")
        plt.legend()
        plt.ylabel("statistics")
        plt.xlabel(xlabels[j])
        plt.grid()
    plt.tight_layout()

# %%
def stretch(x, c=0.5, k=10):
    """
    x: array of values in [0,1]
    c: center of your typical fluctuation band
    k: stretch strength (try 5-50; higher = more aggressive)
    """
    x = np.asarray(x)
    u = np.where(x >= c, (x - c) / (1 - c), (x - c) / c)  # -> [-1, 1], c -> 0
    stretched = np.arcsinh(k * u) / np.arcsinh(k)          # amplify near u=0
    y = np.where(stretched >= 0, c + stretched * (1 - c), c + stretched * c)
    return np.clip(y, 0, 1)

# %% [markdown]
# ## Load training and test data, filter curves

# %%
saveroot = "/pscratch/sd/q/qhang/cnnpz/cardinal/"
fname = saveroot + "train_100k_noisy_y1_i23.parquet"
training_y1 = pd.read_parquet(fname)
training_y1 = training_y1.rename(columns={'Roman_obs_J129': 'mag_J_roman', 
                                              'Roman_obs_H158': 'mag_H_roman'})

fname = saveroot + "train_100k_noisy_y10_i25.4.parquet"
training_y10 = pd.read_parquet(fname)
training_y10 = training_y10.rename(columns={'Roman_obs_J129': 'mag_J_roman', 
                                              'Roman_obs_H158': 'mag_H_roman'})

saveroot = "/pscratch/sd/q/qhang/cnnpz/cardinal/"
fname = saveroot + "test_100k_noisy_y1_i23.parquet"
test_y1 = pd.read_parquet(fname)
test_y1 = test_y1.rename(columns={'Roman_obs_J129': 'mag_J_roman', 
                                              'Roman_obs_H158': 'mag_H_roman'})

fname = saveroot + "test_100k_noisy_y10_i25.4.parquet"
test_y10 = pd.read_parquet(fname)
test_y10 = test_y10.rename(columns={'Roman_obs_J129': 'mag_J_roman', 
                                              'Roman_obs_H158': 'mag_H_roman'})

# %%
training_y1.keys()
# Out:
# Index(['galaxy_id', 'ra', 'dec', 'sedid', 'size', 'Ellipticity_1',
#        'Ellipticity_2', 'Roman_Y106', 'Roman_J129', 'Roman_H158', 'Roman_F184',
#        'Roman_K213', 'WISE_W1', 'WISE_W2', 'redshift', 'true_redshift',
#        't_true_redshift', 'Euclid_Y', 'Euclid_J', 'Euclid_H',
#        'Euclid_redshift', 'shift_ra', 'shift_dec', 'Ellipticity1',
#        'Ellipticity2', 'Roman_obs_F184', 'Roman_obs_K213',
#        'totalHalfLightRadiusArcsec', 'TotalEllipticity', 'mag_u_lsst',
#        'mag_u_lsst_err', 'mag_g_lsst', 'mag_g_lsst_err', 'mag_r_lsst',
#        'mag_r_lsst_err', 'mag_i_lsst', 'mag_i_lsst_err', 'mag_z_lsst',
#        'mag_z_lsst_err', 'mag_y_lsst', 'mag_y_lsst_err', 'major', 'minor',
#        'mag_y_euclid_nisp', 'mag_y_euclid_nisp_err', 'mag_j_euclid_nisp',
#        'mag_j_euclid_nisp_err', 'mag_h_euclid_nisp', 'mag_h_euclid_nisp_err',
#        'Roman_obs_Y106', 'Roman_obs_Y106_err', 'mag_J_roman',
#        'Roman_obs_J129_err', 'mag_H_roman', 'Roman_obs_H158_err'],
#       dtype='object')

# %% [markdown]
# ### Transform data, make X_train, Y_train, and test dataset, variants of this dataset

# %%
# get the LSST and roman filter curves:
filter_root = "/global/homes/q/qhang/desc/rail_base/src/rail/examples_data/estimation_data/data/FILTER/"

wave = {
    "Y":106,
    "J":129,
    "H":158,
}
lsst_filter_curves = {}
roman_filter_curves = {}
for b in "ugrizy":
  lsst_filter_curves[b] = np.loadtxt(filter_root + f'DC2LSST_{b}.res')

for b in "YJH":
  roman_filter_curves[b] = np.loadtxt(filter_root + f'roman_{b}{wave[b]}.res')

# define the wavelength grid
# to begin with, use blocks rather than filter curves
lambda_min = lsst_filter_curves['u'][:,0].min()
lambda_max = roman_filter_curves['H'][:,0].max()
print(lambda_min,lambda_max)

lambda_array = np.linspace(lambda_min,lambda_max,31)
# now let's conver filter curves to blocks: here let's also ignore the big Y band as it overlaps with the y band
# Out:
# 3000.0 18650.0

# %%
bin_edges = {}
for b in "ugrizyJH":
  if b not in "JH":
    bin_edges[b] = get_bin_edges(lsst_filter_curves[b][:,0])
  else:
    bin_edges[b] = get_bin_edges(roman_filter_curves[b][:,0])
new_edges = lambda_array

rebinned_filters={}
for b in "ugrizyJH":
  if b not in "JH":
    counts = lsst_filter_curves[b][:,1]
  else:
    counts = roman_filter_curves[b][:,1]
  rebinned_filters[b] = rebin_filter(bin_edges[b], counts, new_edges)

lambda_array_cen = (new_edges[1:] + new_edges[:-1])/2
dlambda = new_edges[1] - new_edges[0]
#for b in "ugrizyJH":
#  plt.plot(lambda_array_cen, rebinned_filters[b],'.-')

# further convert this to blocks:
# let's take 1 when the current filter value is > next filter
filter_blocks={}
bands = "ugrizyJH"
for i, b in enumerate("ugrizyJ"):
  if i>0:
    filter_blocks[b] = (rebinned_filters[b] >= rebinned_filters[bands[i+1]]) & (rebinned_filters[b] > rebinned_filters[bands[i-1]])
  else:
    filter_blocks[b] = (rebinned_filters[b] > rebinned_filters[bands[i+1]])
filter_blocks['H'] = (rebinned_filters['H'] > rebinned_filters['J']) & (rebinned_filters['H'] > rebinned_filters['y'])

# %%
def transform_data_to_XY(data, apply_stretch = True, c=0.8, k=20, max_mag = 32):
    data_transformed = convert_data_format(data, lambda_array_cen)
    # now split training and validation set:
    Y = data['redshift']
    X = np.copy(data_transformed)
    X[:,:,0] /= max_mag
    if apply_stretch == True:
        X[:,:,0] = stretch(X[:,:,0], c=c, k=k)
    return X, Y

# %%
X_y1, Y_y1 = transform_data_to_XY(training_y1)
X_test_y1, Y_test_y1 = transform_data_to_XY(test_y1)

X_y10, Y_y10 = transform_data_to_XY(training_y10)
X_test_y10, Y_test_y10 = transform_data_to_XY(test_y10)

# %%
print(X_y1.shape, Y_y1.shape)
# Out:
# (107189, 30, 3) (107189,)

# %% [markdown]
# ## Making datasets with missing bands - NIR removal

# %%
def make_incomplete_nir_data(data, frac=0.5, sub_val = np.inf):
    subset = data.sample(frac=0.5)
    idx = subset.index
    idx = list(subset.index)
    data_copy = data.copy()
    data_copy.loc[idx, 'mag_J_roman'] = np.inf 
    data_copy.loc[idx, 'mag_H_roman'] = np.inf
    X_misnir, Y_misnir = transform_data_to_XY(data_copy)
    return X_misnir, Y_misnir

# %%
# let's construct a dataset where half of the sample do not have NIR measurements:
X_y1_misnir, Y_y1_misnir = make_incomplete_nir_data(training_y1)
X_test_y1_misnir, Y_test_y1_misnir = make_incomplete_nir_data(test_y1)

X_y10_misnir, Y_y10_misnir = make_incomplete_nir_data(training_y10)
X_test_y10_misnir, Y_test_y10_misnir = make_incomplete_nir_data(test_y10)

# %% [markdown]
# # visualize the data

# %%
def visualize_the_data(X, Y, title="Example data vector"):
    delta_wave = 1/len(lambda_array_cen)
    for i, b in enumerate("ugrizyJH"):
      plt.bar(X[i,:,1] , filter_blocks[b].astype(int), color=f'C{i}', width=delta_wave, alpha=0.2,
             edgecolor='white')
    for i in range(5):
      z = Y[i]
      plt.plot(X[i,:,1], X[i,:,0], label=f"z={round(z,2)}")
      plt.plot(X[i,:,1], X[i,:,2], color='k')
    plt.plot(X[i,:,1], X[i,:,2], color='k', label="sensitivity")
    plt.ylabel("mag (normed)")
    plt.xlabel("wavelength label")
    plt.legend()
    plt.title(title)

# %%
visualize_the_data(X_y1, Y_y1, title="Y1 training example")

# %%
visualize_the_data(X_y1_misnir, Y_y1_misnir, title="Y1 misnir example")

# %%
visualize_the_data(X_y10, Y_y10, title="Y10 training example")

# %%
visualize_the_data(X_y10_misnir, Y_y10_misnir, title="Y10 misnir example")

# %% [markdown]
# # training ensemble model

# %%
# here code up a CNN to with a 1D filter:
from tensorflow.keras import layers, models, callbacks

def build_model(input_shape):
    # 6 layers
    model = models.Sequential([
        layers.Conv1D(32,  kernel_size=3, activation='relu',
                      padding='same', input_shape=input_shape),
        layers.MaxPooling1D(),
        layers.Conv1D(64,  kernel_size=3, activation='relu',
                      padding='same'),
        layers.MaxPooling1D(),
        layers.Conv1D(128, kernel_size=3, activation='relu',
                      padding='same'),
        layers.MaxPooling1D(),
        layers.Conv1D(256, kernel_size=3, activation='relu',
                      padding='same'),
        #layers.MaxPooling1D(),
        layers.Conv1D(512, kernel_size=3, activation='relu',
                      padding='same'),
        layers.Conv1D(512, kernel_size=3, activation='relu',
                      padding='same'),
        layers.GlobalAveragePooling1D(),
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.3),
        layers.Dense(1)
    ])
    return model

def build_model_v2(input_shape):
    # 5 layers
    model = models.Sequential([
        layers.Conv1D(32,  kernel_size=3, activation='relu',
                      padding='same', input_shape=input_shape),
        layers.MaxPooling1D(),
        layers.Conv1D(64,  kernel_size=3, activation='relu',
                      padding='same'),
        layers.MaxPooling1D(),
        layers.Conv1D(128, kernel_size=3, activation='relu',
                      padding='same'),
        layers.MaxPooling1D(),
        layers.Conv1D(256, kernel_size=3, activation='relu',
                      padding='same'),
        layers.MaxPooling1D(),
        layers.Conv1D(512, kernel_size=3, activation='relu',
                      padding='same'),
        layers.GlobalAveragePooling1D(),
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.3),
        layers.Dense(1)
    ])
    return model

# --- Prediction: average across all models ---
def ensemble_predict(trained_models, X_test):
    predictions = []
    
    for model, Y_mean, Y_std in trained_models:
        # predict in normalised space, then denormalise
        y_pred_norm = model.predict(X_test)
        y_pred = y_pred_norm * Y_std + Y_mean   # denormalise
        predictions.append(y_pred)
    
    # average predictions across all models
    return np.mean(predictions, axis=0), np.std(predictions, axis=0)
    

def plot_ensemble_losses(histories, ylim=(0, 0.1)):
    n_folds = len(histories)
    
    # Define colours and line styles explicitly
    style = {
        'loss':     {'color': 'blue',  'linestyle': '-'},   # solid blue
        'val_loss': {'color': 'blue',  'linestyle': '--'},  # dashed blue
        'mae':      {'color': 'red',   'linestyle': '-'},   # solid red
        'val_mae':  {'color': 'red',   'linestyle': '--'},  # dashed red
    }
    
    # n_folds panels + 1 summary panel
    fig, axes = plt.subplots(
        1, n_folds + 1,
        figsize=(5 * (n_folds + 1), 5),
        sharey=True
    )
    
    # --- Individual fold panels ---
    for fold, (ax, history) in enumerate(zip(axes[:-1], histories)):
        for metric, s in style.items():
            if metric in history.history:
                ax.plot(
                    history.history[metric],
                    label=metric,
                    color=s['color'],
                    linestyle=s['linestyle'],
                    linewidth=2
                )
        ax.set_title(f"Fold {fold+1}")
        ax.set_xlabel("Epoch")
        ax.set_ylim(ylim)
        ax.grid(True)
        ax.legend()
        if fold == 0:
            ax.set_ylabel("Loss / MAE")
    
    # --- Summary panel ---
    ax_summary = axes[-1]
    
    for metric, s in style.items():
        # collect this metric across all folds that have it
        all_folds = [
            h.history[metric]
            for h in histories
            if metric in h.history
        ]
        
        if len(all_folds) == 0:
            continue
        
        # pad to same length (early stopping may stop folds at different epochs)
        max_len = max(len(f) for f in all_folds)
        padded  = [
            np.pad(f, (0, max_len - len(f)), mode='edge')
            for f in all_folds
        ]
        
        mean   = np.mean(padded, axis=0)
        std    = np.std(padded,  axis=0)
        epochs = np.arange(max_len)
        
        # plot mean line
        ax_summary.plot(
            epochs, mean,
            label=metric,
            color=s['color'],
            linestyle=s['linestyle'],
            linewidth=2
        )
        
        # plot shaded std band around mean
        ax_summary.fill_between(
            epochs,
            mean - std,
            mean + std,
            color=s['color'],
            alpha=0.15
        )
    
    ax_summary.set_title("Summary (mean ± std)")
    ax_summary.set_xlabel("Epoch")
    ax_summary.set_ylim(ylim)
    ax_summary.grid(True)
    ax_summary.legend()
    
    plt.suptitle("Ensemble Model — Loss per Fold", fontsize=14, y=1.02)
    plt.tight_layout()
    plt.show()


def save_ensemble(trained_models, save_dir=''):
    """
    Save all ensemble models and their normalisation parameters.
    trained_models: list of (model, Y_mean, Y_std) tuples
    """
    os.makedirs(save_dir, exist_ok=True)
    
    # Save each model separately
    norm_params = []
    for fold, (model, Y_mean, Y_std) in enumerate(trained_models):
        # Save model weights
        model_path = os.path.join(save_dir, f'model_fold_{fold+1}.keras')
        model.save(model_path)
        print(f"Saved fold {fold+1} model to {model_path}")
        
        # Collect normalisation parameters
        norm_params.append({
            'fold':   fold + 1,
            'Y_mean': float(Y_mean),
            'Y_std':  float(Y_std)
        })
    
    # Save normalisation parameters as a single JSON file
    norm_path = os.path.join(save_dir, 'norm_params.json')
    with open(norm_path, 'w') as f:
        json.dump(norm_params, f, indent=2)
    print(f"Saved normalisation parameters to {norm_path}")


def load_ensemble(save_dir=''):
    """
    Load all ensemble models and their normalisation parameters.
    Returns: list of (model, Y_mean, Y_std) tuples
    """
    # Load normalisation parameters
    norm_path = os.path.join(save_dir, 'norm_params.json')
    with open(norm_path, 'r') as f:
        norm_params = json.load(f)
    
    # Load each model
    trained_models = []
    for params in norm_params:
        fold      = params['fold']
        model_path = os.path.join(save_dir, f'model_fold_{fold}.keras')
        
        model  = tf.keras.models.load_model(model_path)
        Y_mean = params['Y_mean']
        Y_std  = params['Y_std']
        
        trained_models.append((model, Y_mean, Y_std))
        print(f"Loaded fold {fold} model from {model_path}")
    
    return trained_models

# %%
def train_ensembles(build_model_func, X, Y, N_SPLITS = 5, EPOCHS = 100, BATCH_SIZE = 256, random_state=42):

    kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=random_state)
    
    trained_models = []
    histories = []

    for fold, (idx_train, idx_val) in enumerate(kf.split(X)):
        
        print(f"\n--- Fold {fold+1}/{N_SPLITS} ---")
    
        # Clear session before each fold
        tf.keras.backend.clear_session()
    
        # ── Callbacks ─────────────────────────────────────────────────────────────────
        early_stop = callbacks.EarlyStopping(
        monitor='val_loss', patience=5, restore_best_weights=True
        )
        reduce_lr = callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1
        )
        
        # Split data using fold indices
        X_train, X_val = X[idx_train], X[idx_val]
        Y_train, Y_val = Y[idx_train], Y[idx_val]
        
        # Normalise Y using train statistics only
        #Y_mean, Y_std = Y_train.mean(), Y_train.std()
        Y_mean = 0
        Y_std = 3
        Y_train_norm = (Y_train - Y_mean) / Y_std
        Y_val_norm   = (Y_val   - Y_mean) / Y_std
        
        # Build fresh model for each fold
        model = build_model_func(input_shape=X_train.shape[1:])
        model.compile(optimizer='adam', loss='mse')
        
        # Train
        history = model.fit(
            X_train, Y_train_norm,
            validation_data=(X_val, Y_val_norm),
            epochs=EPOCHS,
            batch_size=BATCH_SIZE,
            callbacks=[early_stop, reduce_lr],
            verbose=2
        )
        
        trained_models.append((model, Y_mean, Y_std))  # save model + its normalisation
        histories.append(history)

    return trained_models, histories

# %%
# train on Y1 complete 
trained_models, histories = train_ensembles(build_model, X_y1, Y_y1)
# Out:
# --- Fold 1/5 ---
# 2026-08-20 08:31:57.674663: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38478 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:c1:00.0, compute capability: 8.0
# Epoch 1/100
# 2026-08-20 08:31:59.905807: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8903
# 2026-08-20 08:32:04.670858: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f8bb59a3c70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-08-20 08:32:04.670875: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A100-SXM4-40GB, Compute Capability 8.0
# 2026-08-20 08:32:04.696325: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1787239924.829464  562559 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 335/335 - 12s - loss: 0.3373 - val_loss: 0.1557 - lr: 0.0010 - 12s/epoch - 37ms/step
# Epoch 2/100
# 335/335 - 1s - loss: 0.1443 - val_loss: 0.0993 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 335/335 - 1s - loss: 0.1111 - val_loss: 0.0761 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 335/335 - 1s - loss: 0.0906 - val_loss: 0.0538 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 335/335 - 1s - loss: 0.0832 - val_loss: 0.0541 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
# 335/335 - 1s - loss: 0.0792 - val_loss: 0.0431 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
# 335/335 - 1s - loss: 0.0744 - val_loss: 0.0419 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/100
# 335/335 - 1s - loss: 0.0703 - val_loss: 0.0452 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 9/100
# 335/335 - 1s - loss: 0.0683 - val_loss: 0.0398 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 10/100
# 335/335 - 1s - loss: 0.0688 - val_loss: 0.0437 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 11/100
# 335/335 - 1s - loss: 0.0683 - val_loss: 0.0431 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 12/100
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 335/335 - 1s - loss: 0.0673 - val_loss: 0.0445 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 13/100
# 335/335 - 1s - loss: 0.0599 - val_loss: 0.0341 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 14/100
# 335/335 - 1s - loss: 0.0592 - val_loss: 0.0367 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 15/100
# 335/335 - 1s - loss: 0.0594 - val_loss: 0.0372 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 16/100
# 335/335 - 1s - loss: 0.0587 - val_loss: 0.0328 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 17/100
# 335/335 - 1s - loss: 0.0590 - val_loss: 0.0338 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 18/100
# 335/335 - 1s - loss: 0.0572 - val_loss: 0.0322 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 19/100
# 335/335 - 1s - loss: 0.0578 - val_loss: 0.0337 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 20/100
# 335/335 - 1s - loss: 0.0559 - val_loss: 0.0336 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 21/100
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 335/335 - 1s - loss: 0.0581 - val_loss: 0.0373 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 22/100
# 335/335 - 1s - loss: 0.0528 - val_loss: 0.0320 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 23/100
# 335/335 - 1s - loss: 0.0508 - val_loss: 0.0288 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 24/100
# 335/335 - 1s - loss: 0.0519 - val_loss: 0.0295 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 25/100
# 335/335 - 1s - loss: 0.0514 - val_loss: 0.0327 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 26/100
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 335/335 - 1s - loss: 0.0528 - val_loss: 0.0304 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 27/100
# 335/335 - 1s - loss: 0.0489 - val_loss: 0.0289 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 28/100
# 335/335 - 1s - loss: 0.0484 - val_loss: 0.0336 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
#
# --- Fold 2/5 ---
# Epoch 1/100
# 335/335 - 3s - loss: 0.3264 - val_loss: 0.1566 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 2/100
# 335/335 - 1s - loss: 0.1376 - val_loss: 0.1105 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 335/335 - 1s - loss: 0.1091 - val_loss: 0.0749 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 335/335 - 1s - loss: 0.0956 - val_loss: 0.0598 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 335/335 - 1s - loss: 0.0841 - val_loss: 0.0537 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
# 335/335 - 1s - loss: 0.0808 - val_loss: 0.0575 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
# 335/335 - 1s - loss: 0.0745 - val_loss: 0.0447 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/100
# 335/335 - 1s - loss: 0.0697 - val_loss: 0.0468 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 9/100
# 335/335 - 1s - loss: 0.0685 - val_loss: 0.0463 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 10/100
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 335/335 - 1s - loss: 0.0666 - val_loss: 0.0496 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 11/100
# 335/335 - 1s - loss: 0.0621 - val_loss: 0.0401 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 12/100
# 335/335 - 1s - loss: 0.0596 - val_loss: 0.0491 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 13/100
# 335/335 - 1s - loss: 0.0586 - val_loss: 0.0374 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 14/100
# 335/335 - 1s - loss: 0.0602 - val_loss: 0.0397 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 15/100
# 335/335 - 1s - loss: 0.0582 - val_loss: 0.0424 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 16/100
# 335/335 - 1s - loss: 0.0595 - val_loss: 0.0363 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 17/100
# 335/335 - 1s - loss: 0.0604 - val_loss: 0.0486 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 18/100
# 335/335 - 1s - loss: 0.0594 - val_loss: 0.0349 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 19/100
# 335/335 - 1s - loss: 0.0586 - val_loss: 0.0436 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 20/100
# 335/335 - 1s - loss: 0.0586 - val_loss: 0.0378 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 21/100
# 335/335 - 1s - loss: 0.0567 - val_loss: 0.0344 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 22/100
# 335/335 - 1s - loss: 0.0584 - val_loss: 0.0405 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 23/100
# 335/335 - 1s - loss: 0.0572 - val_loss: 0.0364 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 24/100
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 335/335 - 1s - loss: 0.0579 - val_loss: 0.0464 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 25/100
# 335/335 - 1s - loss: 0.0533 - val_loss: 0.0344 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 26/100
# 335/335 - 1s - loss: 0.0513 - val_loss: 0.0346 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 27/100
# 335/335 - 1s - loss: 0.0512 - val_loss: 0.0332 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 28/100
# 335/335 - 1s - loss: 0.0517 - val_loss: 0.0306 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 29/100
# 335/335 - 1s - loss: 0.0509 - val_loss: 0.0325 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 30/100
# 335/335 - 1s - loss: 0.0516 - val_loss: 0.0310 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 31/100
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 335/335 - 1s - loss: 0.0506 - val_loss: 0.0342 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 32/100
# 335/335 - 1s - loss: 0.0486 - val_loss: 0.0303 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 33/100
# 335/335 - 1s - loss: 0.0482 - val_loss: 0.0298 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 34/100
# 335/335 - 1s - loss: 0.0485 - val_loss: 0.0293 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 35/100
# 335/335 - 1s - loss: 0.0475 - val_loss: 0.0299 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 36/100
# 335/335 - 1s - loss: 0.0473 - val_loss: 0.0289 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 37/100
# 335/335 - 1s - loss: 0.0477 - val_loss: 0.0286 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 38/100
# 335/335 - 1s - loss: 0.0470 - val_loss: 0.0300 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 39/100
# 335/335 - 1s - loss: 0.0474 - val_loss: 0.0306 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 40/100
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 335/335 - 1s - loss: 0.0477 - val_loss: 0.0304 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 41/100
# 335/335 - 1s - loss: 0.0456 - val_loss: 0.0292 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 42/100
# 335/335 - 1s - loss: 0.0459 - val_loss: 0.0288 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
#
# --- Fold 3/5 ---
# Epoch 1/100
# 335/335 - 3s - loss: 0.3565 - val_loss: 0.1476 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 2/100
# 335/335 - 1s - loss: 0.1605 - val_loss: 0.1036 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 335/335 - 1s - loss: 0.1284 - val_loss: 0.0832 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 335/335 - 1s - loss: 0.1119 - val_loss: 0.0726 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 335/335 - 1s - loss: 0.0903 - val_loss: 0.0628 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
# 335/335 - 1s - loss: 0.0871 - val_loss: 0.0488 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
# 335/335 - 1s - loss: 0.0783 - val_loss: 0.0509 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/100
# 335/335 - 1s - loss: 0.0750 - val_loss: 0.0524 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 9/100
# 335/335 - 1s - loss: 0.0735 - val_loss: 0.0450 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 10/100
# 335/335 - 1s - loss: 0.0710 - val_loss: 0.0619 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 11/100
# 335/335 - 1s - loss: 0.0739 - val_loss: 0.0400 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 12/100
# 335/335 - 1s - loss: 0.0684 - val_loss: 0.0416 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 13/100
# 335/335 - 1s - loss: 0.0681 - val_loss: 0.0433 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 14/100
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 335/335 - 1s - loss: 0.0673 - val_loss: 0.0440 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 15/100
# 335/335 - 1s - loss: 0.0601 - val_loss: 0.0348 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 16/100
# 335/335 - 1s - loss: 0.0595 - val_loss: 0.0370 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 17/100
# 335/335 - 1s - loss: 0.0607 - val_loss: 0.0329 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 18/100
# 335/335 - 1s - loss: 0.0600 - val_loss: 0.0338 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 19/100
# 335/335 - 1s - loss: 0.0607 - val_loss: 0.0328 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 20/100
# 335/335 - 1s - loss: 0.0595 - val_loss: 0.0323 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 21/100
# 335/335 - 1s - loss: 0.0588 - val_loss: 0.0282 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 22/100
# 335/335 - 1s - loss: 0.0606 - val_loss: 0.0360 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 23/100
# 335/335 - 1s - loss: 0.0582 - val_loss: 0.0314 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 24/100
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 335/335 - 1s - loss: 0.0574 - val_loss: 0.0316 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 25/100
# 335/335 - 1s - loss: 0.0538 - val_loss: 0.0277 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 26/100
# 335/335 - 1s - loss: 0.0537 - val_loss: 0.0329 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 27/100
# 335/335 - 1s - loss: 0.0523 - val_loss: 0.0282 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 28/100
# 335/335 - 1s - loss: 0.0521 - val_loss: 0.0274 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 29/100
# 335/335 - 1s - loss: 0.0514 - val_loss: 0.0281 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 30/100
# 335/335 - 1s - loss: 0.0514 - val_loss: 0.0290 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 31/100
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 335/335 - 1s - loss: 0.0540 - val_loss: 0.0401 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 32/100
# 335/335 - 1s - loss: 0.0501 - val_loss: 0.0266 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 33/100
# 335/335 - 1s - loss: 0.0495 - val_loss: 0.0276 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 34/100
# 335/335 - 1s - loss: 0.0496 - val_loss: 0.0251 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 35/100
# 335/335 - 1s - loss: 0.0484 - val_loss: 0.0259 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 36/100
# 335/335 - 1s - loss: 0.0484 - val_loss: 0.0252 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 37/100
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 335/335 - 1s - loss: 0.0495 - val_loss: 0.0273 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 38/100
# 335/335 - 1s - loss: 0.0478 - val_loss: 0.0263 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 39/100
# 335/335 - 1s - loss: 0.0472 - val_loss: 0.0250 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 40/100
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 335/335 - 1s - loss: 0.0475 - val_loss: 0.0254 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 41/100
# 335/335 - 1s - loss: 0.0469 - val_loss: 0.0258 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 42/100
# 335/335 - 1s - loss: 0.0468 - val_loss: 0.0254 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 43/100
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 335/335 - 1s - loss: 0.0469 - val_loss: 0.0253 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 44/100
# 335/335 - 1s - loss: 0.0466 - val_loss: 0.0255 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
#
# --- Fold 4/5 ---
# Epoch 1/100
# 335/335 - 3s - loss: 0.3490 - val_loss: 0.1405 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 2/100
# 335/335 - 1s - loss: 0.1619 - val_loss: 0.1248 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 335/335 - 1s - loss: 0.1300 - val_loss: 0.0932 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 335/335 - 1s - loss: 0.1127 - val_loss: 0.0810 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 335/335 - 1s - loss: 0.0999 - val_loss: 0.0772 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
# 335/335 - 1s - loss: 0.0899 - val_loss: 0.0579 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
# 335/335 - 1s - loss: 0.0797 - val_loss: 0.0533 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/100
# 335/335 - 1s - loss: 0.0778 - val_loss: 0.0435 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 9/100
# 335/335 - 1s - loss: 0.0753 - val_loss: 0.0445 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 10/100
# 335/335 - 1s - loss: 0.0745 - val_loss: 0.0453 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 11/100
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 335/335 - 1s - loss: 0.0701 - val_loss: 0.0572 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 12/100
# 335/335 - 1s - loss: 0.0643 - val_loss: 0.0383 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 13/100
# 335/335 - 1s - loss: 0.0643 - val_loss: 0.0344 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 14/100
# 335/335 - 1s - loss: 0.0621 - val_loss: 0.0456 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 15/100
# 335/335 - 1s - loss: 0.0648 - val_loss: 0.0386 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 16/100
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 335/335 - 1s - loss: 0.0636 - val_loss: 0.0374 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 17/100
# 335/335 - 1s - loss: 0.0588 - val_loss: 0.0333 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 18/100
# 335/335 - 1s - loss: 0.0565 - val_loss: 0.0307 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 19/100
# 335/335 - 1s - loss: 0.0565 - val_loss: 0.0302 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 20/100
# 335/335 - 1s - loss: 0.0565 - val_loss: 0.0386 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 21/100
# 335/335 - 1s - loss: 0.0560 - val_loss: 0.0341 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 22/100
# 335/335 - 1s - loss: 0.0571 - val_loss: 0.0286 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 23/100
# 335/335 - 1s - loss: 0.0558 - val_loss: 0.0315 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 24/100
# 335/335 - 1s - loss: 0.0567 - val_loss: 0.0303 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 25/100
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 335/335 - 1s - loss: 0.0554 - val_loss: 0.0292 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 26/100
# 335/335 - 1s - loss: 0.0541 - val_loss: 0.0274 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 27/100
# 335/335 - 1s - loss: 0.0530 - val_loss: 0.0295 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 28/100
# 335/335 - 1s - loss: 0.0523 - val_loss: 0.0278 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 29/100
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 335/335 - 1s - loss: 0.0528 - val_loss: 0.0283 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 30/100
# 335/335 - 1s - loss: 0.0511 - val_loss: 0.0260 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 31/100
# 335/335 - 1s - loss: 0.0506 - val_loss: 0.0255 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 32/100
# 335/335 - 1s - loss: 0.0500 - val_loss: 0.0265 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 33/100
# 335/335 - 1s - loss: 0.0506 - val_loss: 0.0259 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 34/100
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 335/335 - 1s - loss: 0.0505 - val_loss: 0.0265 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 35/100
# 335/335 - 1s - loss: 0.0497 - val_loss: 0.0266 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 36/100
# 335/335 - 1s - loss: 0.0494 - val_loss: 0.0261 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
#
# --- Fold 5/5 ---
# Epoch 1/100
# 335/335 - 3s - loss: 0.3877 - val_loss: 0.1759 - lr: 0.0010 - 3s/epoch - 10ms/step
# Epoch 2/100
# 335/335 - 1s - loss: 0.1707 - val_loss: 0.1137 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 335/335 - 1s - loss: 0.1331 - val_loss: 0.0939 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 335/335 - 1s - loss: 0.1194 - val_loss: 0.1043 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 335/335 - 1s - loss: 0.1017 - val_loss: 0.0642 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
# 335/335 - 1s - loss: 0.0839 - val_loss: 0.0650 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
# 335/335 - 1s - loss: 0.0761 - val_loss: 0.0435 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/100
# 335/335 - 1s - loss: 0.0725 - val_loss: 0.0523 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 9/100
# 335/335 - 1s - loss: 0.0689 - val_loss: 0.0418 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 10/100
# 335/335 - 1s - loss: 0.0685 - val_loss: 0.0495 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 11/100
# 335/335 - 1s - loss: 0.0694 - val_loss: 0.0430 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 12/100
# 335/335 - 1s - loss: 0.0673 - val_loss: 0.0360 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 13/100
# 335/335 - 1s - loss: 0.0634 - val_loss: 0.0440 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 14/100
# 335/335 - 1s - loss: 0.0619 - val_loss: 0.0379 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 15/100
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 335/335 - 1s - loss: 0.0605 - val_loss: 0.0416 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 16/100
# 335/335 - 1s - loss: 0.0541 - val_loss: 0.0314 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 17/100
# 335/335 - 1s - loss: 0.0536 - val_loss: 0.0325 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 18/100
# 335/335 - 1s - loss: 0.0541 - val_loss: 0.0417 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 19/100
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 335/335 - 1s - loss: 0.0537 - val_loss: 0.0327 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 20/100
# 335/335 - 1s - loss: 0.0494 - val_loss: 0.0309 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 21/100
# 335/335 - 1s - loss: 0.0495 - val_loss: 0.0294 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 22/100
# 335/335 - 1s - loss: 0.0486 - val_loss: 0.0309 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 23/100
# 335/335 - 1s - loss: 0.0484 - val_loss: 0.0305 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 24/100
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 335/335 - 1s - loss: 0.0464 - val_loss: 0.0303 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 25/100
# 335/335 - 1s - loss: 0.0451 - val_loss: 0.0276 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 26/100
# 335/335 - 1s - loss: 0.0440 - val_loss: 0.0281 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 27/100
# 335/335 - 1s - loss: 0.0441 - val_loss: 0.0328 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 28/100
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 335/335 - 1s - loss: 0.0445 - val_loss: 0.0277 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 29/100
# 335/335 - 1s - loss: 0.0431 - val_loss: 0.0267 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 30/100
# 335/335 - 1s - loss: 0.0430 - val_loss: 0.0270 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 31/100
# 335/335 - 1s - loss: 0.0424 - val_loss: 0.0279 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 32/100
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 335/335 - 1s - loss: 0.0429 - val_loss: 0.0270 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 33/100
# 335/335 - 1s - loss: 0.0424 - val_loss: 0.0265 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 34/100
# 335/335 - 1s - loss: 0.0422 - val_loss: 0.0273 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 35/100
# 335/335 - 1s - loss: 0.0419 - val_loss: 0.0263 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 36/100
# 335/335 - 1s - loss: 0.0424 - val_loss: 0.0269 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 37/100
# 335/335 - 1s - loss: 0.0421 - val_loss: 0.0267 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 38/100
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 335/335 - 1s - loss: 0.0422 - val_loss: 0.0267 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 39/100
# 335/335 - 1s - loss: 0.0413 - val_loss: 0.0260 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 40/100
# 335/335 - 1s - loss: 0.0414 - val_loss: 0.0263 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 41/100
# 335/335 - 1s - loss: 0.0416 - val_loss: 0.0264 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 42/100
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 335/335 - 1s - loss: 0.0417 - val_loss: 0.0263 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 43/100
# 335/335 - 1s - loss: 0.0413 - val_loss: 0.0263 - lr: 7.8125e-06 - 1s/epoch - 4ms/step
# Epoch 44/100
# 335/335 - 1s - loss: 0.0412 - val_loss: 0.0263 - lr: 7.8125e-06 - 1s/epoch - 4ms/step

# %%
plot_ensemble_losses(histories, ylim=(0, 0.1))

# %%
# Final prediction on test set
y_pred_ensemble, y_pred_STD = ensemble_predict(trained_models, X_test_y1)
# Out:
# 3360/3360 [==============================] - 4s 1ms/step
# 3360/3360 [==============================] - 4s 1ms/step
# 3360/3360 [==============================] - 4s 1ms/step
# 3360/3360 [==============================] - 4s 1ms/step
# 3360/3360 [==============================] - 4s 1ms/step

# %%
# save the trained model:
root = "/pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models"
save_dir = root + "/y1_complete_ensemble_CNN_6layers"
save_ensemble(trained_models, save_dir=save_dir)
# Out:
# Saved fold 1 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y1_complete_ensemble_CNN_6layers/model_fold_1.keras
# Saved fold 2 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y1_complete_ensemble_CNN_6layers/model_fold_2.keras
# Saved fold 3 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y1_complete_ensemble_CNN_6layers/model_fold_3.keras
# Saved fold 4 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y1_complete_ensemble_CNN_6layers/model_fold_4.keras
# Saved fold 5 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y1_complete_ensemble_CNN_6layers/model_fold_5.keras
# Saved normalisation parameters to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y1_complete_ensemble_CNN_6layers/norm_params.json

# %%
redshift_bins = np.linspace(0,2.5,11)
imag_bins = np.linspace(18, 25.5,11)
#fname = save_dir + "/stats.pkl"
stats2, redshift_stats2, imag_stats2 = get_all_stats(Y_test_y1, y_pred_ensemble.flatten(), test_y1['mag_i_lsst'], save=False, 
                                                     redshift_bins = redshift_bins, imag_bins = imag_bins)

plot_stats(stats2, redshift_stats2, imag_stats2, Y_test_y1, y_pred_ensemble.flatten(), 
           redshift_bins, imag_bins, test_y1['mag_i_lsst'], save_path=save_dir + '/photoz_stats.png')
# Out:
# /global/common/software/nersc9/tensorflow/2.15.0/lib/python3.9/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /global/common/software/nersc9/tensorflow/2.15.0/lib/python3.9/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /global/common/software/nersc9/tensorflow/2.15.0/lib/python3.9/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /global/common/software/nersc9/tensorflow/2.15.0/lib/python3.9/site-packages/scipy/stats/_stats_py.py:3666: RuntimeWarning: Mean of empty slice.
#   c_mean = c.mean()
# /global/common/software/nersc9/tensorflow/2.15.0/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /global/common/software/nersc9/tensorflow/2.15.0/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /tmp/ipykernel_562300/2220381783.py:18: RuntimeWarning: invalid value encountered in scalar divide
#   outlier_rate = np.sum(np.abs(subset) > 3 * np.std(subset_clip)) / len(
# /tmp/ipykernel_562300/2220381783.py:21: RuntimeWarning: invalid value encountered in scalar divide
#   abs_outlier_rate = np.sum(np.abs(subset) > abs_out_thresh) / len(
# /tmp/ipykernel_562300/1952338895.py:98: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Plot saved to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y1_complete_ensemble_CNN_6layers/photoz_stats.png

# %%
# also plot the STD as a function of redshift and i-band magnitude:
fig,axarr=plt.subplots(1,3,figsize=[13,4])
plt.sca(axarr[0])
ind = y_pred_STD.flatten() >= 0.05
plt.scatter(Y_test_y1[~ind], y_pred_ensemble.flatten()[~ind], s=0.1, color='k')
plt.scatter(Y_test_y1[ind], y_pred_ensemble.flatten()[ind], s=0.5, color='r', label="STD_y > 0.05")
plt.xlabel("Truth redshift")
plt.ylabel("predicted redshift (mean)")
plt.legend()

plt.sca(axarr[1])
plt.scatter(Y_test_y1, y_pred_STD.flatten(), s=0.1, color='k')
plt.xlabel("Truth redshift")
plt.ylabel("predicted redshift (STD)")

plt.sca(axarr[2])
plt.scatter(test_y1['mag_i_lsst'], y_pred_STD.flatten(), s=0.1, color='k')
plt.xlabel("i magnitude")
plt.ylabel("predicted redshift (STD)")

plt.tight_layout()

# %%
# now let's train on the data with dropped bands:
trained_models, histories = train_ensembles(build_model, X_y1_misnir, Y_y1_misnir)
# Out:
# --- Fold 1/5 ---
# Epoch 1/100
# 335/335 - 3s - loss: 0.3426 - val_loss: 0.1691 - lr: 0.0010 - 3s/epoch - 10ms/step
# Epoch 2/100
# 335/335 - 1s - loss: 0.1608 - val_loss: 0.1066 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 335/335 - 1s - loss: 0.1355 - val_loss: 0.0990 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 335/335 - 1s - loss: 0.1208 - val_loss: 0.0912 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 335/335 - 1s - loss: 0.1105 - val_loss: 0.0828 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
# 335/335 - 1s - loss: 0.1045 - val_loss: 0.0730 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
# 335/335 - 1s - loss: 0.0968 - val_loss: 0.0729 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/100
# 335/335 - 1s - loss: 0.0950 - val_loss: 0.0633 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 9/100
# 335/335 - 1s - loss: 0.0925 - val_loss: 0.0757 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 10/100
# 335/335 - 1s - loss: 0.0917 - val_loss: 0.0628 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 11/100
# 335/335 - 1s - loss: 0.0869 - val_loss: 0.0775 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 12/100
# 335/335 - 1s - loss: 0.0866 - val_loss: 0.0543 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 13/100
# 335/335 - 1s - loss: 0.0831 - val_loss: 0.0532 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 14/100
# 335/335 - 1s - loss: 0.0829 - val_loss: 0.0488 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 15/100
# 335/335 - 1s - loss: 0.0815 - val_loss: 0.0520 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 16/100
# 335/335 - 1s - loss: 0.0818 - val_loss: 0.0576 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 17/100
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 335/335 - 1s - loss: 0.0788 - val_loss: 0.0530 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 18/100
# 335/335 - 1s - loss: 0.0716 - val_loss: 0.0446 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 19/100
# 335/335 - 1s - loss: 0.0706 - val_loss: 0.0440 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 20/100
# 335/335 - 1s - loss: 0.0721 - val_loss: 0.0467 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 21/100
# 335/335 - 1s - loss: 0.0692 - val_loss: 0.0444 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 22/100
# 335/335 - 1s - loss: 0.0693 - val_loss: 0.0427 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 23/100
# 335/335 - 1s - loss: 0.0687 - val_loss: 0.0447 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 24/100
# 335/335 - 1s - loss: 0.0708 - val_loss: 0.0426 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 25/100
# 335/335 - 1s - loss: 0.0678 - val_loss: 0.0408 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 26/100
# 335/335 - 1s - loss: 0.0703 - val_loss: 0.0447 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 27/100
# 335/335 - 1s - loss: 0.0692 - val_loss: 0.0488 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 28/100
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 335/335 - 1s - loss: 0.0679 - val_loss: 0.0456 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 29/100
# 335/335 - 1s - loss: 0.0642 - val_loss: 0.0414 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 30/100
# 335/335 - 1s - loss: 0.0634 - val_loss: 0.0402 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 31/100
# 335/335 - 1s - loss: 0.0630 - val_loss: 0.0423 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 32/100
# 335/335 - 1s - loss: 0.0620 - val_loss: 0.0413 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 33/100
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 335/335 - 1s - loss: 0.0638 - val_loss: 0.0443 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 34/100
# 335/335 - 1s - loss: 0.0612 - val_loss: 0.0391 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 35/100
# 335/335 - 1s - loss: 0.0596 - val_loss: 0.0396 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 36/100
# 335/335 - 1s - loss: 0.0605 - val_loss: 0.0412 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 37/100
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 335/335 - 1s - loss: 0.0588 - val_loss: 0.0392 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 38/100
# 335/335 - 1s - loss: 0.0584 - val_loss: 0.0381 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 39/100
# 335/335 - 1s - loss: 0.0579 - val_loss: 0.0383 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 40/100
# 335/335 - 1s - loss: 0.0579 - val_loss: 0.0373 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 41/100
# 335/335 - 1s - loss: 0.0581 - val_loss: 0.0387 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 42/100
# 335/335 - 1s - loss: 0.0578 - val_loss: 0.0380 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 43/100
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 335/335 - 1s - loss: 0.0579 - val_loss: 0.0382 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 44/100
# 335/335 - 1s - loss: 0.0569 - val_loss: 0.0374 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 45/100
# 335/335 - 1s - loss: 0.0574 - val_loss: 0.0376 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
#
# --- Fold 2/5 ---
# Epoch 1/100
# 335/335 - 3s - loss: 0.4225 - val_loss: 0.1866 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 2/100
# 335/335 - 1s - loss: 0.1629 - val_loss: 0.1527 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 335/335 - 1s - loss: 0.1381 - val_loss: 0.1068 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 335/335 - 1s - loss: 0.1213 - val_loss: 0.0930 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 335/335 - 1s - loss: 0.1070 - val_loss: 0.0785 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
# 335/335 - 1s - loss: 0.1034 - val_loss: 0.0759 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
# 335/335 - 1s - loss: 0.0945 - val_loss: 0.0666 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/100
# 335/335 - 1s - loss: 0.0931 - val_loss: 0.0649 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 9/100
# 335/335 - 1s - loss: 0.0900 - val_loss: 0.0747 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 10/100
# 335/335 - 1s - loss: 0.0889 - val_loss: 0.0630 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 11/100
# 335/335 - 1s - loss: 0.0873 - val_loss: 0.0671 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 12/100
# 335/335 - 1s - loss: 0.0875 - val_loss: 0.0576 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 13/100
# 335/335 - 1s - loss: 0.0858 - val_loss: 0.0735 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 14/100
# 335/335 - 1s - loss: 0.0825 - val_loss: 0.0697 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 15/100
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 335/335 - 1s - loss: 0.0812 - val_loss: 0.0618 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 16/100
# 335/335 - 1s - loss: 0.0729 - val_loss: 0.0584 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 17/100
# 335/335 - 1s - loss: 0.0727 - val_loss: 0.0557 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 18/100
# 335/335 - 1s - loss: 0.0702 - val_loss: 0.0506 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 19/100
# 335/335 - 1s - loss: 0.0711 - val_loss: 0.0574 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 20/100
# 335/335 - 1s - loss: 0.0702 - val_loss: 0.0520 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 21/100
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 335/335 - 1s - loss: 0.0693 - val_loss: 0.0510 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 22/100
# 335/335 - 1s - loss: 0.0656 - val_loss: 0.0485 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 23/100
# 335/335 - 1s - loss: 0.0642 - val_loss: 0.0485 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 24/100
# 335/335 - 1s - loss: 0.0644 - val_loss: 0.0485 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 25/100
# 335/335 - 1s - loss: 0.0649 - val_loss: 0.0482 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 26/100
# 335/335 - 1s - loss: 0.0639 - val_loss: 0.0479 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 27/100
# 335/335 - 1s - loss: 0.0639 - val_loss: 0.0456 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 28/100
# 335/335 - 1s - loss: 0.0631 - val_loss: 0.0492 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 29/100
# 335/335 - 1s - loss: 0.0643 - val_loss: 0.0481 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 30/100
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 335/335 - 1s - loss: 0.0635 - val_loss: 0.0475 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 31/100
# 335/335 - 1s - loss: 0.0615 - val_loss: 0.0463 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 32/100
# 335/335 - 1s - loss: 0.0610 - val_loss: 0.0463 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
#
# --- Fold 3/5 ---
# Epoch 1/100
# 335/335 - 3s - loss: 0.4032 - val_loss: 0.1652 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 2/100
# 335/335 - 1s - loss: 0.1860 - val_loss: 0.1866 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 335/335 - 1s - loss: 0.1602 - val_loss: 0.1126 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 335/335 - 1s - loss: 0.1449 - val_loss: 0.1069 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 335/335 - 1s - loss: 0.1323 - val_loss: 0.0905 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
# 335/335 - 1s - loss: 0.1207 - val_loss: 0.0764 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
# 335/335 - 1s - loss: 0.1119 - val_loss: 0.0745 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/100
# 335/335 - 1s - loss: 0.1076 - val_loss: 0.0670 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 9/100
# 335/335 - 1s - loss: 0.1023 - val_loss: 0.0685 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 10/100
# 335/335 - 1s - loss: 0.0977 - val_loss: 0.0670 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 11/100
# 335/335 - 1s - loss: 0.0967 - val_loss: 0.0621 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 12/100
# 335/335 - 1s - loss: 0.0942 - val_loss: 0.0654 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 13/100
# 335/335 - 1s - loss: 0.0920 - val_loss: 0.0667 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 14/100
# 335/335 - 1s - loss: 0.0909 - val_loss: 0.0511 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 15/100
# 335/335 - 1s - loss: 0.0881 - val_loss: 0.0579 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 16/100
# 335/335 - 1s - loss: 0.0878 - val_loss: 0.0560 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 17/100
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 335/335 - 1s - loss: 0.0871 - val_loss: 0.0540 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 18/100
# 335/335 - 1s - loss: 0.0795 - val_loss: 0.0509 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 19/100
# 335/335 - 1s - loss: 0.0762 - val_loss: 0.0526 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 20/100
# 335/335 - 1s - loss: 0.0770 - val_loss: 0.0472 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 21/100
# 335/335 - 1s - loss: 0.0762 - val_loss: 0.0492 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 22/100
# 335/335 - 1s - loss: 0.0754 - val_loss: 0.0437 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 23/100
# 335/335 - 1s - loss: 0.0767 - val_loss: 0.0464 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 24/100
# 335/335 - 1s - loss: 0.0739 - val_loss: 0.0530 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 25/100
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 335/335 - 1s - loss: 0.0754 - val_loss: 0.0469 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 26/100
# 335/335 - 1s - loss: 0.0692 - val_loss: 0.0436 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 27/100
# 335/335 - 1s - loss: 0.0700 - val_loss: 0.0405 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 28/100
# 335/335 - 1s - loss: 0.0672 - val_loss: 0.0403 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 29/100
# 335/335 - 1s - loss: 0.0681 - val_loss: 0.0403 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 30/100
# 335/335 - 1s - loss: 0.0684 - val_loss: 0.0415 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 31/100
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 335/335 - 1s - loss: 0.0697 - val_loss: 0.0416 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 32/100
# 335/335 - 1s - loss: 0.0660 - val_loss: 0.0389 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 33/100
# 335/335 - 1s - loss: 0.0651 - val_loss: 0.0411 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 34/100
# 335/335 - 1s - loss: 0.0642 - val_loss: 0.0417 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 35/100
# 335/335 - 1s - loss: 0.0637 - val_loss: 0.0385 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 36/100
# 335/335 - 1s - loss: 0.0651 - val_loss: 0.0403 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 37/100
# 335/335 - 1s - loss: 0.0642 - val_loss: 0.0390 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 38/100
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 335/335 - 1s - loss: 0.0639 - val_loss: 0.0396 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 39/100
# 335/335 - 1s - loss: 0.0630 - val_loss: 0.0404 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 40/100
# 335/335 - 1s - loss: 0.0623 - val_loss: 0.0387 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
#
# --- Fold 4/5 ---
# Epoch 1/100
# 335/335 - 3s - loss: 0.4056 - val_loss: 0.1863 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 2/100
# 335/335 - 1s - loss: 0.1804 - val_loss: 0.1349 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 335/335 - 1s - loss: 0.1579 - val_loss: 0.1395 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 335/335 - 1s - loss: 0.1423 - val_loss: 0.0980 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 335/335 - 1s - loss: 0.1229 - val_loss: 0.0773 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
# 335/335 - 1s - loss: 0.1121 - val_loss: 0.0716 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
# 335/335 - 1s - loss: 0.1016 - val_loss: 0.0700 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/100
# 335/335 - 1s - loss: 0.0984 - val_loss: 0.0681 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 9/100
# 335/335 - 1s - loss: 0.0931 - val_loss: 0.0625 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 10/100
# 335/335 - 1s - loss: 0.0934 - val_loss: 0.0674 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 11/100
# 335/335 - 1s - loss: 0.0904 - val_loss: 0.0744 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 12/100
# 335/335 - 1s - loss: 0.0893 - val_loss: 0.0621 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 13/100
# 335/335 - 1s - loss: 0.0869 - val_loss: 0.0580 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 14/100
# 335/335 - 1s - loss: 0.0874 - val_loss: 0.0616 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 15/100
# 335/335 - 1s - loss: 0.0854 - val_loss: 0.0584 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 16/100
# 335/335 - 1s - loss: 0.0831 - val_loss: 0.0549 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 17/100
# 335/335 - 1s - loss: 0.0832 - val_loss: 0.0649 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 18/100
# 335/335 - 1s - loss: 0.0817 - val_loss: 0.0581 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 19/100
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 335/335 - 1s - loss: 0.0837 - val_loss: 0.0674 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 20/100
# 335/335 - 1s - loss: 0.0751 - val_loss: 0.0518 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 21/100
# 335/335 - 1s - loss: 0.0721 - val_loss: 0.0457 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 22/100
# 335/335 - 1s - loss: 0.0724 - val_loss: 0.0508 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 23/100
# 335/335 - 1s - loss: 0.0716 - val_loss: 0.0483 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 24/100
# 335/335 - 1s - loss: 0.0718 - val_loss: 0.0447 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 25/100
# 335/335 - 1s - loss: 0.0738 - val_loss: 0.0464 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 26/100
# 335/335 - 1s - loss: 0.0721 - val_loss: 0.0484 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 27/100
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 335/335 - 1s - loss: 0.0696 - val_loss: 0.0476 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 28/100
# 335/335 - 1s - loss: 0.0662 - val_loss: 0.0432 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 29/100
# 335/335 - 1s - loss: 0.0661 - val_loss: 0.0432 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 30/100
# 335/335 - 1s - loss: 0.0658 - val_loss: 0.0412 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 31/100
# 335/335 - 1s - loss: 0.0660 - val_loss: 0.0410 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 32/100
# 335/335 - 1s - loss: 0.0646 - val_loss: 0.0418 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 33/100
# 335/335 - 1s - loss: 0.0666 - val_loss: 0.0447 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 34/100
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 335/335 - 1s - loss: 0.0648 - val_loss: 0.0444 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 35/100
# 335/335 - 1s - loss: 0.0626 - val_loss: 0.0413 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 36/100
# 335/335 - 1s - loss: 0.0619 - val_loss: 0.0402 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 37/100
# 335/335 - 1s - loss: 0.0620 - val_loss: 0.0393 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 38/100
# 335/335 - 1s - loss: 0.0616 - val_loss: 0.0397 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 39/100
# 335/335 - 1s - loss: 0.0609 - val_loss: 0.0390 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 40/100
# 335/335 - 1s - loss: 0.0608 - val_loss: 0.0392 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 41/100
# 335/335 - 1s - loss: 0.0604 - val_loss: 0.0395 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 42/100
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 335/335 - 1s - loss: 0.0611 - val_loss: 0.0397 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 43/100
# 335/335 - 1s - loss: 0.0600 - val_loss: 0.0387 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 44/100
# 335/335 - 1s - loss: 0.0594 - val_loss: 0.0381 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 45/100
# 335/335 - 1s - loss: 0.0597 - val_loss: 0.0389 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 46/100
# 335/335 - 1s - loss: 0.0598 - val_loss: 0.0385 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 47/100
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 335/335 - 1s - loss: 0.0593 - val_loss: 0.0388 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 48/100
# 335/335 - 1s - loss: 0.0579 - val_loss: 0.0387 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 49/100
# 335/335 - 1s - loss: 0.0577 - val_loss: 0.0381 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 50/100
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 335/335 - 1s - loss: 0.0578 - val_loss: 0.0385 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 51/100
# 335/335 - 1s - loss: 0.0574 - val_loss: 0.0380 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 52/100
# 335/335 - 1s - loss: 0.0570 - val_loss: 0.0380 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 53/100
# 335/335 - 1s - loss: 0.0576 - val_loss: 0.0376 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 54/100
# 335/335 - 1s - loss: 0.0573 - val_loss: 0.0377 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 55/100
# 335/335 - 1s - loss: 0.0573 - val_loss: 0.0377 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 56/100
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 335/335 - 1s - loss: 0.0573 - val_loss: 0.0376 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 57/100
# 335/335 - 1s - loss: 0.0572 - val_loss: 0.0376 - lr: 7.8125e-06 - 1s/epoch - 4ms/step
# Epoch 58/100
# 335/335 - 1s - loss: 0.0569 - val_loss: 0.0377 - lr: 7.8125e-06 - 1s/epoch - 4ms/step
#
# --- Fold 5/5 ---
# Epoch 1/100
# 335/335 - 3s - loss: 0.3383 - val_loss: 0.1686 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 2/100
# 335/335 - 1s - loss: 0.1565 - val_loss: 0.1061 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 335/335 - 1s - loss: 0.1325 - val_loss: 0.0949 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 335/335 - 1s - loss: 0.1148 - val_loss: 0.0776 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 335/335 - 1s - loss: 0.1074 - val_loss: 0.0695 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
# 335/335 - 1s - loss: 0.1017 - val_loss: 0.0681 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
# 335/335 - 1s - loss: 0.0969 - val_loss: 0.0694 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/100
# 335/335 - 1s - loss: 0.0910 - val_loss: 0.0626 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 9/100
# 335/335 - 1s - loss: 0.0880 - val_loss: 0.0770 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 10/100
# 335/335 - 1s - loss: 0.0849 - val_loss: 0.0669 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 11/100
# 335/335 - 1s - loss: 0.0846 - val_loss: 0.0566 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 12/100
# 335/335 - 1s - loss: 0.0824 - val_loss: 0.0537 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 13/100
# 335/335 - 1s - loss: 0.0803 - val_loss: 0.0530 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 14/100
# 335/335 - 1s - loss: 0.0799 - val_loss: 0.0543 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 15/100
# 335/335 - 1s - loss: 0.0803 - val_loss: 0.0521 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 16/100
# 335/335 - 1s - loss: 0.0767 - val_loss: 0.0509 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 17/100
# 335/335 - 1s - loss: 0.0756 - val_loss: 0.0557 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 18/100
# 335/335 - 1s - loss: 0.0733 - val_loss: 0.0577 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 19/100
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 335/335 - 1s - loss: 0.0737 - val_loss: 0.0604 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 20/100
# 335/335 - 1s - loss: 0.0681 - val_loss: 0.0445 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 21/100
# 335/335 - 1s - loss: 0.0657 - val_loss: 0.0447 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 22/100
# 335/335 - 1s - loss: 0.0670 - val_loss: 0.0448 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 23/100
# 335/335 - 1s - loss: 0.0655 - val_loss: 0.0432 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 24/100
# 335/335 - 1s - loss: 0.0655 - val_loss: 0.0513 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 25/100
# 335/335 - 1s - loss: 0.0668 - val_loss: 0.0473 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 26/100
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 335/335 - 1s - loss: 0.0659 - val_loss: 0.0471 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 27/100
# 335/335 - 1s - loss: 0.0618 - val_loss: 0.0422 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 28/100
# 335/335 - 1s - loss: 0.0610 - val_loss: 0.0427 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 29/100
# 335/335 - 1s - loss: 0.0610 - val_loss: 0.0455 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 30/100
# 335/335 - 1s - loss: 0.0602 - val_loss: 0.0413 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 31/100
# 335/335 - 1s - loss: 0.0601 - val_loss: 0.0438 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 32/100
# 335/335 - 1s - loss: 0.0609 - val_loss: 0.0446 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 33/100
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 335/335 - 1s - loss: 0.0600 - val_loss: 0.0414 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 34/100
# 335/335 - 1s - loss: 0.0578 - val_loss: 0.0408 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 35/100
# 335/335 - 1s - loss: 0.0573 - val_loss: 0.0414 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 36/100
# 335/335 - 1s - loss: 0.0573 - val_loss: 0.0397 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 37/100
# 335/335 - 1s - loss: 0.0570 - val_loss: 0.0413 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 38/100
# 335/335 - 1s - loss: 0.0570 - val_loss: 0.0416 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 39/100
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 335/335 - 1s - loss: 0.0579 - val_loss: 0.0423 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 40/100
# 335/335 - 1s - loss: 0.0558 - val_loss: 0.0394 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 41/100
# 335/335 - 1s - loss: 0.0557 - val_loss: 0.0401 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 42/100
# 335/335 - 1s - loss: 0.0554 - val_loss: 0.0390 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 43/100
# 335/335 - 1s - loss: 0.0553 - val_loss: 0.0397 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 44/100
# 335/335 - 1s - loss: 0.0553 - val_loss: 0.0407 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 45/100
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 335/335 - 1s - loss: 0.0553 - val_loss: 0.0396 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 46/100
# 335/335 - 1s - loss: 0.0546 - val_loss: 0.0397 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 47/100
# 335/335 - 1s - loss: 0.0545 - val_loss: 0.0391 - lr: 3.1250e-05 - 1s/epoch - 4ms/step

# %%
y_pred_ensemble_misnir, y_pred_STD_misnir = ensemble_predict(trained_models, X_test_y1_misnir)
# Out:
# 3360/3360 [==============================] - 4s 1ms/step
# 3360/3360 [==============================] - 4s 1ms/step
# 3360/3360 [==============================] - 4s 1ms/step
# 3360/3360 [==============================] - 4s 1ms/step
# 3360/3360 [==============================] - 4s 1ms/step

# %%
# save the trained model:
root = "/pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models"
save_dir = root + "/y1_misnir_ensemble_CNN_6layers"
save_ensemble(trained_models, save_dir=save_dir)
# Out:
# Saved fold 1 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y1_misnir_ensemble_CNN_6layers/model_fold_1.keras
# Saved fold 2 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y1_misnir_ensemble_CNN_6layers/model_fold_2.keras
# Saved fold 3 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y1_misnir_ensemble_CNN_6layers/model_fold_3.keras
# Saved fold 4 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y1_misnir_ensemble_CNN_6layers/model_fold_4.keras
# Saved fold 5 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y1_misnir_ensemble_CNN_6layers/model_fold_5.keras
# Saved normalisation parameters to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y1_misnir_ensemble_CNN_6layers/norm_params.json

# %%
redshift_bins = np.linspace(0,2.5,11)
imag_bins = np.linspace(18, 25.5,11)
#fname = save_dir + "/stats.pkl"
stats2, redshift_stats2, imag_stats2 = get_all_stats(Y_test_y1_misnir, y_pred_ensemble_misnir.flatten(), test_y1['mag_i_lsst'], save=False, 
                                                     redshift_bins = redshift_bins, imag_bins = imag_bins)

plot_stats(stats2, redshift_stats2, imag_stats2, Y_test_y1_misnir, y_pred_ensemble_misnir.flatten(), 
           redshift_bins, imag_bins, test_y1['mag_i_lsst'], save_path=save_dir + '/photoz_stats.png')
# Out:
# /global/common/software/nersc9/tensorflow/2.15.0/lib/python3.9/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /global/common/software/nersc9/tensorflow/2.15.0/lib/python3.9/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /global/common/software/nersc9/tensorflow/2.15.0/lib/python3.9/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /global/common/software/nersc9/tensorflow/2.15.0/lib/python3.9/site-packages/scipy/stats/_stats_py.py:3666: RuntimeWarning: Mean of empty slice.
#   c_mean = c.mean()
# /global/common/software/nersc9/tensorflow/2.15.0/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /global/common/software/nersc9/tensorflow/2.15.0/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /tmp/ipykernel_562300/2220381783.py:18: RuntimeWarning: invalid value encountered in scalar divide
#   outlier_rate = np.sum(np.abs(subset) > 3 * np.std(subset_clip)) / len(
# /tmp/ipykernel_562300/2220381783.py:21: RuntimeWarning: invalid value encountered in scalar divide
#   abs_outlier_rate = np.sum(np.abs(subset) > abs_out_thresh) / len(
# /tmp/ipykernel_562300/1952338895.py:98: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Plot saved to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y1_misnir_ensemble_CNN_6layers/photoz_stats.png

# %%
# let's apply the complete test data on the model trained with incomplete data
y_pred_ensemble2, y_pred_STD2= ensemble_predict(trained_models, X_test_y1)
# Out:
# 3360/3360 [==============================] - 4s 1ms/step
# 3360/3360 [==============================] - 4s 1ms/step
# 3360/3360 [==============================] - 4s 1ms/step
# 3360/3360 [==============================] - 4s 1ms/step
# 3360/3360 [==============================] - 4s 1ms/step

# %%
redshift_bins = np.linspace(0,2.5,11)
imag_bins = np.linspace(18, 25.5,11)
#fname = save_dir + "/stats.pkl"
stats2, redshift_stats2, imag_stats2 = get_all_stats(Y_test_y1, y_pred_ensemble2.flatten(), test_y1['mag_i_lsst'], save=False, 
                                                     redshift_bins = redshift_bins, imag_bins = imag_bins)

plot_stats(stats2, redshift_stats2, imag_stats2, Y_test_y1, y_pred_ensemble2.flatten(), 
           redshift_bins, imag_bins, test_y1['mag_i_lsst'], save_path=save_dir + '/photoz_stats.png')
# Out:
# /tmp/ipykernel_562300/2220381783.py:18: RuntimeWarning: invalid value encountered in scalar divide
#   outlier_rate = np.sum(np.abs(subset) > 3 * np.std(subset_clip)) / len(
# /tmp/ipykernel_562300/2220381783.py:21: RuntimeWarning: invalid value encountered in scalar divide
#   abs_outlier_rate = np.sum(np.abs(subset) > abs_out_thresh) / len(
# /tmp/ipykernel_562300/1952338895.py:98: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Plot saved to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y1_misnir_ensemble_CNN_6layers/photoz_stats.png

# %% [markdown]
# ## Cardinal Y10

# %%
trained_models, histories = train_ensembles(build_model, X_y10, Y_y10)
# Out:
# --- Fold 1/5 ---
# Epoch 1/100
# 323/323 - 4s - loss: 0.3003 - val_loss: 0.1409 - lr: 0.0010 - 4s/epoch - 12ms/step
# Epoch 2/100
# 323/323 - 1s - loss: 0.1427 - val_loss: 0.0980 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 323/323 - 1s - loss: 0.1267 - val_loss: 0.0879 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 323/323 - 1s - loss: 0.1173 - val_loss: 0.0791 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 323/323 - 1s - loss: 0.1107 - val_loss: 0.0778 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
# 323/323 - 1s - loss: 0.1062 - val_loss: 0.0816 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
# 323/323 - 1s - loss: 0.1029 - val_loss: 0.0814 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/100
# 323/323 - 1s - loss: 0.1018 - val_loss: 0.0709 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 9/100
# 323/323 - 1s - loss: 0.0984 - val_loss: 0.0754 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 10/100
# 323/323 - 1s - loss: 0.0988 - val_loss: 0.0702 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 11/100
# 323/323 - 1s - loss: 0.0966 - val_loss: 0.0723 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 12/100
# 323/323 - 1s - loss: 0.0951 - val_loss: 0.0716 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 13/100
# 323/323 - 1s - loss: 0.0920 - val_loss: 0.0653 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 14/100
# 323/323 - 1s - loss: 0.0892 - val_loss: 0.0630 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 15/100
# 323/323 - 1s - loss: 0.0895 - val_loss: 0.0602 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 16/100
# 323/323 - 1s - loss: 0.0891 - val_loss: 0.0720 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 17/100
# 323/323 - 1s - loss: 0.0879 - val_loss: 0.0658 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 18/100
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 323/323 - 1s - loss: 0.0858 - val_loss: 0.0659 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 19/100
# 323/323 - 1s - loss: 0.0798 - val_loss: 0.0581 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 20/100
# 323/323 - 1s - loss: 0.0787 - val_loss: 0.0574 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 21/100
# 323/323 - 1s - loss: 0.0785 - val_loss: 0.0591 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 22/100
# 323/323 - 1s - loss: 0.0781 - val_loss: 0.0587 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 23/100
# 323/323 - 1s - loss: 0.0781 - val_loss: 0.0549 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 24/100
# 323/323 - 1s - loss: 0.0761 - val_loss: 0.0555 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 25/100
# 323/323 - 1s - loss: 0.0772 - val_loss: 0.0552 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 26/100
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 323/323 - 1s - loss: 0.0774 - val_loss: 0.0667 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 27/100
# 323/323 - 1s - loss: 0.0731 - val_loss: 0.0520 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 28/100
# 323/323 - 1s - loss: 0.0729 - val_loss: 0.0512 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 29/100
# 323/323 - 1s - loss: 0.0717 - val_loss: 0.0525 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 30/100
# 323/323 - 1s - loss: 0.0712 - val_loss: 0.0508 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 31/100
# 323/323 - 1s - loss: 0.0712 - val_loss: 0.0525 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 32/100
# 323/323 - 1s - loss: 0.0709 - val_loss: 0.0510 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 33/100
# 323/323 - 1s - loss: 0.0706 - val_loss: 0.0504 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 34/100
# 323/323 - 1s - loss: 0.0706 - val_loss: 0.0536 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 35/100
# 323/323 - 1s - loss: 0.0699 - val_loss: 0.0516 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 36/100
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 323/323 - 1s - loss: 0.0696 - val_loss: 0.0527 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 37/100
# 323/323 - 1s - loss: 0.0671 - val_loss: 0.0502 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 38/100
# 323/323 - 1s - loss: 0.0666 - val_loss: 0.0508 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 39/100
# 323/323 - 1s - loss: 0.0661 - val_loss: 0.0497 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 40/100
# 323/323 - 1s - loss: 0.0659 - val_loss: 0.0512 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 41/100
# 323/323 - 1s - loss: 0.0655 - val_loss: 0.0509 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 42/100
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 323/323 - 1s - loss: 0.0656 - val_loss: 0.0507 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 43/100
# 323/323 - 1s - loss: 0.0646 - val_loss: 0.0502 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 44/100
# 323/323 - 1s - loss: 0.0640 - val_loss: 0.0505 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
#
# --- Fold 2/5 ---
# Epoch 1/100
# 323/323 - 3s - loss: 0.3069 - val_loss: 0.1799 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 2/100
# 323/323 - 1s - loss: 0.1407 - val_loss: 0.1057 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 323/323 - 1s - loss: 0.1225 - val_loss: 0.0911 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 323/323 - 1s - loss: 0.1123 - val_loss: 0.0864 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 323/323 - 1s - loss: 0.1073 - val_loss: 0.1087 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
# 323/323 - 1s - loss: 0.1050 - val_loss: 0.0761 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
# 323/323 - 1s - loss: 0.0990 - val_loss: 0.0718 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/100
# 323/323 - 1s - loss: 0.0987 - val_loss: 0.0944 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 9/100
# 323/323 - 1s - loss: 0.0955 - val_loss: 0.0747 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 10/100
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 323/323 - 1s - loss: 0.0944 - val_loss: 0.0900 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 11/100
# 323/323 - 1s - loss: 0.0865 - val_loss: 0.0652 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 12/100
# 323/323 - 1s - loss: 0.0863 - val_loss: 0.0679 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 13/100
# 323/323 - 1s - loss: 0.0849 - val_loss: 0.0669 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 14/100
# 323/323 - 1s - loss: 0.0854 - val_loss: 0.0624 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 15/100
# 323/323 - 1s - loss: 0.0847 - val_loss: 0.0663 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 16/100
# 323/323 - 1s - loss: 0.0842 - val_loss: 0.0632 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 17/100
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 323/323 - 1s - loss: 0.0835 - val_loss: 0.0661 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 18/100
# 323/323 - 1s - loss: 0.0785 - val_loss: 0.0587 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 19/100
# 323/323 - 1s - loss: 0.0787 - val_loss: 0.0600 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 20/100
# 323/323 - 1s - loss: 0.0789 - val_loss: 0.0578 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 21/100
# 323/323 - 1s - loss: 0.0771 - val_loss: 0.0576 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 22/100
# 323/323 - 1s - loss: 0.0765 - val_loss: 0.0562 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 23/100
# 323/323 - 1s - loss: 0.0761 - val_loss: 0.0564 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 24/100
# 323/323 - 1s - loss: 0.0755 - val_loss: 0.0603 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 25/100
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 323/323 - 1s - loss: 0.0745 - val_loss: 0.0568 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 26/100
# 323/323 - 1s - loss: 0.0726 - val_loss: 0.0557 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 27/100
# 323/323 - 1s - loss: 0.0718 - val_loss: 0.0550 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 28/100
# 323/323 - 1s - loss: 0.0713 - val_loss: 0.0543 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 29/100
# 323/323 - 1s - loss: 0.0722 - val_loss: 0.0545 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 30/100
# 323/323 - 1s - loss: 0.0708 - val_loss: 0.0540 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 31/100
# 323/323 - 1s - loss: 0.0700 - val_loss: 0.0551 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 32/100
# 323/323 - 1s - loss: 0.0708 - val_loss: 0.0551 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 33/100
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 323/323 - 1s - loss: 0.0710 - val_loss: 0.0552 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 34/100
# 323/323 - 1s - loss: 0.0690 - val_loss: 0.0548 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 35/100
# 323/323 - 1s - loss: 0.0690 - val_loss: 0.0553 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
#
# --- Fold 3/5 ---
# Epoch 1/100
# 323/323 - 3s - loss: 0.2906 - val_loss: 0.1361 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 2/100
# 323/323 - 1s - loss: 0.1325 - val_loss: 0.1119 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 323/323 - 1s - loss: 0.1181 - val_loss: 0.0943 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 323/323 - 1s - loss: 0.1106 - val_loss: 0.0942 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 323/323 - 1s - loss: 0.1031 - val_loss: 0.0822 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
# 323/323 - 1s - loss: 0.1000 - val_loss: 0.0838 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
# 323/323 - 1s - loss: 0.0964 - val_loss: 0.0875 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/100
# 323/323 - 1s - loss: 0.0964 - val_loss: 0.0716 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 9/100
# 323/323 - 1s - loss: 0.0935 - val_loss: 0.0708 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 10/100
# 323/323 - 1s - loss: 0.0908 - val_loss: 0.0681 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 11/100
# 323/323 - 1s - loss: 0.0880 - val_loss: 0.0698 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 12/100
# 323/323 - 1s - loss: 0.0871 - val_loss: 0.0723 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 13/100
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 323/323 - 1s - loss: 0.0884 - val_loss: 0.0696 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 14/100
# 323/323 - 1s - loss: 0.0792 - val_loss: 0.0641 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 15/100
# 323/323 - 1s - loss: 0.0783 - val_loss: 0.0619 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 16/100
# 323/323 - 1s - loss: 0.0786 - val_loss: 0.0603 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 17/100
# 323/323 - 1s - loss: 0.0763 - val_loss: 0.0649 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 18/100
# 323/323 - 1s - loss: 0.0767 - val_loss: 0.0611 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 19/100
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 323/323 - 1s - loss: 0.0780 - val_loss: 0.0609 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 20/100
# 323/323 - 1s - loss: 0.0724 - val_loss: 0.0571 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 21/100
# 323/323 - 1s - loss: 0.0714 - val_loss: 0.0577 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 22/100
# 323/323 - 1s - loss: 0.0712 - val_loss: 0.0560 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 23/100
# 323/323 - 1s - loss: 0.0720 - val_loss: 0.0597 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 24/100
# 323/323 - 1s - loss: 0.0708 - val_loss: 0.0564 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 25/100
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 323/323 - 1s - loss: 0.0709 - val_loss: 0.0575 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 26/100
# 323/323 - 1s - loss: 0.0677 - val_loss: 0.0550 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 27/100
# 323/323 - 1s - loss: 0.0677 - val_loss: 0.0548 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 28/100
# 323/323 - 1s - loss: 0.0671 - val_loss: 0.0555 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 29/100
# 323/323 - 1s - loss: 0.0669 - val_loss: 0.0545 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 30/100
# 323/323 - 1s - loss: 0.0668 - val_loss: 0.0546 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 31/100
# 323/323 - 1s - loss: 0.0665 - val_loss: 0.0561 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 32/100
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 323/323 - 1s - loss: 0.0661 - val_loss: 0.0555 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 33/100
# 323/323 - 1s - loss: 0.0648 - val_loss: 0.0546 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 34/100
# 323/323 - 1s - loss: 0.0650 - val_loss: 0.0547 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
#
# --- Fold 4/5 ---
# Epoch 1/100
# 323/323 - 3s - loss: 0.3409 - val_loss: 0.1356 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 2/100
# 323/323 - 1s - loss: 0.1630 - val_loss: 0.1361 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 323/323 - 1s - loss: 0.1389 - val_loss: 0.0934 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 323/323 - 1s - loss: 0.1256 - val_loss: 0.0870 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 323/323 - 1s - loss: 0.1193 - val_loss: 0.0943 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
# 323/323 - 1s - loss: 0.1172 - val_loss: 0.0817 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
# 323/323 - 1s - loss: 0.1137 - val_loss: 0.0802 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/100
# 323/323 - 1s - loss: 0.1110 - val_loss: 0.0797 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 9/100
# 323/323 - 1s - loss: 0.1077 - val_loss: 0.0773 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 10/100
# 323/323 - 1s - loss: 0.1067 - val_loss: 0.0790 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 11/100
# 323/323 - 1s - loss: 0.1045 - val_loss: 0.0732 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 12/100
# 323/323 - 1s - loss: 0.0993 - val_loss: 0.0792 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 13/100
# 323/323 - 1s - loss: 0.0997 - val_loss: 0.0753 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 14/100
# 323/323 - 1s - loss: 0.0985 - val_loss: 0.0677 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 15/100
# 323/323 - 1s - loss: 0.0945 - val_loss: 0.0705 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 16/100
# 323/323 - 1s - loss: 0.0952 - val_loss: 0.0721 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 17/100
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 323/323 - 1s - loss: 0.0942 - val_loss: 0.0758 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 18/100
# 323/323 - 1s - loss: 0.0879 - val_loss: 0.0626 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 19/100
# 323/323 - 1s - loss: 0.0866 - val_loss: 0.0639 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 20/100
# 323/323 - 1s - loss: 0.0865 - val_loss: 0.0667 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 21/100
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 323/323 - 1s - loss: 0.0851 - val_loss: 0.0630 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 22/100
# 323/323 - 1s - loss: 0.0814 - val_loss: 0.0619 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 23/100
# 323/323 - 1s - loss: 0.0807 - val_loss: 0.0622 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 24/100
# 323/323 - 1s - loss: 0.0805 - val_loss: 0.0595 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 25/100
# 323/323 - 1s - loss: 0.0802 - val_loss: 0.0621 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 26/100
# 323/323 - 1s - loss: 0.0798 - val_loss: 0.0593 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 27/100
# 323/323 - 1s - loss: 0.0791 - val_loss: 0.0595 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 28/100
# 323/323 - 1s - loss: 0.0794 - val_loss: 0.0586 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 29/100
# 323/323 - 1s - loss: 0.0794 - val_loss: 0.0576 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 30/100
# 323/323 - 1s - loss: 0.0790 - val_loss: 0.0597 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 31/100
# 323/323 - 1s - loss: 0.0781 - val_loss: 0.0612 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 32/100
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 323/323 - 1s - loss: 0.0780 - val_loss: 0.0580 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 33/100
# 323/323 - 1s - loss: 0.0754 - val_loss: 0.0568 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 34/100
# 323/323 - 1s - loss: 0.0752 - val_loss: 0.0576 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 35/100
# 323/323 - 1s - loss: 0.0750 - val_loss: 0.0575 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 36/100
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 323/323 - 1s - loss: 0.0742 - val_loss: 0.0569 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 37/100
# 323/323 - 1s - loss: 0.0731 - val_loss: 0.0576 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 38/100
# 323/323 - 1s - loss: 0.0733 - val_loss: 0.0582 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
#
# --- Fold 5/5 ---
# Epoch 1/100
# 323/323 - 3s - loss: 0.2752 - val_loss: 0.1142 - lr: 0.0010 - 3s/epoch - 11ms/step
# Epoch 2/100
# 323/323 - 1s - loss: 0.1388 - val_loss: 0.0991 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 323/323 - 1s - loss: 0.1241 - val_loss: 0.0843 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 323/323 - 1s - loss: 0.1128 - val_loss: 0.0798 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 323/323 - 1s - loss: 0.1078 - val_loss: 0.0773 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
# 323/323 - 1s - loss: 0.1037 - val_loss: 0.0699 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
# 323/323 - 1s - loss: 0.1015 - val_loss: 0.0740 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/100
# 323/323 - 1s - loss: 0.0982 - val_loss: 0.0703 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 9/100
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 323/323 - 1s - loss: 0.0976 - val_loss: 0.0715 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 10/100
# 323/323 - 1s - loss: 0.0888 - val_loss: 0.0670 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 11/100
# 323/323 - 1s - loss: 0.0874 - val_loss: 0.0627 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 12/100
# 323/323 - 1s - loss: 0.0878 - val_loss: 0.0597 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 13/100
# 323/323 - 1s - loss: 0.0869 - val_loss: 0.0627 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 14/100
# 323/323 - 1s - loss: 0.0857 - val_loss: 0.0651 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 15/100
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 323/323 - 1s - loss: 0.0851 - val_loss: 0.0609 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 16/100
# 323/323 - 1s - loss: 0.0807 - val_loss: 0.0564 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 17/100
# 323/323 - 1s - loss: 0.0801 - val_loss: 0.0611 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 18/100
# 323/323 - 1s - loss: 0.0791 - val_loss: 0.0595 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 19/100
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 323/323 - 1s - loss: 0.0800 - val_loss: 0.0572 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 20/100
# 323/323 - 1s - loss: 0.0774 - val_loss: 0.0554 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 21/100
# 323/323 - 1s - loss: 0.0769 - val_loss: 0.0556 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 22/100
# 323/323 - 1s - loss: 0.0756 - val_loss: 0.0558 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 23/100
# 323/323 - 1s - loss: 0.0746 - val_loss: 0.0551 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 24/100
# 323/323 - 1s - loss: 0.0756 - val_loss: 0.0550 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 25/100
# 323/323 - 1s - loss: 0.0757 - val_loss: 0.0547 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 26/100
# 323/323 - 1s - loss: 0.0745 - val_loss: 0.0538 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 27/100
# 323/323 - 1s - loss: 0.0741 - val_loss: 0.0549 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 28/100
# 323/323 - 1s - loss: 0.0751 - val_loss: 0.0544 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 29/100
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 323/323 - 1s - loss: 0.0739 - val_loss: 0.0559 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 30/100
# 323/323 - 1s - loss: 0.0729 - val_loss: 0.0537 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 31/100
# 323/323 - 1s - loss: 0.0720 - val_loss: 0.0538 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 32/100
# 323/323 - 1s - loss: 0.0720 - val_loss: 0.0550 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 33/100
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 323/323 - 1s - loss: 0.0722 - val_loss: 0.0545 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 34/100
# 323/323 - 1s - loss: 0.0712 - val_loss: 0.0535 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 35/100
# 323/323 - 1s - loss: 0.0712 - val_loss: 0.0538 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 36/100
# 323/323 - 1s - loss: 0.0708 - val_loss: 0.0536 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 37/100
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 323/323 - 1s - loss: 0.0709 - val_loss: 0.0539 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 38/100
# 323/323 - 1s - loss: 0.0698 - val_loss: 0.0538 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 39/100
# 323/323 - 1s - loss: 0.0704 - val_loss: 0.0533 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 40/100
# 323/323 - 1s - loss: 0.0699 - val_loss: 0.0539 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 41/100
# 323/323 - 1s - loss: 0.0697 - val_loss: 0.0536 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 42/100
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 323/323 - 1s - loss: 0.0702 - val_loss: 0.0535 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 43/100
# 323/323 - 1s - loss: 0.0699 - val_loss: 0.0536 - lr: 7.8125e-06 - 1s/epoch - 4ms/step
# Epoch 44/100
# 323/323 - 1s - loss: 0.0699 - val_loss: 0.0537 - lr: 7.8125e-06 - 1s/epoch - 4ms/step

# %%
plot_ensemble_losses(histories, ylim=(0, 0.2))

# %%
y_pred_ensemble, y_pred_STD = ensemble_predict(trained_models, X_test_y10)
# Out:
# 3229/3229 [==============================] - 4s 1ms/step
# 3229/3229 [==============================] - 4s 1ms/step
# 3229/3229 [==============================] - 4s 1ms/step
# 3229/3229 [==============================] - 4s 1ms/step
# 3229/3229 [==============================] - 4s 1ms/step

# %%
# save the trained model:
root = "/pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models"
save_dir = root + "/y10_complete_ensemble_CNN_6layers"
save_ensemble(trained_models, save_dir=save_dir)
# Out:
# Saved fold 1 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y10_complete_ensemble_CNN_6layers/model_fold_1.keras
# Saved fold 2 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y10_complete_ensemble_CNN_6layers/model_fold_2.keras
# Saved fold 3 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y10_complete_ensemble_CNN_6layers/model_fold_3.keras
# Saved fold 4 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y10_complete_ensemble_CNN_6layers/model_fold_4.keras
# Saved fold 5 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y10_complete_ensemble_CNN_6layers/model_fold_5.keras
# Saved normalisation parameters to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y10_complete_ensemble_CNN_6layers/norm_params.json

# %%
redshift_bins = np.linspace(0,2.5,11)
imag_bins = np.linspace(18, 25.5,11)
#fname = save_dir + "/stats.pkl"
stats2, redshift_stats2, imag_stats2 = get_all_stats(Y_test_y10, y_pred_ensemble.flatten(), test_y10['mag_i_lsst'], save=False, 
                                                     redshift_bins = redshift_bins, imag_bins = imag_bins)

plot_stats(stats2, redshift_stats2, imag_stats2, Y_test_y10, y_pred_ensemble.flatten(), 
           redshift_bins, imag_bins, test_y10['mag_i_lsst'], save_path=save_dir + '/photoz_stats.png')
# Out:
# /tmp/ipykernel_562300/1952338895.py:98: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Plot saved to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y10_complete_ensemble_CNN_6layers/photoz_stats.png

# %%
# also plot the STD as a function of redshift and i-band magnitude:
fig,axarr=plt.subplots(1,3,figsize=[13,4])
plt.sca(axarr[0])
ind = y_pred_STD.flatten() >= 0.05
plt.scatter(Y_test_y10[~ind], y_pred_ensemble.flatten()[~ind], s=0.1, color='k')
plt.scatter(Y_test_y10[ind], y_pred_ensemble.flatten()[ind], s=0.5, color='r', label="STD_y > 0.05")
plt.xlabel("Truth redshift")
plt.ylabel("predicted redshift (mean)")
plt.legend()

plt.sca(axarr[1])
plt.scatter(Y_test_y10, y_pred_STD.flatten(), s=0.1, color='k')
plt.xlabel("Truth redshift")
plt.ylabel("predicted redshift (STD)")

plt.sca(axarr[2])
plt.scatter(test_y10['mag_i_lsst'], y_pred_STD.flatten(), s=0.1, color='k')
plt.xlabel("i magnitude")
plt.ylabel("predicted redshift (STD)")

plt.tight_layout()

# %%
# try applying this model to the specsel data: is this consistent?
root = "/pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models"
save_dir = root + "/y10_complete_ensemble_CNN_6layers"
trained_models = load_ensemble(save_dir=save_dir)
# Out:
# 2026-08-21 03:44:02.932742: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38478 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:82:00.0, compute capability: 8.0
# Loaded fold 1 model from /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y10_complete_ensemble_CNN_6layers/model_fold_1.keras
# Loaded fold 2 model from /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y10_complete_ensemble_CNN_6layers/model_fold_2.keras
# Loaded fold 3 model from /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y10_complete_ensemble_CNN_6layers/model_fold_3.keras
# Loaded fold 4 model from /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y10_complete_ensemble_CNN_6layers/model_fold_4.keras
# Loaded fold 5 model from /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y10_complete_ensemble_CNN_6layers/model_fold_5.keras

# %%
saveroot = "/pscratch/sd/q/qhang/cnnpz/cardinal/"
training_y10_spec = pd.read_parquet(saveroot + "train_100k_noisy_y10_i25.4.SpecSelect.parquet")
# change the name of the roman columns:
training_y10_spec = training_y10_spec.rename(columns={'Roman_obs_J129': 'mag_J_roman', 
                                              'Roman_obs_H158': 'mag_H_roman'})

X_y10_spec, Y_y10_spec = transform_data_to_XY(training_y10_spec)
y_pred_ensemble_spec, y_pred_STD_spec = ensemble_predict(trained_models, X_y10_spec)
# Out:
# 2026-08-21 03:48:19.299102: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8903
# 3125/3125 [==============================] - 5s 1ms/step
# 3125/3125 [==============================] - 3s 1ms/step
# 3125/3125 [==============================] - 3s 1ms/step
# 3125/3125 [==============================] - 3s 1ms/step
# 3125/3125 [==============================] - 3s 1ms/step

# %%
redshift_bins = np.linspace(0,2.5,11)
imag_bins = np.linspace(18, 25.5,11)
#fname = save_dir + "/stats.pkl"
stats2, redshift_stats2, imag_stats2 = get_all_stats(Y_y10_spec, y_pred_ensemble_spec.flatten(), 
                                                     training_y10_spec['mag_i_lsst'], save=False, 
                                                     redshift_bins = redshift_bins, imag_bins = imag_bins)

plot_stats(stats2, redshift_stats2, imag_stats2, Y_y10_spec, y_pred_ensemble_spec.flatten(), 
           redshift_bins, imag_bins, training_y10_spec['mag_i_lsst'], save_path=save_dir + '/photoz_stats.png')
# Out:
# /global/common/software/nersc9/tensorflow/2.15.0/lib/python3.9/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /global/common/software/nersc9/tensorflow/2.15.0/lib/python3.9/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /global/common/software/nersc9/tensorflow/2.15.0/lib/python3.9/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /global/common/software/nersc9/tensorflow/2.15.0/lib/python3.9/site-packages/scipy/stats/_stats_py.py:3666: RuntimeWarning: Mean of empty slice.
#   c_mean = c.mean()
# /global/common/software/nersc9/tensorflow/2.15.0/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /global/common/software/nersc9/tensorflow/2.15.0/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /tmp/ipykernel_1275168/2220381783.py:18: RuntimeWarning: invalid value encountered in scalar divide
#   outlier_rate = np.sum(np.abs(subset) > 3 * np.std(subset_clip)) / len(
# /tmp/ipykernel_1275168/2220381783.py:21: RuntimeWarning: invalid value encountered in scalar divide
#   abs_outlier_rate = np.sum(np.abs(subset) > abs_out_thresh) / len(
# /tmp/ipykernel_1275168/1952338895.py:98: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Plot saved to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y10_complete_ensemble_CNN_6layers/photoz_stats.png

# %% [markdown]
# This works well on the spec selected sample!

# %% [markdown]
# ## dropping nir data

# %%
trained_models, histories = train_ensembles(build_model, X_y10_misnir, Y_y10_misnir)
# Out:
# --- Fold 1/5 ---
# Epoch 1/100
# 323/323 - 3s - loss: 0.4370 - val_loss: 0.2732 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 2/100
# 323/323 - 1s - loss: 0.2642 - val_loss: 0.2231 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 323/323 - 1s - loss: 0.2498 - val_loss: 0.2351 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 323/323 - 1s - loss: 0.2349 - val_loss: 0.2176 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 323/323 - 1s - loss: 0.2302 - val_loss: 0.1960 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
# 323/323 - 1s - loss: 0.2274 - val_loss: 0.1955 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
# 323/323 - 1s - loss: 0.2175 - val_loss: 0.2028 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/100
# 323/323 - 1s - loss: 0.2190 - val_loss: 0.1913 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 9/100
# 323/323 - 1s - loss: 0.2123 - val_loss: 0.1889 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 10/100
# 323/323 - 1s - loss: 0.2102 - val_loss: 0.2024 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 11/100
# 323/323 - 1s - loss: 0.2066 - val_loss: 0.1828 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 12/100
# 323/323 - 1s - loss: 0.2069 - val_loss: 0.1865 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 13/100
# 323/323 - 1s - loss: 0.2057 - val_loss: 0.1804 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 14/100
# 323/323 - 1s - loss: 0.1993 - val_loss: 0.1809 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 15/100
# 323/323 - 1s - loss: 0.2003 - val_loss: 0.1778 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 16/100
# 323/323 - 1s - loss: 0.1958 - val_loss: 0.1708 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 17/100
# 323/323 - 1s - loss: 0.1982 - val_loss: 0.1780 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 18/100
# 323/323 - 1s - loss: 0.1932 - val_loss: 0.1733 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 19/100
# 323/323 - 1s - loss: 0.1938 - val_loss: 0.1687 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 20/100
# 323/323 - 1s - loss: 0.1911 - val_loss: 0.1736 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 21/100
# 323/323 - 1s - loss: 0.1932 - val_loss: 0.1757 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 22/100
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 323/323 - 1s - loss: 0.1905 - val_loss: 0.1710 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 23/100
# 323/323 - 1s - loss: 0.1810 - val_loss: 0.1659 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 24/100
# 323/323 - 1s - loss: 0.1794 - val_loss: 0.1667 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 25/100
# 323/323 - 1s - loss: 0.1776 - val_loss: 0.1640 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 26/100
# 323/323 - 1s - loss: 0.1781 - val_loss: 0.1649 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 27/100
# 323/323 - 1s - loss: 0.1777 - val_loss: 0.1599 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 28/100
# 323/323 - 1s - loss: 0.1768 - val_loss: 0.1649 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 29/100
# 323/323 - 1s - loss: 0.1754 - val_loss: 0.1667 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 30/100
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 323/323 - 1s - loss: 0.1765 - val_loss: 0.1629 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 31/100
# 323/323 - 1s - loss: 0.1697 - val_loss: 0.1620 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 32/100
# 323/323 - 1s - loss: 0.1689 - val_loss: 0.1583 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 33/100
# 323/323 - 1s - loss: 0.1666 - val_loss: 0.1619 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 34/100
# 323/323 - 1s - loss: 0.1659 - val_loss: 0.1608 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 35/100
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 323/323 - 1s - loss: 0.1650 - val_loss: 0.1613 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 36/100
# 323/323 - 1s - loss: 0.1611 - val_loss: 0.1590 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 37/100
# 323/323 - 1s - loss: 0.1608 - val_loss: 0.1588 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
#
# --- Fold 2/5 ---
# Epoch 1/100
# 323/323 - 3s - loss: 0.4050 - val_loss: 0.3112 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 2/100
# 323/323 - 1s - loss: 0.2578 - val_loss: 0.2229 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 323/323 - 1s - loss: 0.2365 - val_loss: 0.2395 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 323/323 - 1s - loss: 0.2269 - val_loss: 0.2045 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 323/323 - 1s - loss: 0.2238 - val_loss: 0.2132 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
# 323/323 - 1s - loss: 0.2222 - val_loss: 0.2204 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 323/323 - 1s - loss: 0.2141 - val_loss: 0.2202 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/100
# 323/323 - 1s - loss: 0.2048 - val_loss: 0.1909 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 9/100
# 323/323 - 1s - loss: 0.1992 - val_loss: 0.1930 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 10/100
# 323/323 - 1s - loss: 0.2024 - val_loss: 0.1844 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 11/100
# 323/323 - 1s - loss: 0.1975 - val_loss: 0.1906 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 12/100
# 323/323 - 1s - loss: 0.1955 - val_loss: 0.1901 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 13/100
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 323/323 - 1s - loss: 0.1951 - val_loss: 0.1885 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 14/100
# 323/323 - 1s - loss: 0.1864 - val_loss: 0.1805 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 15/100
# 323/323 - 1s - loss: 0.1862 - val_loss: 0.1776 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 16/100
# 323/323 - 1s - loss: 0.1832 - val_loss: 0.1773 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 17/100
# 323/323 - 1s - loss: 0.1840 - val_loss: 0.1760 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 18/100
# 323/323 - 1s - loss: 0.1828 - val_loss: 0.1746 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 19/100
# 323/323 - 1s - loss: 0.1824 - val_loss: 0.1759 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 20/100
# 323/323 - 1s - loss: 0.1822 - val_loss: 0.1712 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 21/100
# 323/323 - 1s - loss: 0.1812 - val_loss: 0.1757 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 22/100
# 323/323 - 1s - loss: 0.1801 - val_loss: 0.1715 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 23/100
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 323/323 - 1s - loss: 0.1796 - val_loss: 0.1765 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 24/100
# 323/323 - 1s - loss: 0.1739 - val_loss: 0.1733 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 25/100
# 323/323 - 1s - loss: 0.1739 - val_loss: 0.1699 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 26/100
# 323/323 - 1s - loss: 0.1727 - val_loss: 0.1710 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 27/100
# 323/323 - 1s - loss: 0.1717 - val_loss: 0.1716 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 28/100
# 323/323 - 1s - loss: 0.1700 - val_loss: 0.1696 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 29/100
# 323/323 - 1s - loss: 0.1697 - val_loss: 0.1706 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 30/100
# 323/323 - 1s - loss: 0.1699 - val_loss: 0.1738 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 31/100
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 323/323 - 1s - loss: 0.1697 - val_loss: 0.1697 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 32/100
# 323/323 - 1s - loss: 0.1660 - val_loss: 0.1676 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 33/100
# 323/323 - 1s - loss: 0.1661 - val_loss: 0.1698 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 34/100
# 323/323 - 1s - loss: 0.1649 - val_loss: 0.1705 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 35/100
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 323/323 - 1s - loss: 0.1657 - val_loss: 0.1675 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 36/100
# 323/323 - 1s - loss: 0.1631 - val_loss: 0.1671 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 37/100
# 323/323 - 1s - loss: 0.1628 - val_loss: 0.1674 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 38/100
# 323/323 - 1s - loss: 0.1623 - val_loss: 0.1669 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 39/100
# 323/323 - 1s - loss: 0.1628 - val_loss: 0.1670 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 40/100
# 323/323 - 1s - loss: 0.1624 - val_loss: 0.1680 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 41/100
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 323/323 - 1s - loss: 0.1624 - val_loss: 0.1675 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 42/100
# 323/323 - 1s - loss: 0.1615 - val_loss: 0.1667 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 43/100
# 323/323 - 1s - loss: 0.1608 - val_loss: 0.1674 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 44/100
# 323/323 - 1s - loss: 0.1605 - val_loss: 0.1676 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 45/100
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 323/323 - 1s - loss: 0.1613 - val_loss: 0.1670 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 46/100
# 323/323 - 1s - loss: 0.1600 - val_loss: 0.1673 - lr: 7.8125e-06 - 1s/epoch - 4ms/step
# Epoch 47/100
# 323/323 - 1s - loss: 0.1600 - val_loss: 0.1669 - lr: 7.8125e-06 - 1s/epoch - 4ms/step
#
# --- Fold 3/5 ---
# Epoch 1/100
# 323/323 - 3s - loss: 0.4726 - val_loss: 0.2569 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 2/100
# 323/323 - 1s - loss: 0.2746 - val_loss: 0.2411 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 323/323 - 1s - loss: 0.2506 - val_loss: 0.2072 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 323/323 - 1s - loss: 0.2391 - val_loss: 0.2227 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 323/323 - 1s - loss: 0.2302 - val_loss: 0.2085 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 323/323 - 1s - loss: 0.2278 - val_loss: 0.2244 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
# 323/323 - 1s - loss: 0.2145 - val_loss: 0.1914 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 8/100
# 323/323 - 1s - loss: 0.2118 - val_loss: 0.1963 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 9/100
# 323/323 - 1s - loss: 0.2086 - val_loss: 0.1874 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 10/100
# 323/323 - 1s - loss: 0.2058 - val_loss: 0.1900 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 11/100
# 323/323 - 1s - loss: 0.2088 - val_loss: 0.1917 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 12/100
# 323/323 - 1s - loss: 0.2059 - val_loss: 0.1872 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 13/100
# 323/323 - 1s - loss: 0.2062 - val_loss: 0.1882 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 14/100
# 323/323 - 1s - loss: 0.2017 - val_loss: 0.1916 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 15/100
# 323/323 - 1s - loss: 0.2015 - val_loss: 0.1847 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 16/100
# 323/323 - 1s - loss: 0.1998 - val_loss: 0.1928 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 17/100
# 323/323 - 1s - loss: 0.2001 - val_loss: 0.1780 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 18/100
# 323/323 - 1s - loss: 0.1966 - val_loss: 0.1850 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 19/100
# 323/323 - 1s - loss: 0.1970 - val_loss: 0.1792 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 20/100
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 323/323 - 1s - loss: 0.1970 - val_loss: 0.1803 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 21/100
# 323/323 - 1s - loss: 0.1875 - val_loss: 0.1750 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 22/100
# 323/323 - 1s - loss: 0.1861 - val_loss: 0.1768 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 23/100
# 323/323 - 1s - loss: 0.1864 - val_loss: 0.1708 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 24/100
# 323/323 - 1s - loss: 0.1855 - val_loss: 0.1698 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 25/100
# 323/323 - 1s - loss: 0.1842 - val_loss: 0.1699 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 26/100
# 323/323 - 1s - loss: 0.1842 - val_loss: 0.1732 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 27/100
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 323/323 - 1s - loss: 0.1836 - val_loss: 0.1715 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 28/100
# 323/323 - 1s - loss: 0.1781 - val_loss: 0.1689 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 29/100
# 323/323 - 1s - loss: 0.1780 - val_loss: 0.1672 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 30/100
# 323/323 - 1s - loss: 0.1760 - val_loss: 0.1685 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 31/100
# 323/323 - 1s - loss: 0.1777 - val_loss: 0.1696 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 32/100
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 323/323 - 1s - loss: 0.1763 - val_loss: 0.1700 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 33/100
# 323/323 - 1s - loss: 0.1733 - val_loss: 0.1671 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 34/100
# 323/323 - 1s - loss: 0.1726 - val_loss: 0.1670 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 35/100
# 323/323 - 1s - loss: 0.1726 - val_loss: 0.1668 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 36/100
# 323/323 - 1s - loss: 0.1720 - val_loss: 0.1674 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 37/100
# 323/323 - 1s - loss: 0.1729 - val_loss: 0.1682 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 38/100
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 323/323 - 1s - loss: 0.1713 - val_loss: 0.1667 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 39/100
# 323/323 - 1s - loss: 0.1694 - val_loss: 0.1678 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 40/100
# 323/323 - 1s - loss: 0.1701 - val_loss: 0.1667 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 41/100
# 323/323 - 1s - loss: 0.1699 - val_loss: 0.1671 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 42/100
# 323/323 - 1s - loss: 0.1697 - val_loss: 0.1671 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 43/100
# 323/323 - 1s - loss: 0.1684 - val_loss: 0.1664 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 44/100
# 323/323 - 1s - loss: 0.1680 - val_loss: 0.1673 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 45/100
# 323/323 - 1s - loss: 0.1689 - val_loss: 0.1668 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 46/100
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 323/323 - 1s - loss: 0.1686 - val_loss: 0.1666 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 47/100
# 323/323 - 1s - loss: 0.1678 - val_loss: 0.1666 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 48/100
# 323/323 - 1s - loss: 0.1678 - val_loss: 0.1669 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
#
# --- Fold 4/5 ---
# Epoch 1/100
# 323/323 - 3s - loss: 0.4490 - val_loss: 0.2800 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 2/100
# 323/323 - 1s - loss: 0.2758 - val_loss: 0.2443 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 323/323 - 1s - loss: 0.2491 - val_loss: 0.2247 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 323/323 - 1s - loss: 0.2379 - val_loss: 0.2320 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 323/323 - 1s - loss: 0.2348 - val_loss: 0.2149 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
# 323/323 - 1s - loss: 0.2270 - val_loss: 0.2238 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
# 323/323 - 1s - loss: 0.2181 - val_loss: 0.2025 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/100
# 323/323 - 1s - loss: 0.2153 - val_loss: 0.2091 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 9/100
# 323/323 - 1s - loss: 0.2176 - val_loss: 0.2035 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 10/100
# 323/323 - 1s - loss: 0.2169 - val_loss: 0.2011 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 11/100
# 323/323 - 1s - loss: 0.2098 - val_loss: 0.2220 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 12/100
# 323/323 - 1s - loss: 0.2090 - val_loss: 0.2029 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 13/100
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 323/323 - 1s - loss: 0.2080 - val_loss: 0.2066 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 14/100
# 323/323 - 1s - loss: 0.1960 - val_loss: 0.1855 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 15/100
# 323/323 - 1s - loss: 0.1945 - val_loss: 0.1830 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 16/100
# 323/323 - 1s - loss: 0.1928 - val_loss: 0.1834 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 17/100
# 323/323 - 1s - loss: 0.1924 - val_loss: 0.1839 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 18/100
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 323/323 - 1s - loss: 0.1928 - val_loss: 0.1835 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 19/100
# 323/323 - 1s - loss: 0.1852 - val_loss: 0.1795 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 20/100
# 323/323 - 1s - loss: 0.1829 - val_loss: 0.1777 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 21/100
# 323/323 - 1s - loss: 0.1836 - val_loss: 0.1746 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 22/100
# 323/323 - 1s - loss: 0.1811 - val_loss: 0.1771 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 23/100
# 323/323 - 1s - loss: 0.1826 - val_loss: 0.1785 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 24/100
# 323/323 - 1s - loss: 0.1820 - val_loss: 0.1745 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 25/100
# 323/323 - 1s - loss: 0.1801 - val_loss: 0.1730 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 26/100
# 323/323 - 1s - loss: 0.1808 - val_loss: 0.1764 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 27/100
# 323/323 - 1s - loss: 0.1799 - val_loss: 0.1728 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 28/100
# 323/323 - 1s - loss: 0.1788 - val_loss: 0.1711 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 29/100
# 323/323 - 1s - loss: 0.1780 - val_loss: 0.1752 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 30/100
# 323/323 - 1s - loss: 0.1771 - val_loss: 0.1759 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 31/100
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 323/323 - 1s - loss: 0.1771 - val_loss: 0.1725 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 32/100
# 323/323 - 1s - loss: 0.1727 - val_loss: 0.1712 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 33/100
# 323/323 - 1s - loss: 0.1713 - val_loss: 0.1698 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 34/100
# 323/323 - 1s - loss: 0.1712 - val_loss: 0.1696 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 35/100
# 323/323 - 1s - loss: 0.1706 - val_loss: 0.1700 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 36/100
# 323/323 - 1s - loss: 0.1713 - val_loss: 0.1701 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 37/100
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 323/323 - 1s - loss: 0.1688 - val_loss: 0.1713 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 38/100
# 323/323 - 1s - loss: 0.1662 - val_loss: 0.1692 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 39/100
# 323/323 - 1s - loss: 0.1665 - val_loss: 0.1680 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 40/100
# 323/323 - 1s - loss: 0.1665 - val_loss: 0.1683 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 41/100
# 323/323 - 1s - loss: 0.1661 - val_loss: 0.1681 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 42/100
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 323/323 - 1s - loss: 0.1663 - val_loss: 0.1699 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 43/100
# 323/323 - 1s - loss: 0.1640 - val_loss: 0.1674 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 44/100
# 323/323 - 1s - loss: 0.1636 - val_loss: 0.1680 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 45/100
# 323/323 - 1s - loss: 0.1630 - val_loss: 0.1683 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 46/100
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 323/323 - 1s - loss: 0.1624 - val_loss: 0.1679 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 47/100
# 323/323 - 1s - loss: 0.1625 - val_loss: 0.1676 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 48/100
# 323/323 - 1s - loss: 0.1619 - val_loss: 0.1678 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
#
# --- Fold 5/5 ---
# Epoch 1/100
# 323/323 - 3s - loss: 0.4908 - val_loss: 0.2664 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 2/100
# 323/323 - 1s - loss: 0.2739 - val_loss: 0.2381 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 323/323 - 1s - loss: 0.2474 - val_loss: 0.2276 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 323/323 - 1s - loss: 0.2379 - val_loss: 0.2246 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 323/323 - 1s - loss: 0.2308 - val_loss: 0.1901 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
# 323/323 - 1s - loss: 0.2296 - val_loss: 0.2003 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
# 323/323 - 1s - loss: 0.2222 - val_loss: 0.1966 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/100
# 323/323 - 1s - loss: 0.2190 - val_loss: 0.1869 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 9/100
# 323/323 - 1s - loss: 0.2183 - val_loss: 0.1852 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 10/100
# 323/323 - 1s - loss: 0.2149 - val_loss: 0.1759 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 11/100
# 323/323 - 1s - loss: 0.2121 - val_loss: 0.1867 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 12/100
# 323/323 - 1s - loss: 0.2115 - val_loss: 0.1709 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 13/100
# 323/323 - 1s - loss: 0.2106 - val_loss: 0.1797 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 14/100
# 323/323 - 1s - loss: 0.2059 - val_loss: 0.1841 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 15/100
# 323/323 - 1s - loss: 0.2019 - val_loss: 0.1695 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 16/100
# 323/323 - 1s - loss: 0.2015 - val_loss: 0.1666 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 17/100
# 323/323 - 1s - loss: 0.2008 - val_loss: 0.1718 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 18/100
# 323/323 - 1s - loss: 0.1993 - val_loss: 0.1737 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 19/100
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 323/323 - 1s - loss: 0.1959 - val_loss: 0.1744 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 20/100
# 323/323 - 1s - loss: 0.1861 - val_loss: 0.1620 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 21/100
# 323/323 - 1s - loss: 0.1843 - val_loss: 0.1652 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 22/100
# 323/323 - 1s - loss: 0.1838 - val_loss: 0.1584 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 23/100
# 323/323 - 1s - loss: 0.1833 - val_loss: 0.1590 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 24/100
# 323/323 - 1s - loss: 0.1831 - val_loss: 0.1587 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 25/100
# 323/323 - 1s - loss: 0.1829 - val_loss: 0.1571 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 26/100
# 323/323 - 1s - loss: 0.1814 - val_loss: 0.1594 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 27/100
# 323/323 - 1s - loss: 0.1807 - val_loss: 0.1587 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 28/100
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 323/323 - 1s - loss: 0.1806 - val_loss: 0.1612 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 29/100
# 323/323 - 1s - loss: 0.1747 - val_loss: 0.1535 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 30/100
# 323/323 - 1s - loss: 0.1725 - val_loss: 0.1538 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 31/100
# 323/323 - 1s - loss: 0.1719 - val_loss: 0.1565 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 32/100
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 323/323 - 1s - loss: 0.1715 - val_loss: 0.1567 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 33/100
# 323/323 - 1s - loss: 0.1686 - val_loss: 0.1549 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 34/100
# 323/323 - 1s - loss: 0.1671 - val_loss: 0.1551 - lr: 1.2500e-04 - 1s/epoch - 4ms/step

# %%
y_pred_ensemble_misnir, y_pred_STD_misnir = ensemble_predict(trained_models, X_test_y10_misnir)
# Out:
# 3229/3229 [==============================] - 4s 1ms/step
# 3229/3229 [==============================] - 4s 1ms/step
# 3229/3229 [==============================] - 3s 1ms/step
# 3229/3229 [==============================] - 3s 1ms/step
# 3229/3229 [==============================] - 3s 1ms/step

# %%
# save the trained model:
root = "/pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models"
save_dir = root + "/y10_misnir_ensemble_CNN_6layers"
save_ensemble(trained_models, save_dir=save_dir)
# Out:
# Saved fold 1 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y10_misnir_ensemble_CNN_6layers/model_fold_1.keras
# Saved fold 2 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y10_misnir_ensemble_CNN_6layers/model_fold_2.keras
# Saved fold 3 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y10_misnir_ensemble_CNN_6layers/model_fold_3.keras
# Saved fold 4 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y10_misnir_ensemble_CNN_6layers/model_fold_4.keras
# Saved fold 5 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y10_misnir_ensemble_CNN_6layers/model_fold_5.keras
# Saved normalisation parameters to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y10_misnir_ensemble_CNN_6layers/norm_params.json

# %%
redshift_bins = np.linspace(0,2.5,11)
imag_bins = np.linspace(18, 25.5,11)
#fname = save_dir + "/stats.pkl"
stats2, redshift_stats2, imag_stats2 = get_all_stats(Y_test_y10_misnir, y_pred_ensemble_misnir.flatten(), test_y10['mag_i_lsst'], save=False, 
                                                     redshift_bins = redshift_bins, imag_bins = imag_bins)

plot_stats(stats2, redshift_stats2, imag_stats2, Y_test_y10_misnir, y_pred_ensemble_misnir.flatten(), 
           redshift_bins, imag_bins, test_y10['mag_i_lsst'], save_path=save_dir + '/photoz_stats.png')
# Out:
# /tmp/ipykernel_562300/1952338895.py:98: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Plot saved to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y10_misnir_ensemble_CNN_6layers/photoz_stats.png

# %% [markdown]
# ## Spec select sample (no pre-training):

# %%
saveroot = "/pscratch/sd/q/qhang/cnnpz/cardinal/"
training_y10_spec = pd.read_parquet(saveroot + "train_100k_noisy_y10_i25.4.SpecSelect.parquet")
# change the name of the roman columns:
training_y10_spec = training_y10_spec.rename(columns={'Roman_obs_J129': 'mag_J_roman', 
                                              'Roman_obs_H158': 'mag_H_roman'})
training_y10_spec = training_y10_spec.reset_index(drop=True) 
X_y10_spec, Y_y10_spec = transform_data_to_XY(training_y10_spec)


saveroot = "/pscratch/sd/q/qhang/cnnpz/cardinal/"
training_y1_spec = pd.read_parquet(saveroot + "train_100k_noisy_y1_i23.SpecSelect.parquet")
# change the name of the roman columns:
training_y1_spec = training_y1_spec.rename(columns={'Roman_obs_J129': 'mag_J_roman', 
                                              'Roman_obs_H158': 'mag_H_roman'})
training_y1_spec = training_y1_spec.reset_index(drop=True) 
X_y1_spec, Y_y1_spec = transform_data_to_XY(training_y1_spec)

# %%
Y_y1_spec
# Out:
# 0        0.540908
# 1        0.101199
# 2        0.388574
# 3        0.346534
# 4        0.643569
#            ...
# 90611    0.153747
# 90612    0.179227
# 90613    0.666857
# 90614    0.944296
# 90615    0.903384
# Name: redshift, Length: 90616, dtype: float64

# %%
visualize_the_data(X_y1_spec, Y_y1_spec, title="Y1 spec example")

# %%
trained_models, histories = train_ensembles(build_model, X_y1_spec, Y_y1_spec)
# Out:
# --- Fold 1/5 ---
# Epoch 1/100
# 2026-08-21 04:25:32.854769: I external/local_xla/xla/service/service.cc:168] XLA service 0x56422fd7bda0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-08-21 04:25:32.854787: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A100-SXM4-40GB, Compute Capability 8.0
# 2026-08-21 04:25:32.863268: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1787311532.967001 1277334 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 284/284 - 7s - loss: 0.4078 - val_loss: 0.1725 - lr: 0.0010 - 7s/epoch - 24ms/step
# Epoch 2/100
# 284/284 - 1s - loss: 0.1725 - val_loss: 0.1144 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 284/284 - 1s - loss: 0.1408 - val_loss: 0.3193 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 284/284 - 1s - loss: 0.1226 - val_loss: 0.1070 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 284/284 - 1s - loss: 0.0992 - val_loss: 0.0633 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
# 284/284 - 1s - loss: 0.0884 - val_loss: 0.0796 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
# 284/284 - 1s - loss: 0.0796 - val_loss: 0.0679 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/100
# 284/284 - 1s - loss: 0.0809 - val_loss: 0.0524 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 9/100
# 284/284 - 1s - loss: 0.0777 - val_loss: 0.0546 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 10/100
# 284/284 - 1s - loss: 0.0760 - val_loss: 0.0674 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 11/100
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 284/284 - 1s - loss: 0.0688 - val_loss: 0.0539 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 12/100
# 284/284 - 1s - loss: 0.0642 - val_loss: 0.0398 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 13/100
# 284/284 - 1s - loss: 0.0642 - val_loss: 0.0404 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 14/100
# 284/284 - 1s - loss: 0.0661 - val_loss: 0.0518 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 15/100
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 284/284 - 1s - loss: 0.0642 - val_loss: 0.0439 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 16/100
# 284/284 - 1s - loss: 0.0591 - val_loss: 0.0391 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 17/100
# 284/284 - 1s - loss: 0.0590 - val_loss: 0.0364 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 18/100
# 284/284 - 1s - loss: 0.0591 - val_loss: 0.0340 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 19/100
# 284/284 - 1s - loss: 0.0581 - val_loss: 0.0382 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 20/100
# 284/284 - 1s - loss: 0.0592 - val_loss: 0.0379 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 21/100
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 284/284 - 1s - loss: 0.0591 - val_loss: 0.0361 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 22/100
# 284/284 - 1s - loss: 0.0555 - val_loss: 0.0347 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 23/100
# 284/284 - 1s - loss: 0.0558 - val_loss: 0.0325 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 24/100
# 284/284 - 1s - loss: 0.0556 - val_loss: 0.0359 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 25/100
# 284/284 - 1s - loss: 0.0558 - val_loss: 0.0401 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 26/100
# 284/284 - 1s - loss: 0.0560 - val_loss: 0.0315 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 27/100
# 284/284 - 1s - loss: 0.0549 - val_loss: 0.0381 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 28/100
# 284/284 - 1s - loss: 0.0553 - val_loss: 0.0326 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 29/100
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 284/284 - 1s - loss: 0.0543 - val_loss: 0.0389 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 30/100
# 284/284 - 1s - loss: 0.0539 - val_loss: 0.0360 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 31/100
# 284/284 - 1s - loss: 0.0531 - val_loss: 0.0362 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
#
# --- Fold 2/5 ---
# Epoch 1/100
# 284/284 - 3s - loss: 0.3916 - val_loss: 0.1615 - lr: 0.0010 - 3s/epoch - 11ms/step
# Epoch 2/100
# 284/284 - 1s - loss: 0.1640 - val_loss: 0.0980 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 284/284 - 1s - loss: 0.1301 - val_loss: 0.0961 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 284/284 - 1s - loss: 0.1170 - val_loss: 0.0923 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 284/284 - 1s - loss: 0.0994 - val_loss: 0.0827 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
# 284/284 - 1s - loss: 0.0886 - val_loss: 0.0495 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
# 284/284 - 1s - loss: 0.0819 - val_loss: 0.0510 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/100
# 284/284 - 1s - loss: 0.0796 - val_loss: 0.0489 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 9/100
# 284/284 - 1s - loss: 0.0749 - val_loss: 0.0421 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 10/100
# 284/284 - 1s - loss: 0.0753 - val_loss: 0.0404 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 11/100
# 284/284 - 1s - loss: 0.0719 - val_loss: 0.0441 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 12/100
# 284/284 - 1s - loss: 0.0702 - val_loss: 0.0564 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 13/100
# 284/284 - 1s - loss: 0.0678 - val_loss: 0.0362 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 14/100
# 284/284 - 1s - loss: 0.0718 - val_loss: 0.0393 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 15/100
# 284/284 - 1s - loss: 0.0689 - val_loss: 0.0425 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 16/100
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 284/284 - 1s - loss: 0.0681 - val_loss: 0.0435 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 17/100
# 284/284 - 1s - loss: 0.0596 - val_loss: 0.0359 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 18/100
# 284/284 - 1s - loss: 0.0589 - val_loss: 0.0313 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 19/100
# 284/284 - 1s - loss: 0.0593 - val_loss: 0.0338 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 20/100
# 284/284 - 1s - loss: 0.0585 - val_loss: 0.0363 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 21/100
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 284/284 - 1s - loss: 0.0611 - val_loss: 0.0329 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 22/100
# 284/284 - 1s - loss: 0.0562 - val_loss: 0.0328 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 23/100
# 284/284 - 1s - loss: 0.0550 - val_loss: 0.0320 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
#
# --- Fold 3/5 ---
# Epoch 1/100
# 284/284 - 3s - loss: 0.4148 - val_loss: 0.2143 - lr: 0.0010 - 3s/epoch - 10ms/step
# Epoch 2/100
# 284/284 - 1s - loss: 0.1747 - val_loss: 0.1312 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 284/284 - 1s - loss: 0.1428 - val_loss: 0.1074 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 284/284 - 1s - loss: 0.1243 - val_loss: 0.0909 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 284/284 - 1s - loss: 0.1116 - val_loss: 0.0848 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
# 284/284 - 1s - loss: 0.1039 - val_loss: 0.1042 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
# 284/284 - 1s - loss: 0.0952 - val_loss: 0.0681 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/100
# 284/284 - 1s - loss: 0.0885 - val_loss: 0.0556 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 9/100
# 284/284 - 1s - loss: 0.0869 - val_loss: 0.0463 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 10/100
# 284/284 - 1s - loss: 0.0794 - val_loss: 0.0487 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 11/100
# 284/284 - 1s - loss: 0.0766 - val_loss: 0.0466 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 12/100
# 284/284 - 1s - loss: 0.0765 - val_loss: 0.0451 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 13/100
# 284/284 - 1s - loss: 0.0784 - val_loss: 0.0452 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 14/100
# 284/284 - 1s - loss: 0.0746 - val_loss: 0.0474 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 15/100
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 284/284 - 1s - loss: 0.0779 - val_loss: 0.0491 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 16/100
# 284/284 - 1s - loss: 0.0708 - val_loss: 0.0408 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 17/100
# 284/284 - 1s - loss: 0.0680 - val_loss: 0.0375 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 18/100
# 284/284 - 1s - loss: 0.0684 - val_loss: 0.0413 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 19/100
# 284/284 - 1s - loss: 0.0683 - val_loss: 0.0574 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 20/100
# 284/284 - 1s - loss: 0.0666 - val_loss: 0.0339 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 21/100
# 284/284 - 1s - loss: 0.0663 - val_loss: 0.0340 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 22/100
# 284/284 - 1s - loss: 0.0656 - val_loss: 0.0396 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 23/100
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 284/284 - 1s - loss: 0.0677 - val_loss: 0.0403 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 24/100
# 284/284 - 1s - loss: 0.0644 - val_loss: 0.0339 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 25/100
# 284/284 - 1s - loss: 0.0627 - val_loss: 0.0337 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 26/100
# 284/284 - 1s - loss: 0.0637 - val_loss: 0.0310 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 27/100
# 284/284 - 1s - loss: 0.0633 - val_loss: 0.0298 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 28/100
# 284/284 - 1s - loss: 0.0616 - val_loss: 0.0338 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 29/100
# 284/284 - 1s - loss: 0.0602 - val_loss: 0.0323 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 30/100
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 284/284 - 1s - loss: 0.0619 - val_loss: 0.0343 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 31/100
# 284/284 - 1s - loss: 0.0599 - val_loss: 0.0286 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 32/100
# 284/284 - 1s - loss: 0.0587 - val_loss: 0.0277 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 33/100
# 284/284 - 1s - loss: 0.0577 - val_loss: 0.0288 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 34/100
# 284/284 - 1s - loss: 0.0577 - val_loss: 0.0278 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 35/100
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 284/284 - 1s - loss: 0.0566 - val_loss: 0.0284 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 36/100
# 284/284 - 1s - loss: 0.0555 - val_loss: 0.0285 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 37/100
# 284/284 - 1s - loss: 0.0555 - val_loss: 0.0278 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
#
# --- Fold 4/5 ---
# Epoch 1/100
# 284/284 - 3s - loss: 0.3994 - val_loss: 0.1564 - lr: 0.0010 - 3s/epoch - 10ms/step
# Epoch 2/100
# 284/284 - 1s - loss: 0.1653 - val_loss: 0.1017 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 284/284 - 1s - loss: 0.1308 - val_loss: 0.2409 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 284/284 - 1s - loss: 0.1207 - val_loss: 0.0775 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 284/284 - 1s - loss: 0.1096 - val_loss: 0.0668 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
# 284/284 - 1s - loss: 0.0992 - val_loss: 0.0577 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
# 284/284 - 1s - loss: 0.0911 - val_loss: 0.0504 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/100
# 284/284 - 1s - loss: 0.0826 - val_loss: 0.0457 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 9/100
# 284/284 - 1s - loss: 0.0813 - val_loss: 0.0426 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 10/100
# 284/284 - 1s - loss: 0.0776 - val_loss: 0.0449 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 11/100
# 284/284 - 1s - loss: 0.0759 - val_loss: 0.0359 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 12/100
# 284/284 - 1s - loss: 0.0732 - val_loss: 0.0398 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 13/100
# 284/284 - 1s - loss: 0.0754 - val_loss: 0.0342 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 14/100
# 284/284 - 1s - loss: 0.0695 - val_loss: 0.0746 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 15/100
# 284/284 - 1s - loss: 0.0745 - val_loss: 0.0359 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 16/100
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 284/284 - 1s - loss: 0.0713 - val_loss: 0.0348 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 17/100
# 284/284 - 1s - loss: 0.0635 - val_loss: 0.0503 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 18/100
# 284/284 - 1s - loss: 0.0627 - val_loss: 0.0329 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 19/100
# 284/284 - 1s - loss: 0.0624 - val_loss: 0.0312 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 20/100
# 284/284 - 1s - loss: 0.0622 - val_loss: 0.0312 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 21/100
# 284/284 - 1s - loss: 0.0626 - val_loss: 0.0332 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 22/100
# 284/284 - 1s - loss: 0.0615 - val_loss: 0.0299 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 23/100
# 284/284 - 1s - loss: 0.0612 - val_loss: 0.0329 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 24/100
# 284/284 - 1s - loss: 0.0616 - val_loss: 0.0347 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 25/100
# 284/284 - 1s - loss: 0.0586 - val_loss: 0.0290 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 26/100
# 284/284 - 1s - loss: 0.0611 - val_loss: 0.0316 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 27/100
# 284/284 - 1s - loss: 0.0622 - val_loss: 0.0298 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 28/100
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 284/284 - 1s - loss: 0.0599 - val_loss: 0.0349 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 29/100
# 284/284 - 1s - loss: 0.0564 - val_loss: 0.0291 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 30/100
# 284/284 - 1s - loss: 0.0565 - val_loss: 0.0277 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 31/100
# 284/284 - 1s - loss: 0.0552 - val_loss: 0.0291 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 32/100
# 284/284 - 1s - loss: 0.0556 - val_loss: 0.0340 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 33/100
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 284/284 - 1s - loss: 0.0551 - val_loss: 0.0281 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 34/100
# 284/284 - 1s - loss: 0.0532 - val_loss: 0.0268 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 35/100
# 284/284 - 1s - loss: 0.0521 - val_loss: 0.0269 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 36/100
# 284/284 - 1s - loss: 0.0520 - val_loss: 0.0295 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 37/100
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 284/284 - 1s - loss: 0.0521 - val_loss: 0.0286 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 38/100
# 284/284 - 1s - loss: 0.0501 - val_loss: 0.0270 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 39/100
# 284/284 - 1s - loss: 0.0503 - val_loss: 0.0256 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 40/100
# 284/284 - 1s - loss: 0.0511 - val_loss: 0.0273 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 41/100
# 284/284 - 1s - loss: 0.0504 - val_loss: 0.0271 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 42/100
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 284/284 - 1s - loss: 0.0509 - val_loss: 0.0269 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 43/100
# 284/284 - 1s - loss: 0.0496 - val_loss: 0.0257 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 44/100
# 284/284 - 1s - loss: 0.0500 - val_loss: 0.0264 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
#
# --- Fold 5/5 ---
# Epoch 1/100
# 284/284 - 3s - loss: 0.4467 - val_loss: 0.1938 - lr: 0.0010 - 3s/epoch - 10ms/step
# Epoch 2/100
# 284/284 - 1s - loss: 0.1907 - val_loss: 0.1549 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 284/284 - 1s - loss: 0.1580 - val_loss: 0.1146 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 284/284 - 1s - loss: 0.1369 - val_loss: 0.0944 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 284/284 - 1s - loss: 0.1253 - val_loss: 0.0891 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
# 284/284 - 1s - loss: 0.1171 - val_loss: 0.0937 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
# 284/284 - 1s - loss: 0.1086 - val_loss: 0.0761 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/100
# 284/284 - 1s - loss: 0.0994 - val_loss: 0.0661 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 9/100
# 284/284 - 1s - loss: 0.0979 - val_loss: 0.0685 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 10/100
# 284/284 - 1s - loss: 0.0896 - val_loss: 0.0568 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 11/100
# 284/284 - 1s - loss: 0.0852 - val_loss: 0.0581 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 12/100
# 284/284 - 1s - loss: 0.0849 - val_loss: 0.0452 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 13/100
# 284/284 - 1s - loss: 0.0801 - val_loss: 0.0777 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 14/100
# 284/284 - 1s - loss: 0.0829 - val_loss: 0.0458 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 15/100
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 284/284 - 1s - loss: 0.0778 - val_loss: 0.0618 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 16/100
# 284/284 - 1s - loss: 0.0711 - val_loss: 0.0502 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 17/100
# 284/284 - 1s - loss: 0.0699 - val_loss: 0.0352 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 18/100
# 284/284 - 1s - loss: 0.0691 - val_loss: 0.0413 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 19/100
# 284/284 - 1s - loss: 0.0687 - val_loss: 0.0363 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 20/100
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 284/284 - 1s - loss: 0.0698 - val_loss: 0.0375 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 21/100
# 284/284 - 1s - loss: 0.0659 - val_loss: 0.0387 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 22/100
# 284/284 - 1s - loss: 0.0656 - val_loss: 0.0303 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 23/100
# 284/284 - 1s - loss: 0.0654 - val_loss: 0.0322 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 24/100
# 284/284 - 1s - loss: 0.0648 - val_loss: 0.0303 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 25/100
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 284/284 - 1s - loss: 0.0641 - val_loss: 0.0445 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 26/100
# 284/284 - 1s - loss: 0.0628 - val_loss: 0.0328 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 27/100
# 284/284 - 1s - loss: 0.0620 - val_loss: 0.0338 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 28/100
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 284/284 - 1s - loss: 0.0609 - val_loss: 0.0320 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 29/100
# 284/284 - 1s - loss: 0.0603 - val_loss: 0.0297 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 30/100
# 284/284 - 1s - loss: 0.0594 - val_loss: 0.0305 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 31/100
# 284/284 - 1s - loss: 0.0593 - val_loss: 0.0307 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 32/100
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 284/284 - 1s - loss: 0.0595 - val_loss: 0.0308 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 33/100
# 284/284 - 1s - loss: 0.0583 - val_loss: 0.0304 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 34/100
# 284/284 - 1s - loss: 0.0592 - val_loss: 0.0304 - lr: 3.1250e-05 - 1s/epoch - 4ms/step

# %%
plot_ensemble_losses(histories, ylim=(0, 0.2))

# %%
y_pred_ensemble, y_pred_STD = ensemble_predict(trained_models, X_test_y1)
# Out:
# 3360/3360 [==============================] - 4s 1ms/step
# 3360/3360 [==============================] - 4s 1ms/step
# 3360/3360 [==============================] - 4s 1ms/step
# 3360/3360 [==============================] - 4s 1ms/step
# 3360/3360 [==============================] - 4s 1ms/step

# %%
# save the trained model:
root = "/pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models"
save_dir = root + "/y1_specsel_ensemble_CNN_6layers"
save_ensemble(trained_models, save_dir=save_dir)
# Out:
# Saved fold 1 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y1_specsel_ensemble_CNN_6layers/model_fold_1.keras
# Saved fold 2 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y1_specsel_ensemble_CNN_6layers/model_fold_2.keras
# Saved fold 3 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y1_specsel_ensemble_CNN_6layers/model_fold_3.keras
# Saved fold 4 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y1_specsel_ensemble_CNN_6layers/model_fold_4.keras
# Saved fold 5 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y1_specsel_ensemble_CNN_6layers/model_fold_5.keras
# Saved normalisation parameters to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y1_specsel_ensemble_CNN_6layers/norm_params.json

# %%
redshift_bins = np.linspace(0,2.5,11)
imag_bins = np.linspace(18, 25.5,11)
#fname = save_dir + "/stats.pkl"
stats2, redshift_stats2, imag_stats2 = get_all_stats(Y_test_y1, y_pred_ensemble.flatten(), test_y1['mag_i_lsst'], save=False, 
                                                     redshift_bins = redshift_bins, imag_bins = imag_bins)

plot_stats(stats2, redshift_stats2, imag_stats2, Y_test_y1, y_pred_ensemble.flatten(), 
           redshift_bins, imag_bins, test_y1['mag_i_lsst'], save_path=save_dir + '/photoz_stats.png')
# Out:
# /global/common/software/nersc9/tensorflow/2.15.0/lib/python3.9/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /global/common/software/nersc9/tensorflow/2.15.0/lib/python3.9/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /global/common/software/nersc9/tensorflow/2.15.0/lib/python3.9/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /global/common/software/nersc9/tensorflow/2.15.0/lib/python3.9/site-packages/scipy/stats/_stats_py.py:3666: RuntimeWarning: Mean of empty slice.
#   c_mean = c.mean()
# /global/common/software/nersc9/tensorflow/2.15.0/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /global/common/software/nersc9/tensorflow/2.15.0/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /tmp/ipykernel_1275168/2220381783.py:18: RuntimeWarning: invalid value encountered in scalar divide
#   outlier_rate = np.sum(np.abs(subset) > 3 * np.std(subset_clip)) / len(
# /tmp/ipykernel_1275168/2220381783.py:21: RuntimeWarning: invalid value encountered in scalar divide
#   abs_outlier_rate = np.sum(np.abs(subset) > abs_out_thresh) / len(
# /tmp/ipykernel_1275168/1952338895.py:98: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Plot saved to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y1_specsel_ensemble_CNN_6layers/photoz_stats.png

# %% [markdown]
# ### Y10

# %%
trained_models, histories = train_ensembles(build_model, X_y10_spec, Y_y10_spec)
# Out:
# --- Fold 1/5 ---
# Epoch 1/100
# 313/313 - 4s - loss: 0.3736 - val_loss: 0.1489 - lr: 0.0010 - 4s/epoch - 12ms/step
# Epoch 2/100
# 313/313 - 1s - loss: 0.1413 - val_loss: 0.0813 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 313/313 - 1s - loss: 0.0956 - val_loss: 0.0553 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 313/313 - 1s - loss: 0.0827 - val_loss: 0.0529 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 313/313 - 1s - loss: 0.0715 - val_loss: 0.0533 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
# 313/313 - 1s - loss: 0.0706 - val_loss: 0.0363 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
# 313/313 - 1s - loss: 0.0685 - val_loss: 0.0422 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/100
# 313/313 - 1s - loss: 0.0653 - val_loss: 0.0503 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 9/100
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 313/313 - 1s - loss: 0.0665 - val_loss: 0.0430 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 10/100
# 313/313 - 1s - loss: 0.0572 - val_loss: 0.0289 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 11/100
# 313/313 - 1s - loss: 0.0560 - val_loss: 0.0317 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 12/100
# 313/313 - 1s - loss: 0.0556 - val_loss: 0.0296 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 13/100
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 313/313 - 1s - loss: 0.0572 - val_loss: 0.0411 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 14/100
# 313/313 - 1s - loss: 0.0525 - val_loss: 0.0249 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 15/100
# 313/313 - 1s - loss: 0.0498 - val_loss: 0.0232 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 16/100
# 313/313 - 1s - loss: 0.0512 - val_loss: 0.0255 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 17/100
# 313/313 - 1s - loss: 0.0498 - val_loss: 0.0246 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 18/100
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 313/313 - 1s - loss: 0.0494 - val_loss: 0.0263 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 19/100
# 313/313 - 1s - loss: 0.0465 - val_loss: 0.0201 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 20/100
# 313/313 - 1s - loss: 0.0471 - val_loss: 0.0220 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 21/100
# 313/313 - 1s - loss: 0.0462 - val_loss: 0.0204 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 22/100
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 313/313 - 1s - loss: 0.0455 - val_loss: 0.0200 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 23/100
# 313/313 - 1s - loss: 0.0442 - val_loss: 0.0213 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 24/100
# 313/313 - 1s - loss: 0.0447 - val_loss: 0.0187 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 25/100
# 313/313 - 1s - loss: 0.0438 - val_loss: 0.0188 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 26/100
# 313/313 - 1s - loss: 0.0429 - val_loss: 0.0185 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 27/100
# 313/313 - 1s - loss: 0.0433 - val_loss: 0.0175 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 28/100
# 313/313 - 1s - loss: 0.0430 - val_loss: 0.0200 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 29/100
# 313/313 - 1s - loss: 0.0434 - val_loss: 0.0190 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 30/100
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 313/313 - 1s - loss: 0.0434 - val_loss: 0.0175 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 31/100
# 313/313 - 1s - loss: 0.0419 - val_loss: 0.0171 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 32/100
# 313/313 - 1s - loss: 0.0418 - val_loss: 0.0177 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 33/100
# 313/313 - 1s - loss: 0.0414 - val_loss: 0.0175 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 34/100
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 313/313 - 1s - loss: 0.0415 - val_loss: 0.0182 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 35/100
# 313/313 - 1s - loss: 0.0411 - val_loss: 0.0167 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 36/100
# 313/313 - 1s - loss: 0.0407 - val_loss: 0.0172 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 37/100
# 313/313 - 1s - loss: 0.0412 - val_loss: 0.0174 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 38/100
# 313/313 - 1s - loss: 0.0408 - val_loss: 0.0164 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 39/100
# 313/313 - 1s - loss: 0.0414 - val_loss: 0.0170 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 40/100
# 313/313 - 1s - loss: 0.0411 - val_loss: 0.0167 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 41/100
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 313/313 - 1s - loss: 0.0397 - val_loss: 0.0174 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 42/100
# 313/313 - 1s - loss: 0.0403 - val_loss: 0.0171 - lr: 7.8125e-06 - 1s/epoch - 4ms/step
# Epoch 43/100
# 313/313 - 1s - loss: 0.0403 - val_loss: 0.0167 - lr: 7.8125e-06 - 1s/epoch - 4ms/step
#
# --- Fold 2/5 ---
# Epoch 1/100
# 313/313 - 3s - loss: 0.4017 - val_loss: 0.2097 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 2/100
# 313/313 - 1s - loss: 0.1642 - val_loss: 0.1036 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 313/313 - 1s - loss: 0.1102 - val_loss: 0.0716 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 313/313 - 1s - loss: 0.0929 - val_loss: 0.0562 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 313/313 - 1s - loss: 0.0823 - val_loss: 0.0483 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
# 313/313 - 1s - loss: 0.0771 - val_loss: 0.0456 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
# 313/313 - 1s - loss: 0.0663 - val_loss: 0.0372 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/100
# 313/313 - 1s - loss: 0.0641 - val_loss: 0.0441 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 9/100
# 313/313 - 1s - loss: 0.0645 - val_loss: 0.0423 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 10/100
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 313/313 - 1s - loss: 0.0619 - val_loss: 0.0377 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 11/100
# 313/313 - 1s - loss: 0.0541 - val_loss: 0.0271 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 12/100
# 313/313 - 1s - loss: 0.0521 - val_loss: 0.0283 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 13/100
# 313/313 - 1s - loss: 0.0533 - val_loss: 0.0262 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 14/100
# 313/313 - 1s - loss: 0.0513 - val_loss: 0.0268 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 15/100
# 313/313 - 1s - loss: 0.0545 - val_loss: 0.0252 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 16/100
# 313/313 - 1s - loss: 0.0487 - val_loss: 0.0404 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 17/100
# 313/313 - 1s - loss: 0.0495 - val_loss: 0.0220 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 18/100
# 313/313 - 1s - loss: 0.0502 - val_loss: 0.0256 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 19/100
# 313/313 - 1s - loss: 0.0495 - val_loss: 0.0275 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 20/100
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 313/313 - 1s - loss: 0.0524 - val_loss: 0.0241 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 21/100
# 313/313 - 1s - loss: 0.0445 - val_loss: 0.0332 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 22/100
# 313/313 - 1s - loss: 0.0440 - val_loss: 0.0211 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 23/100
# 313/313 - 1s - loss: 0.0443 - val_loss: 0.0226 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 24/100
# 313/313 - 1s - loss: 0.0421 - val_loss: 0.0202 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 25/100
# 313/313 - 1s - loss: 0.0433 - val_loss: 0.0209 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 26/100
# 313/313 - 1s - loss: 0.0417 - val_loss: 0.0358 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 27/100
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 313/313 - 1s - loss: 0.0428 - val_loss: 0.0207 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 28/100
# 313/313 - 1s - loss: 0.0394 - val_loss: 0.0185 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 29/100
# 313/313 - 1s - loss: 0.0390 - val_loss: 0.0213 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 30/100
# 313/313 - 1s - loss: 0.0402 - val_loss: 0.0198 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 31/100
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 313/313 - 1s - loss: 0.0382 - val_loss: 0.0212 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 32/100
# 313/313 - 1s - loss: 0.0381 - val_loss: 0.0188 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 33/100
# 313/313 - 1s - loss: 0.0370 - val_loss: 0.0181 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 34/100
# 313/313 - 1s - loss: 0.0369 - val_loss: 0.0179 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 35/100
# 313/313 - 1s - loss: 0.0369 - val_loss: 0.0185 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 36/100
# 313/313 - 1s - loss: 0.0365 - val_loss: 0.0203 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 37/100
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 313/313 - 1s - loss: 0.0365 - val_loss: 0.0188 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 38/100
# 313/313 - 1s - loss: 0.0361 - val_loss: 0.0181 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 39/100
# 313/313 - 1s - loss: 0.0352 - val_loss: 0.0173 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 40/100
# 313/313 - 1s - loss: 0.0354 - val_loss: 0.0182 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 41/100
# 313/313 - 1s - loss: 0.0351 - val_loss: 0.0183 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 42/100
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 313/313 - 1s - loss: 0.0353 - val_loss: 0.0199 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 43/100
# 313/313 - 1s - loss: 0.0351 - val_loss: 0.0172 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 44/100
# 313/313 - 1s - loss: 0.0347 - val_loss: 0.0176 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 45/100
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 313/313 - 1s - loss: 0.0345 - val_loss: 0.0188 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 46/100
# 313/313 - 1s - loss: 0.0349 - val_loss: 0.0176 - lr: 7.8125e-06 - 1s/epoch - 4ms/step
# Epoch 47/100
# 313/313 - 1s - loss: 0.0342 - val_loss: 0.0175 - lr: 7.8125e-06 - 1s/epoch - 4ms/step
# Epoch 48/100
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 313/313 - 1s - loss: 0.0339 - val_loss: 0.0178 - lr: 7.8125e-06 - 1s/epoch - 4ms/step
#
# --- Fold 3/5 ---
# Epoch 1/100
# 313/313 - 3s - loss: 0.3424 - val_loss: 0.1468 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 2/100
# 313/313 - 1s - loss: 0.1330 - val_loss: 0.0759 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 313/313 - 1s - loss: 0.1010 - val_loss: 0.0838 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 313/313 - 1s - loss: 0.0895 - val_loss: 0.0643 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 313/313 - 1s - loss: 0.0828 - val_loss: 0.0519 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
# 313/313 - 1s - loss: 0.0784 - val_loss: 0.0532 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
# 313/313 - 1s - loss: 0.0712 - val_loss: 0.0430 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/100
# 313/313 - 1s - loss: 0.0713 - val_loss: 0.0395 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 9/100
# 313/313 - 1s - loss: 0.0670 - val_loss: 0.0408 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 10/100
# 313/313 - 1s - loss: 0.0653 - val_loss: 0.0335 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 11/100
# 313/313 - 1s - loss: 0.0633 - val_loss: 0.0367 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 12/100
# 313/313 - 1s - loss: 0.0605 - val_loss: 0.0283 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 13/100
# 313/313 - 1s - loss: 0.0606 - val_loss: 0.0339 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 14/100
# 313/313 - 1s - loss: 0.0623 - val_loss: 0.0342 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 15/100
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 313/313 - 1s - loss: 0.0605 - val_loss: 0.0287 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 16/100
# 313/313 - 1s - loss: 0.0511 - val_loss: 0.0235 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 17/100
# 313/313 - 1s - loss: 0.0516 - val_loss: 0.0264 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 18/100
# 313/313 - 1s - loss: 0.0515 - val_loss: 0.0243 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 19/100
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 313/313 - 1s - loss: 0.0505 - val_loss: 0.0378 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 20/100
# 313/313 - 1s - loss: 0.0483 - val_loss: 0.0238 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 21/100
# 313/313 - 1s - loss: 0.0462 - val_loss: 0.0202 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 22/100
# 313/313 - 1s - loss: 0.0465 - val_loss: 0.0216 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 23/100
# 313/313 - 1s - loss: 0.0462 - val_loss: 0.0201 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 24/100
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 313/313 - 1s - loss: 0.0451 - val_loss: 0.0219 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 25/100
# 313/313 - 1s - loss: 0.0446 - val_loss: 0.0181 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 26/100
# 313/313 - 1s - loss: 0.0444 - val_loss: 0.0203 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 27/100
# 313/313 - 1s - loss: 0.0435 - val_loss: 0.0202 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 28/100
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 313/313 - 1s - loss: 0.0429 - val_loss: 0.0207 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 29/100
# 313/313 - 1s - loss: 0.0420 - val_loss: 0.0178 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 30/100
# 313/313 - 1s - loss: 0.0418 - val_loss: 0.0181 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 31/100
# 313/313 - 1s - loss: 0.0415 - val_loss: 0.0176 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 32/100
# 313/313 - 1s - loss: 0.0416 - val_loss: 0.0183 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 33/100
# 313/313 - 1s - loss: 0.0413 - val_loss: 0.0186 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 34/100
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 313/313 - 1s - loss: 0.0419 - val_loss: 0.0182 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 35/100
# 313/313 - 1s - loss: 0.0403 - val_loss: 0.0175 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 36/100
# 313/313 - 1s - loss: 0.0406 - val_loss: 0.0172 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 37/100
# 313/313 - 1s - loss: 0.0405 - val_loss: 0.0173 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 38/100
# 313/313 - 1s - loss: 0.0410 - val_loss: 0.0178 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 39/100
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 313/313 - 1s - loss: 0.0403 - val_loss: 0.0174 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 40/100
# 313/313 - 1s - loss: 0.0402 - val_loss: 0.0177 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 41/100
# 313/313 - 1s - loss: 0.0406 - val_loss: 0.0171 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 42/100
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 313/313 - 1s - loss: 0.0398 - val_loss: 0.0175 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 43/100
# 313/313 - 1s - loss: 0.0404 - val_loss: 0.0175 - lr: 7.8125e-06 - 1s/epoch - 4ms/step
# Epoch 44/100
# 313/313 - 1s - loss: 0.0396 - val_loss: 0.0175 - lr: 7.8125e-06 - 1s/epoch - 4ms/step
# Epoch 45/100
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 313/313 - 1s - loss: 0.0402 - val_loss: 0.0176 - lr: 7.8125e-06 - 1s/epoch - 4ms/step
# Epoch 46/100
# 313/313 - 1s - loss: 0.0402 - val_loss: 0.0176 - lr: 3.9063e-06 - 1s/epoch - 4ms/step
#
# --- Fold 4/5 ---
# Epoch 1/100
# 313/313 - 3s - loss: 0.4235 - val_loss: 0.1495 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 2/100
# 313/313 - 1s - loss: 0.1503 - val_loss: 0.0872 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 313/313 - 1s - loss: 0.1076 - val_loss: 0.0741 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 313/313 - 1s - loss: 0.0938 - val_loss: 0.0571 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 313/313 - 1s - loss: 0.0838 - val_loss: 0.0491 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
# 313/313 - 1s - loss: 0.0770 - val_loss: 0.0559 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
# 313/313 - 1s - loss: 0.0769 - val_loss: 0.0404 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/100
# 313/313 - 1s - loss: 0.0699 - val_loss: 0.0414 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 9/100
# 313/313 - 1s - loss: 0.0662 - val_loss: 0.0363 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 10/100
# 313/313 - 1s - loss: 0.0680 - val_loss: 0.0394 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 11/100
# 313/313 - 1s - loss: 0.0687 - val_loss: 0.0430 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 12/100
# 313/313 - 1s - loss: 0.0664 - val_loss: 0.0321 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 13/100
# 313/313 - 1s - loss: 0.0609 - val_loss: 0.0333 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 14/100
# 313/313 - 1s - loss: 0.0587 - val_loss: 0.0300 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 15/100
# 313/313 - 1s - loss: 0.0615 - val_loss: 0.0300 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 16/100
# 313/313 - 1s - loss: 0.0610 - val_loss: 0.0364 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 17/100
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 313/313 - 1s - loss: 0.0596 - val_loss: 0.0314 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 18/100
# 313/313 - 1s - loss: 0.0527 - val_loss: 0.0303 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 19/100
# 313/313 - 1s - loss: 0.0512 - val_loss: 0.0294 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 20/100
# 313/313 - 1s - loss: 0.0521 - val_loss: 0.0261 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 21/100
# 313/313 - 1s - loss: 0.0514 - val_loss: 0.0282 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 22/100
# 313/313 - 1s - loss: 0.0519 - val_loss: 0.0244 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 23/100
# 313/313 - 1s - loss: 0.0514 - val_loss: 0.0325 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 24/100
# 313/313 - 1s - loss: 0.0505 - val_loss: 0.0225 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 25/100
# 313/313 - 1s - loss: 0.0499 - val_loss: 0.0291 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 26/100
# 313/313 - 1s - loss: 0.0524 - val_loss: 0.0241 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 27/100
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 313/313 - 1s - loss: 0.0521 - val_loss: 0.0286 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 28/100
# 313/313 - 1s - loss: 0.0456 - val_loss: 0.0229 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 29/100
# 313/313 - 1s - loss: 0.0433 - val_loss: 0.0232 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
#
# --- Fold 5/5 ---
# Epoch 1/100
# 313/313 - 3s - loss: 0.3433 - val_loss: 0.1266 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 2/100
# 313/313 - 1s - loss: 0.1194 - val_loss: 0.0787 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/100
# 313/313 - 1s - loss: 0.0914 - val_loss: 0.0700 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 4/100
# 313/313 - 1s - loss: 0.0829 - val_loss: 0.0678 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 5/100
# 313/313 - 1s - loss: 0.0775 - val_loss: 0.0518 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/100
# 313/313 - 1s - loss: 0.0777 - val_loss: 0.0600 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/100
# 313/313 - 1s - loss: 0.0713 - val_loss: 0.0461 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/100
# 313/313 - 1s - loss: 0.0657 - val_loss: 0.0427 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 9/100
# 313/313 - 1s - loss: 0.0658 - val_loss: 0.0364 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 10/100
# 313/313 - 1s - loss: 0.0634 - val_loss: 0.0358 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 11/100
# 313/313 - 1s - loss: 0.0606 - val_loss: 0.0374 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 12/100
# 313/313 - 1s - loss: 0.0603 - val_loss: 0.0357 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 13/100
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 313/313 - 1s - loss: 0.0607 - val_loss: 0.0440 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 14/100
# 313/313 - 1s - loss: 0.0525 - val_loss: 0.0270 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 15/100
# 313/313 - 1s - loss: 0.0523 - val_loss: 0.0311 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 16/100
# 313/313 - 1s - loss: 0.0517 - val_loss: 0.0249 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 17/100
# 313/313 - 1s - loss: 0.0518 - val_loss: 0.0325 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 18/100
# 313/313 - 1s - loss: 0.0507 - val_loss: 0.0243 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 19/100
# 313/313 - 1s - loss: 0.0502 - val_loss: 0.0273 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 20/100
# 313/313 - 1s - loss: 0.0500 - val_loss: 0.0271 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 21/100
# 313/313 - 1s - loss: 0.0495 - val_loss: 0.0229 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 22/100
# 313/313 - 1s - loss: 0.0505 - val_loss: 0.0284 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 23/100
# 313/313 - 1s - loss: 0.0506 - val_loss: 0.0285 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 24/100
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 313/313 - 1s - loss: 0.0487 - val_loss: 0.0237 - lr: 5.0000e-04 - 1s/epoch - 4ms/step
# Epoch 25/100
# 313/313 - 1s - loss: 0.0446 - val_loss: 0.0213 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 26/100
# 313/313 - 1s - loss: 0.0425 - val_loss: 0.0203 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 27/100
# 313/313 - 1s - loss: 0.0423 - val_loss: 0.0204 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 28/100
# 313/313 - 1s - loss: 0.0428 - val_loss: 0.0209 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 29/100
# 313/313 - 1s - loss: 0.0430 - val_loss: 0.0190 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 30/100
# 313/313 - 1s - loss: 0.0424 - val_loss: 0.0200 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 31/100
# 313/313 - 1s - loss: 0.0415 - val_loss: 0.0217 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 32/100
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 313/313 - 1s - loss: 0.0435 - val_loss: 0.0211 - lr: 2.5000e-04 - 1s/epoch - 4ms/step
# Epoch 33/100
# 313/313 - 1s - loss: 0.0399 - val_loss: 0.0196 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 34/100
# 313/313 - 1s - loss: 0.0393 - val_loss: 0.0171 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 35/100
# 313/313 - 1s - loss: 0.0389 - val_loss: 0.0175 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 36/100
# 313/313 - 1s - loss: 0.0385 - val_loss: 0.0166 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 37/100
# 313/313 - 1s - loss: 0.0385 - val_loss: 0.0183 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 38/100
# 313/313 - 1s - loss: 0.0393 - val_loss: 0.0172 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 39/100
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 313/313 - 1s - loss: 0.0393 - val_loss: 0.0166 - lr: 1.2500e-04 - 1s/epoch - 4ms/step
# Epoch 40/100
# 313/313 - 1s - loss: 0.0378 - val_loss: 0.0163 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 41/100
# 313/313 - 1s - loss: 0.0376 - val_loss: 0.0159 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 42/100
# 313/313 - 1s - loss: 0.0370 - val_loss: 0.0162 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 43/100
# 313/313 - 1s - loss: 0.0371 - val_loss: 0.0166 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 44/100
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 313/313 - 1s - loss: 0.0368 - val_loss: 0.0160 - lr: 6.2500e-05 - 1s/epoch - 4ms/step
# Epoch 45/100
# 313/313 - 1s - loss: 0.0368 - val_loss: 0.0157 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 46/100
# 313/313 - 1s - loss: 0.0361 - val_loss: 0.0156 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 47/100
# 313/313 - 1s - loss: 0.0364 - val_loss: 0.0154 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 48/100
# 313/313 - 1s - loss: 0.0363 - val_loss: 0.0153 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 49/100
# 313/313 - 1s - loss: 0.0358 - val_loss: 0.0158 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 50/100
# 313/313 - 1s - loss: 0.0357 - val_loss: 0.0150 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 51/100
# 313/313 - 1s - loss: 0.0360 - val_loss: 0.0147 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 52/100
# 313/313 - 1s - loss: 0.0361 - val_loss: 0.0145 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 53/100
# 313/313 - 1s - loss: 0.0357 - val_loss: 0.0145 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 54/100
# 313/313 - 1s - loss: 0.0358 - val_loss: 0.0149 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 55/100
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 313/313 - 1s - loss: 0.0360 - val_loss: 0.0150 - lr: 3.1250e-05 - 1s/epoch - 4ms/step
# Epoch 56/100
# 313/313 - 1s - loss: 0.0356 - val_loss: 0.0149 - lr: 1.5625e-05 - 1s/epoch - 4ms/step
# Epoch 57/100
# 313/313 - 1s - loss: 0.0355 - val_loss: 0.0151 - lr: 1.5625e-05 - 1s/epoch - 4ms/step

# %%
y_pred_ensemble, y_pred_STD = ensemble_predict(trained_models, X_test_y10)
# Out:
# 3229/3229 [==============================] - 4s 1ms/step
# 3229/3229 [==============================] - 4s 1ms/step
# 3229/3229 [==============================] - 4s 1ms/step
# 3229/3229 [==============================] - 4s 1ms/step
# 3229/3229 [==============================] - 4s 1ms/step

# %%
# save the trained model:
root = "/pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models"
save_dir = root + "/y10_specsel_ensemble_CNN_6layers"
save_ensemble(trained_models, save_dir=save_dir)
# Out:
# Saved fold 1 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y10_specsel_ensemble_CNN_6layers/model_fold_1.keras
# Saved fold 2 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y10_specsel_ensemble_CNN_6layers/model_fold_2.keras
# Saved fold 3 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y10_specsel_ensemble_CNN_6layers/model_fold_3.keras
# Saved fold 4 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y10_specsel_ensemble_CNN_6layers/model_fold_4.keras
# Saved fold 5 model to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y10_specsel_ensemble_CNN_6layers/model_fold_5.keras
# Saved normalisation parameters to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y10_specsel_ensemble_CNN_6layers/norm_params.json

# %%
redshift_bins = np.linspace(0,2.5,11)
imag_bins = np.linspace(18, 25.5,11)
#fname = save_dir + "/stats.pkl"
stats2, redshift_stats2, imag_stats2 = get_all_stats(Y_test_y10, y_pred_ensemble.flatten(), test_y10['mag_i_lsst'], save=False, 
                                                     redshift_bins = redshift_bins, imag_bins = imag_bins)

plot_stats(stats2, redshift_stats2, imag_stats2, Y_test_y10, y_pred_ensemble.flatten(), 
           redshift_bins, imag_bins, test_y10['mag_i_lsst'], save_path=save_dir + '/photoz_stats.png')
# Out:
# /tmp/ipykernel_1275168/1952338895.py:98: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Plot saved to /pscratch/sd/q/qhang/cnnpz/noisy_Cardinal/models/y10_specsel_ensemble_CNN_6layers/photoz_stats.png

# %% [markdown]
# ## Now include pre-training with the pop-cosmos data

# %%
# load pre-training data
fname = "/pscratch/sd/q/qhang/pop-cosmos-data/mock_catalog_Ch1_26.degrade_lsst_y1.parquet"
pretraining_y1 = pd.read_parquet(fname)
# change the name of the roman columns:
pretraining_y1 = pretraining_y1.rename(columns={'Roman_obs_J129': 'mag_J_roman', 
                                              'Roman_obs_H158': 'mag_H_roman'})

fname = "/pscratch/sd/q/qhang/pop-cosmos-data/mock_catalog_Ch1_26.degrade_lsst_y10.parquet"
pretraining_y10 = pd.read_parquet(fname)
# change the name of the roman columns:
pretraining_y10 = pretraining_y10.rename(columns={'Roman_obs_J129': 'mag_J_roman', 
                                              'Roman_obs_H158': 'mag_H_roman'})

# %%
# plot comparison in colour-redshift space:
fig,axarr=plt.subplots(1,3,figsize=[10,3],sharey=True)

for ii, colours in enumerate(['gr','ri','iz']):
    plt.sca(axarr[ii])
    ri = pretraining_y10[f'mag_{colours[0]}_lsst'] - pretraining_y10[f'mag_{colours[1]}_lsst']
    red = pretraining_y10['redshift']
    ind = pretraining_y10['mag_i_lsst'] < 25.4
    plt.scatter(red[ind][::50], ri[ind][::50], s=0.1, label="pre-training data")
    
    ri = training_y10[f'mag_{colours[0]}_lsst'] - training_y10[f'mag_{colours[1]}_lsst']
    red = training_y10['redshift']
    plt.scatter(red[::10], ri[::10], s=0.1, label="test data")
    
    plt.grid()
    plt.legend()
    plt.xlabel("redshift")
    plt.ylabel(f"{colours[0]}-{colours[1]}")
    plt.ylim([-1.5,5])

# %%
# pre-training data:
pretraining_y10 = pretraining_y10[pretraining_y10['redshift']<2.4]
pretraining_y10 = pretraining_y10.sample(frac=0.5)
pretraining_y10 = pretraining_y10.reset_index(drop=True)
X_y10_pre, Y_y10_pre = transform_data_to_XY(pretraining_y10)

# %%
len(Y_y10_pre)
# Out:
# 452012

# %%
trained_models, histories = train_ensembles(build_model, X_y10_pre, Y_y10_pre)
# Out:
# --- Fold 1/5 ---
# Epoch 1/100
# 1413/1413 - 7s - loss: 0.0100 - val_loss: 0.0029 - lr: 0.0010 - 7s/epoch - 5ms/step
# Epoch 2/100
# 1413/1413 - 5s - loss: 0.0035 - val_loss: 0.0023 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 3/100
# 1413/1413 - 5s - loss: 0.0031 - val_loss: 0.0023 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 4/100
# 1413/1413 - 5s - loss: 0.0029 - val_loss: 0.0018 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 5/100
# 1413/1413 - 5s - loss: 0.0027 - val_loss: 0.0023 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 6/100
# 1413/1413 - 5s - loss: 0.0026 - val_loss: 0.0019 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 7/100
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1413/1413 - 5s - loss: 0.0026 - val_loss: 0.0019 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 8/100
# 1413/1413 - 5s - loss: 0.0023 - val_loss: 0.0015 - lr: 5.0000e-04 - 5s/epoch - 4ms/step
# Epoch 9/100
# 1413/1413 - 5s - loss: 0.0022 - val_loss: 0.0015 - lr: 5.0000e-04 - 5s/epoch - 4ms/step
# Epoch 10/100
# 1413/1413 - 5s - loss: 0.0022 - val_loss: 0.0015 - lr: 5.0000e-04 - 5s/epoch - 4ms/step
# Epoch 11/100
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1413/1413 - 5s - loss: 0.0021 - val_loss: 0.0015 - lr: 5.0000e-04 - 5s/epoch - 4ms/step
# Epoch 12/100
# 1413/1413 - 5s - loss: 0.0020 - val_loss: 0.0014 - lr: 2.5000e-04 - 5s/epoch - 4ms/step
# Epoch 13/100
# 1413/1413 - 5s - loss: 0.0020 - val_loss: 0.0013 - lr: 2.5000e-04 - 5s/epoch - 4ms/step
# Epoch 14/100
# 1413/1413 - 5s - loss: 0.0020 - val_loss: 0.0013 - lr: 2.5000e-04 - 5s/epoch - 4ms/step
# Epoch 15/100
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1413/1413 - 5s - loss: 0.0020 - val_loss: 0.0013 - lr: 2.5000e-04 - 5s/epoch - 4ms/step
# Epoch 16/100
# 1413/1413 - 5s - loss: 0.0019 - val_loss: 0.0014 - lr: 1.2500e-04 - 5s/epoch - 4ms/step
# Epoch 17/100
# 1413/1413 - 5s - loss: 0.0019 - val_loss: 0.0013 - lr: 1.2500e-04 - 5s/epoch - 4ms/step
# Epoch 18/100
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 1413/1413 - 5s - loss: 0.0019 - val_loss: 0.0013 - lr: 1.2500e-04 - 5s/epoch - 4ms/step
# Epoch 19/100
# 1413/1413 - 5s - loss: 0.0019 - val_loss: 0.0013 - lr: 6.2500e-05 - 5s/epoch - 4ms/step
# Epoch 20/100
# 1413/1413 - 5s - loss: 0.0019 - val_loss: 0.0013 - lr: 6.2500e-05 - 5s/epoch - 4ms/step
# Epoch 21/100
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 1413/1413 - 5s - loss: 0.0019 - val_loss: 0.0013 - lr: 6.2500e-05 - 5s/epoch - 4ms/step
# Epoch 22/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 3.1250e-05 - 5s/epoch - 4ms/step
# Epoch 23/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 3.1250e-05 - 5s/epoch - 4ms/step
# Epoch 24/100
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 3.1250e-05 - 5s/epoch - 4ms/step
# Epoch 25/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 1.5625e-05 - 5s/epoch - 4ms/step
# Epoch 26/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 1.5625e-05 - 5s/epoch - 4ms/step
# Epoch 27/100
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 1.5625e-05 - 5s/epoch - 4ms/step
# Epoch 28/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 7.8125e-06 - 5s/epoch - 4ms/step
# Epoch 29/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 7.8125e-06 - 5s/epoch - 4ms/step
# Epoch 30/100
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 7.8125e-06 - 5s/epoch - 4ms/step
# Epoch 31/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 3.9063e-06 - 5s/epoch - 4ms/step
# Epoch 32/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 3.9063e-06 - 5s/epoch - 4ms/step
# Epoch 33/100
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 3.9063e-06 - 5s/epoch - 4ms/step
# Epoch 34/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 1.9531e-06 - 5s/epoch - 4ms/step
#
# --- Fold 2/5 ---
# Epoch 1/100
# 1413/1413 - 7s - loss: 0.0100 - val_loss: 0.0028 - lr: 0.0010 - 7s/epoch - 5ms/step
# Epoch 2/100
# 1413/1413 - 5s - loss: 0.0036 - val_loss: 0.0025 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 3/100
# 1413/1413 - 5s - loss: 0.0031 - val_loss: 0.0020 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 4/100
# 1413/1413 - 5s - loss: 0.0028 - val_loss: 0.0022 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 5/100
# 1413/1413 - 5s - loss: 0.0027 - val_loss: 0.0023 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 6/100
# 1413/1413 - 5s - loss: 0.0026 - val_loss: 0.0018 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 7/100
# 1413/1413 - 5s - loss: 0.0024 - val_loss: 0.0020 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 8/100
# 1413/1413 - 5s - loss: 0.0023 - val_loss: 0.0016 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 9/100
# 1413/1413 - 5s - loss: 0.0022 - val_loss: 0.0016 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 10/100
# 1413/1413 - 5s - loss: 0.0022 - val_loss: 0.0016 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 11/100
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1413/1413 - 5s - loss: 0.0021 - val_loss: 0.0015 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 12/100
# 1413/1413 - 5s - loss: 0.0020 - val_loss: 0.0013 - lr: 5.0000e-04 - 5s/epoch - 4ms/step
# Epoch 13/100
# 1413/1413 - 5s - loss: 0.0020 - val_loss: 0.0014 - lr: 5.0000e-04 - 5s/epoch - 4ms/step
# Epoch 14/100
# 1413/1413 - 5s - loss: 0.0020 - val_loss: 0.0013 - lr: 5.0000e-04 - 5s/epoch - 4ms/step
# Epoch 15/100
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1413/1413 - 5s - loss: 0.0020 - val_loss: 0.0013 - lr: 5.0000e-04 - 5s/epoch - 4ms/step
# Epoch 16/100
# 1413/1413 - 5s - loss: 0.0019 - val_loss: 0.0014 - lr: 2.5000e-04 - 5s/epoch - 4ms/step
# Epoch 17/100
# 1413/1413 - 5s - loss: 0.0019 - val_loss: 0.0013 - lr: 2.5000e-04 - 5s/epoch - 4ms/step
# Epoch 18/100
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0014 - lr: 2.5000e-04 - 5s/epoch - 4ms/step
# Epoch 19/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 1.2500e-04 - 5s/epoch - 4ms/step
# Epoch 20/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 1.2500e-04 - 5s/epoch - 4ms/step
# Epoch 21/100
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0012 - lr: 1.2500e-04 - 5s/epoch - 4ms/step
# Epoch 22/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 6.2500e-05 - 5s/epoch - 4ms/step
# Epoch 23/100
# 1413/1413 - 5s - loss: 0.0017 - val_loss: 0.0013 - lr: 6.2500e-05 - 5s/epoch - 4ms/step
# Epoch 24/100
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 1413/1413 - 5s - loss: 0.0017 - val_loss: 0.0012 - lr: 6.2500e-05 - 5s/epoch - 4ms/step
# Epoch 25/100
# 1413/1413 - 5s - loss: 0.0017 - val_loss: 0.0012 - lr: 3.1250e-05 - 5s/epoch - 4ms/step
# Epoch 26/100
# 1413/1413 - 5s - loss: 0.0017 - val_loss: 0.0012 - lr: 3.1250e-05 - 5s/epoch - 4ms/step
# Epoch 27/100
# 1413/1413 - 5s - loss: 0.0017 - val_loss: 0.0012 - lr: 3.1250e-05 - 5s/epoch - 4ms/step
# Epoch 28/100
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 1413/1413 - 5s - loss: 0.0017 - val_loss: 0.0012 - lr: 3.1250e-05 - 5s/epoch - 4ms/step
# Epoch 29/100
# 1413/1413 - 5s - loss: 0.0017 - val_loss: 0.0012 - lr: 1.5625e-05 - 5s/epoch - 4ms/step
# Epoch 30/100
# 1413/1413 - 5s - loss: 0.0017 - val_loss: 0.0012 - lr: 1.5625e-05 - 5s/epoch - 4ms/step
#
# --- Fold 3/5 ---
# Epoch 1/100
# 1413/1413 - 7s - loss: 0.0093 - val_loss: 0.0027 - lr: 0.0010 - 7s/epoch - 5ms/step
# Epoch 2/100
# 1413/1413 - 5s - loss: 0.0034 - val_loss: 0.0022 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 3/100
# 1413/1413 - 5s - loss: 0.0030 - val_loss: 0.0021 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 4/100
# 1413/1413 - 5s - loss: 0.0028 - val_loss: 0.0017 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 5/100
# 1413/1413 - 5s - loss: 0.0026 - val_loss: 0.0018 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 6/100
# 1413/1413 - 5s - loss: 0.0024 - val_loss: 0.0017 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 7/100
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1413/1413 - 5s - loss: 0.0023 - val_loss: 0.0017 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 8/100
# 1413/1413 - 5s - loss: 0.0021 - val_loss: 0.0014 - lr: 5.0000e-04 - 5s/epoch - 4ms/step
# Epoch 9/100
# 1413/1413 - 5s - loss: 0.0021 - val_loss: 0.0014 - lr: 5.0000e-04 - 5s/epoch - 4ms/step
# Epoch 10/100
# 1413/1413 - 5s - loss: 0.0021 - val_loss: 0.0015 - lr: 5.0000e-04 - 5s/epoch - 4ms/step
# Epoch 11/100
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1413/1413 - 5s - loss: 0.0020 - val_loss: 0.0014 - lr: 5.0000e-04 - 5s/epoch - 4ms/step
# Epoch 12/100
# 1413/1413 - 5s - loss: 0.0019 - val_loss: 0.0014 - lr: 2.5000e-04 - 5s/epoch - 4ms/step
# Epoch 13/100
# 1413/1413 - 5s - loss: 0.0019 - val_loss: 0.0013 - lr: 2.5000e-04 - 5s/epoch - 4ms/step
# Epoch 14/100
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1413/1413 - 5s - loss: 0.0019 - val_loss: 0.0014 - lr: 2.5000e-04 - 5s/epoch - 4ms/step
# Epoch 15/100
# 1413/1413 - 5s - loss: 0.0019 - val_loss: 0.0013 - lr: 1.2500e-04 - 5s/epoch - 4ms/step
# Epoch 16/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 1.2500e-04 - 5s/epoch - 4ms/step
# Epoch 17/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 1.2500e-04 - 5s/epoch - 4ms/step
# Epoch 18/100
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 1.2500e-04 - 5s/epoch - 4ms/step
# Epoch 19/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 6.2500e-05 - 5s/epoch - 4ms/step
# Epoch 20/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 6.2500e-05 - 5s/epoch - 4ms/step
# Epoch 21/100
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 6.2500e-05 - 5s/epoch - 4ms/step
# Epoch 22/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 3.1250e-05 - 5s/epoch - 4ms/step
# Epoch 23/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 3.1250e-05 - 5s/epoch - 4ms/step
# Epoch 24/100
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 3.1250e-05 - 5s/epoch - 4ms/step
# Epoch 25/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 1.5625e-05 - 5s/epoch - 4ms/step
# Epoch 26/100
# 1413/1413 - 5s - loss: 0.0017 - val_loss: 0.0013 - lr: 1.5625e-05 - 5s/epoch - 4ms/step
# Epoch 27/100
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 1413/1413 - 5s - loss: 0.0017 - val_loss: 0.0013 - lr: 1.5625e-05 - 5s/epoch - 4ms/step
#
# --- Fold 4/5 ---
# Epoch 1/100
# 1413/1413 - 7s - loss: 0.0078 - val_loss: 0.0030 - lr: 0.0010 - 7s/epoch - 5ms/step
# Epoch 2/100
# 1413/1413 - 5s - loss: 0.0033 - val_loss: 0.0021 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 3/100
# 1413/1413 - 5s - loss: 0.0029 - val_loss: 0.0024 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 4/100
# 1413/1413 - 5s - loss: 0.0027 - val_loss: 0.0019 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 5/100
# 1413/1413 - 5s - loss: 0.0025 - val_loss: 0.0017 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 6/100
# 1413/1413 - 5s - loss: 0.0024 - val_loss: 0.0016 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 7/100
# 1413/1413 - 5s - loss: 0.0024 - val_loss: 0.0015 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 8/100
# 1413/1413 - 5s - loss: 0.0023 - val_loss: 0.0017 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 9/100
# 1413/1413 - 5s - loss: 0.0022 - val_loss: 0.0017 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 10/100
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1413/1413 - 5s - loss: 0.0022 - val_loss: 0.0015 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 11/100
# 1413/1413 - 5s - loss: 0.0020 - val_loss: 0.0014 - lr: 5.0000e-04 - 5s/epoch - 4ms/step
# Epoch 12/100
# 1413/1413 - 5s - loss: 0.0020 - val_loss: 0.0014 - lr: 5.0000e-04 - 5s/epoch - 4ms/step
# Epoch 13/100
# 1413/1413 - 5s - loss: 0.0020 - val_loss: 0.0013 - lr: 5.0000e-04 - 5s/epoch - 4ms/step
# Epoch 14/100
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1413/1413 - 5s - loss: 0.0020 - val_loss: 0.0014 - lr: 5.0000e-04 - 5s/epoch - 4ms/step
# Epoch 15/100
# 1413/1413 - 5s - loss: 0.0019 - val_loss: 0.0013 - lr: 2.5000e-04 - 5s/epoch - 4ms/step
# Epoch 16/100
# 1413/1413 - 5s - loss: 0.0019 - val_loss: 0.0014 - lr: 2.5000e-04 - 5s/epoch - 4ms/step
# Epoch 17/100
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 2.5000e-04 - 5s/epoch - 4ms/step
# Epoch 18/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 1.2500e-04 - 5s/epoch - 4ms/step
# Epoch 19/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 1.2500e-04 - 5s/epoch - 4ms/step
# Epoch 20/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 1.2500e-04 - 5s/epoch - 4ms/step
# Epoch 21/100
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 1.2500e-04 - 5s/epoch - 4ms/step
# Epoch 22/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 6.2500e-05 - 5s/epoch - 4ms/step
# Epoch 23/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 6.2500e-05 - 5s/epoch - 4ms/step
#
# --- Fold 5/5 ---
# Epoch 1/100
# 1413/1413 - 7s - loss: 0.0083 - val_loss: 0.0030 - lr: 0.0010 - 7s/epoch - 5ms/step
# Epoch 2/100
# 1413/1413 - 5s - loss: 0.0035 - val_loss: 0.0023 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 3/100
# 1413/1413 - 5s - loss: 0.0032 - val_loss: 0.0027 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 4/100
# 1413/1413 - 5s - loss: 0.0029 - val_loss: 0.0018 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 5/100
# 1413/1413 - 5s - loss: 0.0027 - val_loss: 0.0018 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 6/100
# 1413/1413 - 5s - loss: 0.0026 - val_loss: 0.0017 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 7/100
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1413/1413 - 5s - loss: 0.0025 - val_loss: 0.0018 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 8/100
# 1413/1413 - 5s - loss: 0.0023 - val_loss: 0.0015 - lr: 5.0000e-04 - 5s/epoch - 4ms/step
# Epoch 9/100
# 1413/1413 - 5s - loss: 0.0022 - val_loss: 0.0015 - lr: 5.0000e-04 - 5s/epoch - 4ms/step
# Epoch 10/100
# 1413/1413 - 5s - loss: 0.0022 - val_loss: 0.0014 - lr: 5.0000e-04 - 5s/epoch - 4ms/step
# Epoch 11/100
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1413/1413 - 5s - loss: 0.0021 - val_loss: 0.0014 - lr: 5.0000e-04 - 5s/epoch - 4ms/step
# Epoch 12/100
# 1413/1413 - 5s - loss: 0.0020 - val_loss: 0.0014 - lr: 2.5000e-04 - 5s/epoch - 4ms/step
# Epoch 13/100
# 1413/1413 - 5s - loss: 0.0020 - val_loss: 0.0013 - lr: 2.5000e-04 - 5s/epoch - 4ms/step
# Epoch 14/100
# 1413/1413 - 5s - loss: 0.0020 - val_loss: 0.0014 - lr: 2.5000e-04 - 5s/epoch - 4ms/step
# Epoch 15/100
# 1413/1413 - 5s - loss: 0.0019 - val_loss: 0.0013 - lr: 2.5000e-04 - 5s/epoch - 4ms/step
# Epoch 16/100
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1413/1413 - 5s - loss: 0.0019 - val_loss: 0.0013 - lr: 2.5000e-04 - 5s/epoch - 4ms/step
# Epoch 17/100
# 1413/1413 - 5s - loss: 0.0019 - val_loss: 0.0013 - lr: 1.2500e-04 - 5s/epoch - 4ms/step
# Epoch 18/100
# 1413/1413 - 5s - loss: 0.0019 - val_loss: 0.0013 - lr: 1.2500e-04 - 5s/epoch - 4ms/step
# Epoch 19/100
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 1.2500e-04 - 5s/epoch - 4ms/step
# Epoch 20/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 6.2500e-05 - 5s/epoch - 4ms/step
# Epoch 21/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 6.2500e-05 - 5s/epoch - 4ms/step
# Epoch 22/100
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 6.2500e-05 - 5s/epoch - 4ms/step
# Epoch 23/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 3.1250e-05 - 5s/epoch - 4ms/step
# Epoch 24/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 3.1250e-05 - 5s/epoch - 4ms/step
# Epoch 25/100
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0012 - lr: 3.1250e-05 - 5s/epoch - 4ms/step
# Epoch 26/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0012 - lr: 1.5625e-05 - 5s/epoch - 4ms/step
# Epoch 27/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0012 - lr: 1.5625e-05 - 5s/epoch - 4ms/step
# Epoch 28/100
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0013 - lr: 1.5625e-05 - 5s/epoch - 4ms/step
# Epoch 29/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0012 - lr: 7.8125e-06 - 5s/epoch - 4ms/step
# Epoch 30/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0012 - lr: 7.8125e-06 - 5s/epoch - 4ms/step
# Epoch 31/100
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0012 - lr: 7.8125e-06 - 5s/epoch - 4ms/step
# Epoch 32/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0012 - lr: 3.9063e-06 - 5s/epoch - 4ms/step
# Epoch 33/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0012 - lr: 3.9063e-06 - 5s/epoch - 4ms/step
# Epoch 34/100
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0012 - lr: 3.9063e-06 - 5s/epoch - 4ms/step
# Epoch 35/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0012 - lr: 1.9531e-06 - 5s/epoch - 4ms/step
# Epoch 36/100
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0012 - lr: 1.9531e-06 - 5s/epoch - 4ms/step
# Epoch 37/100
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1e-06.
# 1413/1413 - 5s - loss: 0.0018 - val_loss: 0.0012 - lr: 1.9531e-06 - 5s/epoch - 4ms/step

# %%
plot_ensemble_losses(histories, ylim=(0, 0.01))

# %%
# then fine tune:
def fine_tune_pre_trained_model(X_fortrain, Y_fortrain, pretrained_models = None, model_root = "", nlayers_forzen = 4):

    # need to provide either the model or the model_dir to load the model
    # will always load model if both are provided

    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    
    trained_models = []
    histories = []
    
    for fold, (idx_train, idx_val) in enumerate(kf.split(X_fortrain)):
    
        print(f"\n--- Fold {fold+1}/5 ---")
        tf.keras.backend.clear_session()
        
        # ── Callbacks ─────────────────────────────────────────────────────────────────
        early_stop = callbacks.EarlyStopping(
        monitor='val_loss', patience=5, restore_best_weights=True
        )
        reduce_lr = callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1
        )
        
        # Split data using fold indices
        X_train, X_val = X_fortrain[idx_train], X_fortrain[idx_val]
        Y_train, Y_val = Y_fortrain[idx_train], Y_fortrain[idx_val]

        if model_root != "":
            model = tf.keras.models.load_model(model_root + f'model_fold_{fold+1}.keras')
        else:
            model = pretrained_models[fold][0]
        
        # Step 2: optionally freeze early layers (keep low-level features fixed)
        for layer in model.layers[:nlayers_forzen]:     # freeze first 4 layers
            layer.trainable = False
    
        # same normalization as the pre-training
        Y_mean = 0
        Y_std = 3
        # Normalise Y using train statistics only
        Y_mean, Y_std = Y_train.mean(), Y_train.std()
        Y_train_norm = (Y_train - Y_mean) / Y_std
        Y_val_norm   = (Y_val   - Y_mean) / Y_std
    
        
        # Step 3: recompile with a LOWER learning rate — important
        # too high a learning rate will destroy what the model already learned
        model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),  # much lower than default 1e-3
            loss='mse',
            metrics=['mae']
        )
        
        # Step 4: train on new data
        history = model.fit(
            X_train, Y_train_norm,
            validation_data=(X_val, Y_val_norm),
            epochs=60,           # fewer epochs than original training
            batch_size=256,
            callbacks=[early_stop, reduce_lr],
            verbose=2
        )
    
        trained_models.append((model, Y_mean, Y_std))  # save model + its normalisation
        histories.append(history)
        
    return trained_models, histories

# %%
trained_models_finetune, histories_finetune = fine_tune_pre_trained_model(X_y10_spec, Y_y10_spec, 
                                                pretrained_models = trained_models, 
                                                model_root = "", nlayers_forzen = 4)
# Out:
# --- Fold 1/5 ---
# Epoch 1/60
# 313/313 - 3s - loss: 0.2523 - mae: 0.3267 - val_loss: 0.0452 - val_mae: 0.1289 - lr: 1.0000e-04 - 3s/epoch - 8ms/step
# Epoch 2/60
# 313/313 - 1s - loss: 0.0609 - mae: 0.1632 - val_loss: 0.0316 - val_mae: 0.1044 - lr: 1.0000e-04 - 1s/epoch - 3ms/step
# Epoch 3/60
# 313/313 - 1s - loss: 0.0542 - mae: 0.1536 - val_loss: 0.0279 - val_mae: 0.0980 - lr: 1.0000e-04 - 1s/epoch - 3ms/step
# Epoch 4/60
# 313/313 - 1s - loss: 0.0502 - mae: 0.1484 - val_loss: 0.0260 - val_mae: 0.0924 - lr: 1.0000e-04 - 1s/epoch - 3ms/step
# Epoch 5/60
# 313/313 - 1s - loss: 0.0480 - mae: 0.1460 - val_loss: 0.0248 - val_mae: 0.0916 - lr: 1.0000e-04 - 1s/epoch - 3ms/step
# Epoch 6/60
# 313/313 - 1s - loss: 0.0463 - mae: 0.1433 - val_loss: 0.0263 - val_mae: 0.0886 - lr: 1.0000e-04 - 1s/epoch - 3ms/step
# Epoch 7/60
# 313/313 - 1s - loss: 0.0459 - mae: 0.1428 - val_loss: 0.0213 - val_mae: 0.0833 - lr: 1.0000e-04 - 1s/epoch - 3ms/step
# Epoch 8/60
# 313/313 - 1s - loss: 0.0446 - mae: 0.1410 - val_loss: 0.0229 - val_mae: 0.0828 - lr: 1.0000e-04 - 1s/epoch - 3ms/step
# Epoch 9/60
# 313/313 - 1s - loss: 0.0429 - mae: 0.1392 - val_loss: 0.0222 - val_mae: 0.0875 - lr: 1.0000e-04 - 1s/epoch - 3ms/step
# Epoch 10/60
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 313/313 - 1s - loss: 0.0424 - mae: 0.1382 - val_loss: 0.0216 - val_mae: 0.0886 - lr: 1.0000e-04 - 1s/epoch - 3ms/step
# Epoch 11/60
# 313/313 - 1s - loss: 0.0410 - mae: 0.1367 - val_loss: 0.0204 - val_mae: 0.0812 - lr: 5.0000e-05 - 1s/epoch - 3ms/step
# Epoch 12/60
# 313/313 - 1s - loss: 0.0402 - mae: 0.1355 - val_loss: 0.0209 - val_mae: 0.0794 - lr: 5.0000e-05 - 1s/epoch - 3ms/step
# Epoch 13/60
# 313/313 - 1s - loss: 0.0409 - mae: 0.1361 - val_loss: 0.0199 - val_mae: 0.0792 - lr: 5.0000e-05 - 1s/epoch - 3ms/step
# Epoch 14/60
# 313/313 - 1s - loss: 0.0396 - mae: 0.1351 - val_loss: 0.0200 - val_mae: 0.0808 - lr: 5.0000e-05 - 1s/epoch - 3ms/step
# Epoch 15/60
# 313/313 - 1s - loss: 0.0393 - mae: 0.1345 - val_loss: 0.0185 - val_mae: 0.0804 - lr: 5.0000e-05 - 1s/epoch - 3ms/step
# Epoch 16/60
# 313/313 - 1s - loss: 0.0394 - mae: 0.1341 - val_loss: 0.0188 - val_mae: 0.0774 - lr: 5.0000e-05 - 1s/epoch - 3ms/step
# Epoch 17/60
# 313/313 - 1s - loss: 0.0388 - mae: 0.1336 - val_loss: 0.0184 - val_mae: 0.0777 - lr: 5.0000e-05 - 1s/epoch - 3ms/step
# Epoch 18/60
# 313/313 - 1s - loss: 0.0391 - mae: 0.1334 - val_loss: 0.0184 - val_mae: 0.0784 - lr: 5.0000e-05 - 1s/epoch - 3ms/step
# Epoch 19/60
# 313/313 - 1s - loss: 0.0381 - mae: 0.1325 - val_loss: 0.0178 - val_mae: 0.0767 - lr: 5.0000e-05 - 1s/epoch - 3ms/step
# Epoch 20/60
# 313/313 - 1s - loss: 0.0383 - mae: 0.1331 - val_loss: 0.0168 - val_mae: 0.0760 - lr: 5.0000e-05 - 1s/epoch - 3ms/step
# Epoch 21/60
# 313/313 - 1s - loss: 0.0373 - mae: 0.1315 - val_loss: 0.0179 - val_mae: 0.0776 - lr: 5.0000e-05 - 1s/epoch - 3ms/step
# Epoch 22/60
# 313/313 - 1s - loss: 0.0378 - mae: 0.1319 - val_loss: 0.0182 - val_mae: 0.0779 - lr: 5.0000e-05 - 1s/epoch - 3ms/step
# Epoch 23/60
# 313/313 - 1s - loss: 0.0375 - mae: 0.1314 - val_loss: 0.0167 - val_mae: 0.0757 - lr: 5.0000e-05 - 1s/epoch - 3ms/step
# Epoch 24/60
# 313/313 - 1s - loss: 0.0370 - mae: 0.1312 - val_loss: 0.0176 - val_mae: 0.0803 - lr: 5.0000e-05 - 1s/epoch - 3ms/step
# Epoch 25/60
# 313/313 - 1s - loss: 0.0363 - mae: 0.1304 - val_loss: 0.0165 - val_mae: 0.0739 - lr: 5.0000e-05 - 1s/epoch - 3ms/step
# Epoch 26/60
# 313/313 - 1s - loss: 0.0362 - mae: 0.1300 - val_loss: 0.0167 - val_mae: 0.0751 - lr: 5.0000e-05 - 1s/epoch - 3ms/step
# Epoch 27/60
# 313/313 - 1s - loss: 0.0368 - mae: 0.1305 - val_loss: 0.0174 - val_mae: 0.0769 - lr: 5.0000e-05 - 1s/epoch - 3ms/step
# Epoch 28/60
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 313/313 - 1s - loss: 0.0358 - mae: 0.1298 - val_loss: 0.0165 - val_mae: 0.0735 - lr: 5.0000e-05 - 1s/epoch - 3ms/step
# Epoch 29/60
# 313/313 - 1s - loss: 0.0355 - mae: 0.1293 - val_loss: 0.0163 - val_mae: 0.0735 - lr: 2.5000e-05 - 1s/epoch - 3ms/step
# Epoch 30/60
# 313/313 - 1s - loss: 0.0353 - mae: 0.1283 - val_loss: 0.0161 - val_mae: 0.0727 - lr: 2.5000e-05 - 1s/epoch - 3ms/step
# Epoch 31/60
# 313/313 - 1s - loss: 0.0351 - mae: 0.1289 - val_loss: 0.0168 - val_mae: 0.0751 - lr: 2.5000e-05 - 1s/epoch - 3ms/step
# Epoch 32/60
# 313/313 - 1s - loss: 0.0353 - mae: 0.1288 - val_loss: 0.0166 - val_mae: 0.0719 - lr: 2.5000e-05 - 1s/epoch - 3ms/step
# Epoch 33/60
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 313/313 - 1s - loss: 0.0350 - mae: 0.1285 - val_loss: 0.0164 - val_mae: 0.0744 - lr: 2.5000e-05 - 1s/epoch - 3ms/step
# Epoch 34/60
# 313/313 - 1s - loss: 0.0352 - mae: 0.1283 - val_loss: 0.0158 - val_mae: 0.0726 - lr: 1.2500e-05 - 995ms/epoch - 3ms/step
# Epoch 35/60
# 313/313 - 1s - loss: 0.0352 - mae: 0.1287 - val_loss: 0.0161 - val_mae: 0.0720 - lr: 1.2500e-05 - 999ms/epoch - 3ms/step
# Epoch 36/60
# 313/313 - 1s - loss: 0.0352 - mae: 0.1283 - val_loss: 0.0159 - val_mae: 0.0718 - lr: 1.2500e-05 - 1s/epoch - 3ms/step
# Epoch 37/60
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 313/313 - 1s - loss: 0.0342 - mae: 0.1272 - val_loss: 0.0158 - val_mae: 0.0730 - lr: 1.2500e-05 - 1s/epoch - 3ms/step
# Epoch 38/60
# 313/313 - 1s - loss: 0.0347 - mae: 0.1276 - val_loss: 0.0161 - val_mae: 0.0721 - lr: 6.2500e-06 - 1s/epoch - 3ms/step
# Epoch 39/60
# 313/313 - 1s - loss: 0.0343 - mae: 0.1271 - val_loss: 0.0157 - val_mae: 0.0721 - lr: 6.2500e-06 - 1s/epoch - 3ms/step
# Epoch 40/60
# 313/313 - 1s - loss: 0.0341 - mae: 0.1270 - val_loss: 0.0160 - val_mae: 0.0727 - lr: 6.2500e-06 - 1s/epoch - 3ms/step
# Epoch 41/60
# 313/313 - 1s - loss: 0.0346 - mae: 0.1280 - val_loss: 0.0160 - val_mae: 0.0730 - lr: 6.2500e-06 - 1s/epoch - 3ms/step
# Epoch 42/60
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 313/313 - 1s - loss: 0.0342 - mae: 0.1272 - val_loss: 0.0161 - val_mae: 0.0733 - lr: 6.2500e-06 - 1s/epoch - 3ms/step
# Epoch 43/60
# 313/313 - 1s - loss: 0.0346 - mae: 0.1279 - val_loss: 0.0157 - val_mae: 0.0720 - lr: 3.1250e-06 - 1s/epoch - 3ms/step
# Epoch 44/60
# 313/313 - 1s - loss: 0.0343 - mae: 0.1270 - val_loss: 0.0159 - val_mae: 0.0726 - lr: 3.1250e-06 - 1s/epoch - 3ms/step

# %% [raw]
# auto grad / grad cam - >
